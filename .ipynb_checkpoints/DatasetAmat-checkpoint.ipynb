# %%
#!/usr/bin/python
import nltk
import numpy as np
import re
import tensorflow as tf
from nltk.tokenize import WordPunctTokenizer
from random import randint
from sklearn.model_selection import train_test_split
import random

# %% [markdown]
# Importing Glove and  40000 words list

# %%
wordsList = np.load('wordsList.npy')
print('Loaded the word list!')
wordsList = wordsList.tolist() #Originally loaded as numpy array
wordsList = [word.decode('UTF-8') for word in wordsList] #Encode words as UTF-8
wordVectors = np.load('wordVectors.npy')
print ('Loaded the word vectors!')
print(len(wordsList))
print(wordVectors.shape)
print(wordsList[5066])
print(wordVectors[5066][:])
# Out:
# Loaded the word list!
# Loaded the word vectors!
# 400000
# (400000, 50)
# closure
# [ 0.50653   0.12284  -0.11653  -0.21052  -1.0672   -0.17536   0.16253
#   0.76781   0.25517  -0.15995   0.025424 -0.65425  -0.44638  -0.19395
#   0.45319   1.0955    0.050096 -0.36712   0.1729    0.28393   0.85448
#  -0.54932  -1.1816    0.066158 -0.58561  -0.84893   0.1947    0.37832
#   0.94141   0.62982   2.3869   -0.41035  -0.11599   0.049907 -0.41563
#  -0.056999  1.5044   -0.93772  -0.16045   0.80019  -0.44448  -0.50036
#   0.065875  0.27778  -0.27505  -0.012317 -0.37458   0.49171  -0.35498
#   0.035347]

# %% [markdown]
# Importing the Dataset

# %%
#--------------------Extracting Emotion && sentences from corpus
def extract(dataset):
    f = open(dataset, 'r+')
    linea = f.readline()
    emotion = []
    sentences = []
    neutro = re.compile('^ne')
    while linea != "":    
        #Ignoramos Neutro emotions
        if not re.match(neutro, linea):
            #print("** ",linea)
            linea = linea.split("#")
            #Obtaining the emocion
            emotion.append(linea[0])
            sentences.append(linea[1])
        linea = f.readline()
    f.close()
    return sentences,emotion

dataset = "Aman_Dataset/category_gold_std.txt"
sentences,emotion = extract(dataset)
print(emotion[0]," ",sentences[0])
print("Labels: ",len(emotion), "Sentences: ",len(sentences))
# Out:
# hp 1   This was the best summer I have ever experienced.
#
# Labels:  1290 Sentences:  1290

# %% [markdown]
# Reformating Emotion to Integer Representation : {hp = 0, sd = 1, ag = 2, dg = 3, sp = 4, fr = 5}

# %%
def toClasses(emo):
    id_emo = []
    for e in emo:
        e = e.split()
        e = e[0]
        if e == 'hp':
            e = 0
        elif e == 'sd':
            e = 1
        elif e == 'ag':
            e = 2
        elif e == 'dg':
            e = 3
        elif e == 'sp':
            e = 4
        elif e == 'fr':
            e = 5
            
        id_emo.append(e)
    return id_emo
emotion = toClasses(emotion)
print(emotion[0]," ",sentences[0])
# Out:
# 0   This was the best summer I have ever experienced.

# %%
import matplotlib.pyplot as plt
import collections
# %matplotlib inline
def histograma(emotion):
    #print(emotion)
    plt.hist(emotion, 50)
    plt.xlabel('Emotion')
    plt.ylabel('Frequency')
    plt.axis([0, 7, 0, 600])
    plt.show()
histograma(emotion)

# %% [markdown]
# Preprocesing of Sentences

# %%
def decontracted(phrase):
    # specific
    '''phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)'''

    if phrase == "t":
        phrase = "not"
    elif phrase == "re":
        phrase = "are"
    elif phrase == "s":
        phrase = "is"
    elif phrase == "d":
        phrase = "would"
    elif phrase == "ve":
        phrase = "have"
    elif phrase == "m":
        phrase = "am"
    elif phrase == "ca":
        phrase = "can"
    elif phrase == "isn":
        phrase = "is"
    elif phrase == "aren":
        phrase = "are"
    elif phrase == "wouldn":
        phrase = "would"

    # general
    '''phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)'''
    return phrase

# %%
#----------------Cleanning Sentences--------------
def cleaner(sent):
    for s in range(0,len(sent)):
        print(sent[s])
        sent[s] = sent[s].lower()
        sent[s] = WordPunctTokenizer().tokenize(sent[s])#nltk.word_tokenize(sent[s])
        #print(sent[s])
        for word in range(0,len(sent[s])):
            sent[s][word] = decontracted(sent[s][word])
            sent[s][word] = re.sub(r'[^a-zA-Z0-9\s]', ' ', sent[s][word])
            sent[s][word] = sent[s][word].strip()
            
        sent[s] = list(filter(None, sent[s])) # fastest
        print(sent[s])
        print("-----------")
    return sent

c_sent = sentences[:]    
c_sent = cleaner(c_sent)
print(c_sent[0])
# Out:
# This was the best summer I have ever experienced.
#
# ['this', 'was', 'the', 'best', 'summer', 'i', 'have', 'ever', 'experienced']
# -----------
# I hate fucking pills.
#
# ['i', 'hate', 'fucking', 'pills']
# -----------
# I had a blast in california hanging out with my family and friends.
#
# ['i', 'had', 'a', 'blast', 'in', 'california', 'hanging', 'out', 'with', 'my', 'family', 'and', 'friends']
# -----------
# Thank you to everyone who made me feel at home.
#
# ['thank', 'you', 'to', 'everyone', 'who', 'made', 'me', 'feel', 'at', 'home']
# -----------
# :) I love ya :)
#
# ['i', 'love', 'ya']
# -----------
# My best friend, her grandma doris and my sister friend planned a surprise baby shower for me and hailey on saturday.
#
# ['my', 'best', 'friend', 'her', 'grandma', 'doris', 'and', 'my', 'sister', 'friend', 'planned', 'a', 'surprise', 'baby', 'shower', 'for', 'me', 'and', 'hailey', 'on', 'saturday']
# -----------
# Thank you so much for everyone who came.
#
# ['thank', 'you', 'so', 'much', 'for', 'everyone', 'who', 'came']
# -----------
# :) Hailey recieved many gift cards (because I couldn't bring that much on the plane back home) and cute baby clothes and toys!!
#
# ['hailey', 'recieved', 'many', 'gift', 'cards', 'because', 'i', 'couldn', 'not', 'bring', 'that', 'much', 'on', 'the', 'plane', 'back', 'home', 'and', 'cute', 'baby', 'clothes', 'and', 'toys']
# -----------
# Thank you everyone!
#
# ['thank', 'you', 'everyone']
# -----------
# We had a wonderful yummy cake, fruit and veggie treats.
#
# ['we', 'had', 'a', 'wonderful', 'yummy', 'cake', 'fruit', 'and', 'veggie', 'treats']
# -----------
# My friend Misty brought her cute new baby girl, Jamie!!
#
# ['my', 'friend', 'misty', 'brought', 'her', 'cute', 'new', 'baby', 'girl', 'jamie']
# -----------
# She is so adorable!!
#
# ['she', 'is', 'so', 'adorable']
# -----------
# We played fun baby games and caught up on some old times.
#
# ['we', 'played', 'fun', 'baby', 'games', 'and', 'caught', 'up', 'on', 'some', 'old', 'times']
# -----------
# I had a blast thank you friend!!!!
#
# ['i', 'had', 'a', 'blast', 'thank', 'you', 'friend']
# -----------
# Thank you guys.
#
# ['thank', 'you', 'guys']
# -----------
# I miss you so much and can't wait to see Ginny, Sister friend and my mom in a couple months!!!
#
# ['i', 'miss', 'you', 'so', 'much', 'and', 'can', 'not', 'wait', 'to', 'see', 'ginny', 'sister', 'friend', 'and', 'my', 'mom', 'in', 'a', 'couple', 'months']
# -----------
# Love you
#
# ['love', 'you']
# -----------
# So many lies about who you're talking to, where you're going, what you're doing.
#
# ['so', 'many', 'lies', 'about', 'who', 'you', 'are', 'talking', 'to', 'where', 'you', 'are', 'going', 'what', 'you', 'are', 'doing']
# -----------
# The people that just have to send a "hug" and it puts a smile on your face.
#
# ['the', 'people', 'that', 'just', 'have', 'to', 'send', 'a', 'hug', 'and', 'it', 'puts', 'a', 'smile', 'on', 'your', 'face']
# -----------
# They are amazing.
#
# ['they', 'are', 'amazing']
# -----------
# and I love them.
#
# ['and', 'i', 'love', 'them']
# -----------
# My life is falling apart and I don't mean online.
#
# ['my', 'life', 'is', 'falling', 'apart', 'and', 'i', 'don', 'not', 'mean', 'online']
# -----------
# I'm becoming a broken toy and now that I have had twelve (I counted) vials of blood drawn, I just feel like I'm compltely useless.
#
# ['i', 'am', 'becoming', 'a', 'broken', 'toy', 'and', 'now', 'that', 'i', 'have', 'had', 'twelve', 'i', 'counted', 'vials', 'of', 'blood', 'drawn', 'i', 'just', 'feel', 'like', 'i', 'am', 'compltely', 'useless']
# -----------
# I started callin myself Aki-sama XD It's fun.
#
# ['i', 'started', 'callin', 'myself', 'aki', 'sama', 'xd', 'it', 'is', 'fun']
# -----------
# The Charlotte Observer featured this article about deep-fried Coke a few days ago, which is appaling enough by itself.
#
# ['the', 'charlotte', 'observer', 'featured', 'this', 'article', 'about', 'deep', 'fried', 'coke', 'a', 'few', 'days', 'ago', 'which', 'is', 'appaling', 'enough', 'by', 'itself']
# -----------
# (Speaking of deep-fried shit, did you know there was a town in Texas where they take a Snickers bar, wrap it in bacon, and then deep-fry it?)
#
# ['speaking', 'of', 'deep', 'fried', 'shit', 'did', 'you', 'know', 'there', 'was', 'a', 'town', 'in', 'texas', 'where', 'they', 'take', 'a', 'snickers', 'bar', 'wrap', 'it', 'in', 'bacon', 'and', 'then', 'deep', 'fry', 'it']
# -----------
# How awesome is this country?
#
# ['how', 'awesome', 'is', 'this', 'country']
# -----------
# Had a lovely birthday yesterday with Alex and Christine.
#
# ['had', 'a', 'lovely', 'birthday', 'yesterday', 'with', 'alex', 'and', 'christine']
# -----------
# Been seeing so many good friends and refilling my cell-phone contacts.
#
# ['been', 'seeing', 'so', 'many', 'good', 'friends', 'and', 'refilling', 'my', 'cell', 'phone', 'contacts']
# -----------
# Visiting Bard was like a warm blanket.
#
# ['visiting', 'bard', 'was', 'like', 'a', 'warm', 'blanket']
# -----------
# Earlham is also making me feel more happy than I feel at home.
#
# ['earlham', 'is', 'also', 'making', 'me', 'feel', 'more', 'happy', 'than', 'i', 'feel', 'at', 'home']
# -----------
# Oh and also, I'm listening to an audio book of "The Time-Traveler's Wife" and loving it.
#
# ['oh', 'and', 'also', 'i', 'am', 'listening', 'to', 'an', 'audio', 'book', 'of', 'the', 'time', 'traveler', 'is', 'wife', 'and', 'loving', 'it']
# -----------
# Octoberfest was awesome.
#
# ['octoberfest', 'was', 'awesome']
# -----------
# I also got a ton of compliments including from a couple of strippers that weren't even mine.
#
# ['i', 'also', 'got', 'a', 'ton', 'of', 'compliments', 'including', 'from', 'a', 'couple', 'of', 'strippers', 'that', 'weren', 'not', 'even', 'mine']
# -----------
# What a ridiculously awesome time I had yesterday.
#
# ['what', 'a', 'ridiculously', 'awesome', 'time', 'i', 'had', 'yesterday']
# -----------
# It must have been all your good lucks and have funs that did it.
#
# ['it', 'must', 'have', 'been', 'all', 'your', 'good', 'lucks', 'and', 'have', 'funs', 'that', 'did', 'it']
# -----------
# Really starting to lose it.
#
# ['really', 'starting', 'to', 'lose', 'it']
# -----------
# Sadness Dept: Just heard on NPR that Gillo Pontecorvo died.
#
# ['sadness', 'dept', 'just', 'heard', 'on', 'npr', 'that', 'gillo', 'pontecorvo', 'died']
# -----------
# (I screened it at VSU in '04 for my faculty advisors and they seemed fairly stunned by it.
#
# ['i', 'screened', 'it', 'at', 'vsu', 'in', '04', 'for', 'my', 'faculty', 'advisors', 'and', 'they', 'seemed', 'fairly', 'stunned', 'by', 'it']
# -----------
# Strange.)
#
# ['strange']
# -----------
# Ogro is a Franco-era policier and all the more grim for its muted tone and washed-out palette.
#
# ['ogro', 'is', 'a', 'franco', 'era', 'policier', 'and', 'all', 'the', 'more', 'grim', 'for', 'its', 'muted', 'tone', 'and', 'washed', 'out', 'palette']
# -----------
# "The most wonderful gift that dad got this birthday was the love ofamitabh-abhishek09.jpg his fans that he gets every year.
#
# ['the', 'most', 'wonderful', 'gift', 'that', 'dad', 'got', 'this', 'birthday', 'was', 'the', 'love', 'ofamitabh', 'abhishek09', 'jpg', 'his', 'fans', 'that', 'he', 'gets', 'every', 'year']
# -----------
# "What a fabulous gift for dad on his birthday!
#
# ['what', 'a', 'fabulous', 'gift', 'for', 'dad', 'on', 'his', 'birthday']
# -----------
# Its fantastic.
#
# ['its', 'fantastic']
# -----------
# Well, great.
#
# ['well', 'great']
# -----------
# We as a family are truly honoured.
#
# ['we', 'as', 'a', 'family', 'are', 'truly', 'honoured']
# -----------
# Its a matter of pride for every Indian when a recognition like this comes to dad from a cinema-savvy country like France."
#
# ['its', 'a', 'matter', 'of', 'pride', 'for', 'every', 'indian', 'when', 'a', 'recognition', 'like', 'this', 'comes', 'to', 'dad', 'from', 'a', 'cinema', 'savvy', 'country', 'like', 'france']
# -----------
# "I think its a wonderful idea to remake Sholay.
#
# ['i', 'think', 'its', 'a', 'wonderful', 'idea', 'to', 'remake', 'sholay']
# -----------
# All I can say is, knowing Ramus abilities from close quarters Im pretty sure even Ramesh uncle will be very proud of the film Ramu makes."
#
# ['all', 'i', 'can', 'say', 'is', 'knowing', 'ramus', 'abilities', 'from', 'close', 'quarters', 'im', 'pretty', 'sure', 'even', 'ramesh', 'uncle', 'will', 'be', 'very', 'proud', 'of', 'the', 'film', 'ramu', 'makes']
# -----------
# The show is coming together awesome.
#
# ['the', 'show', 'is', 'coming', 'together', 'awesome']
# -----------
# But the rest of it came across as a really angry, drunken rant.
#
# ['but', 'the', 'rest', 'of', 'it', 'came', 'across', 'as', 'a', 'really', 'angry', 'drunken', 'rant']
# -----------
# If anyone wants to give me a call I'd be more than happy to answer it.
#
# ['if', 'anyone', 'wants', 'to', 'give', 'me', 'a', 'call', 'i', 'would', 'be', 'more', 'than', 'happy', 'to', 'answer', 'it']
# -----------
# lol.
#
# ['lol']
# -----------
# My howland friend Alyssa came with me and we danced the night away.Most of my friends went which was awesome.
#
# ['my', 'howland', 'friend', 'alyssa', 'came', 'with', 'me', 'and', 'we', 'danced', 'the', 'night', 'away', 'most', 'of', 'my', 'friends', 'went', 'which', 'was', 'awesome']
# -----------
# there was only a few of us single people there but it was cool.
#
# ['there', 'was', 'only', 'a', 'few', 'of', 'us', 'single', 'people', 'there', 'but', 'it', 'was', 'cool']
# -----------
# which is one of the slow songs i got to dance with one of my friends Nick who graduated Mathews last year.Hes awesome we danced alot together!Luvs!
#
# ['which', 'is', 'one', 'of', 'the', 'slow', 'songs', 'i', 'got', 'to', 'dance', 'with', 'one', 'of', 'my', 'friends', 'nick', 'who', 'graduated', 'mathews', 'last', 'year', 'hes', 'awesome', 'we', 'danced', 'alot', 'together', 'luvs']
# -----------
# the dance was awsome.The music was really cool.
#
# ['the', 'dance', 'was', 'awsome', 'the', 'music', 'was', 'really', 'cool']
# -----------
# too much rap and not enough rock for my taste but it was all good I was just happy getting out on the dance floor and getting my groove on.lol.
#
# ['too', 'much', 'rap', 'and', 'not', 'enough', 'rock', 'for', 'my', 'taste', 'but', 'it', 'was', 'all', 'good', 'i', 'was', 'just', 'happy', 'getting', 'out', 'on', 'the', 'dance', 'floor', 'and', 'getting', 'my', 'groove', 'on', 'lol']
# -----------
# I also got to see some howland people i once knew (Drew was one) That was pretty cool!
#
# ['i', 'also', 'got', 'to', 'see', 'some', 'howland', 'people', 'i', 'once', 'knew', 'drew', 'was', 'one', 'that', 'was', 'pretty', 'cool']
# -----------
# haha We did the Cha Cha slide and we were all so close together.
#
# ['haha', 'we', 'did', 'the', 'cha', 'cha', 'slide', 'and', 'we', 'were', 'all', 'so', 'close', 'together']
# -----------
# I just loved last night!!
#
# ['i', 'just', 'loved', 'last', 'night']
# -----------
# Ha!
#
# ['ha']
# -----------
# then Lyssa,me,matt,and Kayla couldn't find someplace good to eat that was open 1 in the morning so we all went in to giant eagle and bought junk food haha.
#
# ['then', 'lyssa', 'me', 'matt', 'and', 'kayla', 'couldn', 'not', 'find', 'someplace', 'good', 'to', 'eat', 'that', 'was', 'open', '1', 'in', 'the', 'morning', 'so', 'we', 'all', 'went', 'in', 'to', 'giant', 'eagle', 'and', 'bought', 'junk', 'food', 'haha']
# -----------
# it was amusing.hehehe.But yea overall I haven't had that much fun in a very long time!!
#
# ['it', 'was', 'amusing', 'hehehe', 'but', 'yea', 'overall', 'i', 'haven', 'not', 'had', 'that', 'much', 'fun', 'in', 'a', 'very', 'long', 'time']
# -----------
# im done telling you about my wonderful night lol.
#
# ['im', 'done', 'telling', 'you', 'about', 'my', 'wonderful', 'night', 'lol']
# -----------
# I can't believe she is FINALLY here!!!
#
# ['i', 'can', 'not', 'believe', 'she', 'is', 'finally', 'here']
# -----------
# :) Levi is really exciting to be a big brother, he thinks she is sooooo cool.
#
# ['levi', 'is', 'really', 'exciting', 'to', 'be', 'a', 'big', 'brother', 'he', 'thinks', 'she', 'is', 'sooooo', 'cool']
# -----------
# My life on the weekdays is tae kwon do its what i was born to do i love i there i love to teach people who want to be taught.
#
# ['my', 'life', 'on', 'the', 'weekdays', 'is', 'tae', 'kwon', 'do', 'its', 'what', 'i', 'was', 'born', 'to', 'do', 'i', 'love', 'i', 'there', 'i', 'love', 'to', 'teach', 'people', 'who', 'want', 'to', 'be', 'taught']
# -----------
# Everyone there is amazing its like my second home.
#
# ['everyone', 'there', 'is', 'amazing', 'its', 'like', 'my', 'second', 'home']
# -----------
# luckily we won that one.
#
# ['luckily', 'we', 'won', 'that', 'one']
# -----------
# it was pretty good.
#
# ['it', 'was', 'pretty', 'good']
# -----------
# overall it was a pretty good tournament.
#
# ['overall', 'it', 'was', 'a', 'pretty', 'good', 'tournament']
# -----------
# i'm always happy with those.
#
# ['i', 'am', 'always', 'happy', 'with', 'those']
# -----------
# had a good chill time with team at dever's house.
#
# ['had', 'a', 'good', 'chill', 'time', 'with', 'team', 'at', 'dever', 'is', 'house']
# -----------
# hehe
#
# ['hehe']
# -----------
# however i do miss volleyball.
#
# ['however', 'i', 'do', 'miss', 'volleyball']
# -----------
# I woke up once during the dream and was like, "oh crap, no, go back" and managed to get back to it somehow.
#
# ['i', 'woke', 'up', 'once', 'during', 'the', 'dream', 'and', 'was', 'like', 'oh', 'crap', 'no', 'go', 'back', 'and', 'managed', 'to', 'get', 'back', 'to', 'it', 'somehow']
# -----------
# So in the dream there were times where we were both kinda unsure, but it was still happy (for the both of us I hope).
#
# ['so', 'in', 'the', 'dream', 'there', 'were', 'times', 'where', 'we', 'were', 'both', 'kinda', 'unsure', 'but', 'it', 'was', 'still', 'happy', 'for', 'the', 'both', 'of', 'us', 'i', 'hope']
# -----------
# That's odd though, as I don't usually care for dressy occassions.
#
# ['that', 'is', 'odd', 'though', 'as', 'i', 'don', 'not', 'usually', 'care', 'for', 'dressy', 'occassions']
# -----------
# WTF)
#
# ['wtf']
# -----------
# i'm finally reading the amazing adventures of kavalier &amp; clay.
#
# ['i', 'am', 'finally', 'reading', 'the', 'amazing', 'adventures', 'of', 'kavalier', 'amp', 'clay']
# -----------
# i'm not very far along but i'm quite enjoying it.
#
# ['i', 'am', 'not', 'very', 'far', 'along', 'but', 'i', 'am', 'quite', 'enjoying', 'it']
# -----------
# I'm in Buena Vista at these hot springs and it should be awesome but I didn't sleep one little bit last night.
#
# ['i', 'am', 'in', 'buena', 'vista', 'at', 'these', 'hot', 'springs', 'and', 'it', 'should', 'be', 'awesome', 'but', 'i', 'didn', 'not', 'sleep', 'one', 'little', 'bit', 'last', 'night']
# -----------
# I think the pain and awkwardness of attending your reception is worth seeing your face again.
#
# ['i', 'think', 'the', 'pain', 'and', 'awkwardness', 'of', 'attending', 'your', 'reception', 'is', 'worth', 'seeing', 'your', 'face', 'again']
# -----------
# I miss you so much.
#
# ['i', 'miss', 'you', 'so', 'much']
# -----------
# I've never missed anyone so much as you.
#
# ['i', 'have', 'never', 'missed', 'anyone', 'so', 'much', 'as', 'you']
# -----------
# I'm sitting here in this lobby thing and crying and it's very embarassing but I can't help it because I just want you and me to run away and I want you to hold me for one whole night and rock me to sleep.
#
# ['i', 'am', 'sitting', 'here', 'in', 'this', 'lobby', 'thing', 'and', 'crying', 'and', 'it', 'is', 'very', 'embarassing', 'but', 'i', 'can', 'not', 'help', 'it', 'because', 'i', 'just', 'want', 'you', 'and', 'me', 'to', 'run', 'away', 'and', 'i', 'want', 'you', 'to', 'hold', 'me', 'for', 'one', 'whole', 'night', 'and', 'rock', 'me', 'to', 'sleep']
# -----------
# I miss you.
#
# ['i', 'miss', 'you']
# -----------
# Well Im finishing up my first week at Jubans, its really awesome.
#
# ['well', 'im', 'finishing', 'up', 'my', 'first', 'week', 'at', 'jubans', 'its', 'really', 'awesome']
# -----------
# We get drinks after work too and the food I can eat is awesome.
#
# ['we', 'get', 'drinks', 'after', 'work', 'too', 'and', 'the', 'food', 'i', 'can', 'eat', 'is', 'awesome']
# -----------
# messed up a Quiz in Biology which sucks.
#
# ['messed', 'up', 'a', 'quiz', 'in', 'biology', 'which', 'sucks']
# -----------
# Oh well its nothing too too bad but its making me nervous.
#
# ['oh', 'well', 'its', 'nothing', 'too', 'too', 'bad', 'but', 'its', 'making', 'me', 'nervous']
# -----------
# Truly horrifying footage of a Disney character orgy backstage at one of their shows."
#
# ['truly', 'horrifying', 'footage', 'of', 'a', 'disney', 'character', 'orgy', 'backstage', 'at', 'one', 'of', 'their', 'shows']
# -----------
# Well, not so much an orgy, but really rather amusing!
#
# ['well', 'not', 'so', 'much', 'an', 'orgy', 'but', 'really', 'rather', 'amusing']
# -----------
# I just stood there in shock!
#
# ['i', 'just', 'stood', 'there', 'in', 'shock']
# -----------
# Another slight parallel I find amusing: Jason played Heracles in Alcestes last year, just as I am playing Hippolyta in A Midsummer Night's Dream.
#
# ['another', 'slight', 'parallel', 'i', 'find', 'amusing', 'jason', 'played', 'heracles', 'in', 'alcestes', 'last', 'year', 'just', 'as', 'i', 'am', 'playing', 'hippolyta', 'in', 'a', 'midsummer', 'night', 'is', 'dream']
# -----------
# Sock n' Buskin is a really fun theatre company, I'm liking my occasional rehersal.
#
# ['sock', 'n', 'buskin', 'is', 'a', 'really', 'fun', 'theatre', 'company', 'i', 'am', 'liking', 'my', 'occasional', 'rehersal']
# -----------
# This awesome program
#
# ['this', 'awesome', 'program']
# -----------
# I've been talking to Laura on the phone almost daily, and we're both very excited to see that little baby growing inside of her!
#
# ['i', 'have', 'been', 'talking', 'to', 'laura', 'on', 'the', 'phone', 'almost', 'daily', 'and', 'we', 'are', 'both', 'very', 'excited', 'to', 'see', 'that', 'little', 'baby', 'growing', 'inside', 'of', 'her']
# -----------
# That would be so awesome!
#
# ['that', 'would', 'be', 'so', 'awesome']
# -----------
# Snow in October!
#
# ['snow', 'in', 'october']
# -----------
# I haven't even seen snow in years and to have it in October it too much to wrap around my little head!
#
# ['i', 'haven', 'not', 'even', 'seen', 'snow', 'in', 'years', 'and', 'to', 'have', 'it', 'in', 'october', 'it', 'too', 'much', 'to', 'wrap', 'around', 'my', 'little', 'head']
# -----------
# I'm missing everyone in Wisconsin with the Blue Stars, and sad that I had to leave early.
#
# ['i', 'am', 'missing', 'everyone', 'in', 'wisconsin', 'with', 'the', 'blue', 'stars', 'and', 'sad', 'that', 'i', 'had', 'to', 'leave', 'early']
# -----------
# Miss you guys!
#
# ['miss', 'you', 'guys']
# -----------
# And sadly.
#
# ['and', 'sadly']
# -----------
# It was too much weight for me to carry, my own plus everyone elses.
#
# ['it', 'was', 'too', 'much', 'weight', 'for', 'me', 'to', 'carry', 'my', 'own', 'plus', 'everyone', 'elses']
# -----------
# I get a jolt of something REAL loud and it makes me jump.
#
# ['i', 'get', 'a', 'jolt', 'of', 'something', 'real', 'loud', 'and', 'it', 'makes', 'me', 'jump']
# -----------
# She is afraid to.
#
# ['she', 'is', 'afraid', 'to']
# -----------
# I hope that he can learn to play well and I really do hope he is enjoying himself.
#
# ['i', 'hope', 'that', 'he', 'can', 'learn', 'to', 'play', 'well', 'and', 'i', 'really', 'do', 'hope', 'he', 'is', 'enjoying', 'himself']
# -----------
# No matter the pain is may cause the rest of the family.
#
# ['no', 'matter', 'the', 'pain', 'is', 'may', 'cause', 'the', 'rest', 'of', 'the', 'family']
# -----------
# As long as he is happy.
#
# ['as', 'long', 'as', 'he', 'is', 'happy']
# -----------
# Vegas was a lot of fun.
#
# ['vegas', 'was', 'a', 'lot', 'of', 'fun']
# -----------
# The reception was a friggin  blast!
#
# ['the', 'reception', 'was', 'a', 'friggin', 'blast']
# -----------
# Champagne, music, and me trying to catch those damn flowers.
#
# ['champagne', 'music', 'and', 'me', 'trying', 'to', 'catch', 'those', 'damn', 'flowers']
# -----------
# (didn't catch em by the by) Imagine this: My bro taking his neck tie off of marie's thigh with his teeth while "girls just wanna have fun" blasts in the background!
#
# ['didn', 'not', 'catch', 'em', 'by', 'the', 'by', 'imagine', 'this', 'my', 'bro', 'taking', 'his', 'neck', 'tie', 'off', 'of', 'marie', 'is', 'thigh', 'with', 'his', 'teeth', 'while', 'girls', 'just', 'wanna', 'have', 'fun', 'blasts', 'in', 'the', 'background']
# -----------
# add some jack and cokes and a wendy's drive through and it's a REAL party!!
#
# ['add', 'some', 'jack', 'and', 'cokes', 'and', 'a', 'wendy', 'is', 'drive', 'through', 'and', 'it', 'is', 'a', 'real', 'party']
# -----------
# As Sean put it, it's not like Vietnam where 4 of 5 americans will die, so that really put it into perspective for me
# ['as', 'sean', 'put', 'it', 'it', 'is', 'not', 'like', 'vietnam', 'where', '4', 'of', '5', 'americans', 'will', 'die', 'so', 'that', 'really', 'put', 'it', 'into', 'perspective', 'for', 'me']
# -----------
# Everybody hates everybody, everybody lies, talks shit behind backs, and treats people like shit.
#
# ['everybody', 'hates', 'everybody', 'everybody', 'lies', 'talks', 'shit', 'behind', 'backs', 'and', 'treats', 'people', 'like', 'shit']
# -----------
# My mother truly wants to murder my father, and then gets pissed off when i don't agree with her.
#
# ['my', 'mother', 'truly', 'wants', 'to', 'murder', 'my', 'father', 'and', 'then', 'gets', 'pissed', 'off', 'when', 'i', 'don', 'not', 'agree', 'with', 'her']
# -----------
# UGH!
#
# ['ugh']
# -----------
# ya, i'd say that's some fucked up shit.
#
# ['ya', 'i', 'would', 'say', 'that', 'is', 'some', 'fucked', 'up', 'shit']
# -----------
# =) It was the perfect end to a crappy day.
#
# ['it', 'was', 'the', 'perfect', 'end', 'to', 'a', 'crappy', 'day']
# -----------
# Basically, I just want to focus on staying busy and staying happy.
#
# ['basically', 'i', 'just', 'want', 'to', 'focus', 'on', 'staying', 'busy', 'and', 'staying', 'happy']
# -----------
# So, if you would like to contribute to the "make me smile" foundation", let's party!
#
# ['so', 'if', 'you', 'would', 'like', 'to', 'contribute', 'to', 'the', 'make', 'me', 'smile', 'foundation', 'let', 'is', 'party']
# -----------
# that was sooo fun.
#
# ['that', 'was', 'sooo', 'fun']
# -----------
# lol.
#
# ['lol']
# -----------
# hehehehhe ;) neeeways.
#
# ['hehehehhe', 'neeeways']
# -----------
# WE WERE TOTALLY AWESOME!!!!
#
# ['we', 'were', 'totally', 'awesome']
# -----------
# lol.
#
# ['lol']
# -----------
# We won by several of points.
#
# ['we', 'won', 'by', 'several', 'of', 'points']
# -----------
# yay!!!!
#
# ['yay']
# -----------
# lol.
#
# ['lol']
# -----------
# after the game we went to the dance where I had the best night of my life!!!
#
# ['after', 'the', 'game', 'we', 'went', 'to', 'the', 'dance', 'where', 'i', 'had', 'the', 'best', 'night', 'of', 'my', 'life']
# -----------
# was so awesome.
#
# ['was', 'so', 'awesome']
# -----------
# I cant even explain in words how much fun I had.
#
# ['i', 'cant', 'even', 'explain', 'in', 'words', 'how', 'much', 'fun', 'i', 'had']
# -----------
# ;) hehehehe.
#
# ['hehehehe']
# -----------
# I can honestly say that was the best homecoming ever!!!!
#
# ['i', 'can', 'honestly', 'say', 'that', 'was', 'the', 'best', 'homecoming', 'ever']
# -----------
# Its soooo sad b/c it was my last one.
#
# ['its', 'soooo', 'sad', 'b', 'c', 'it', 'was', 'my', 'last', 'one']
# -----------
# :( at least I had a blast!!!!
#
# ['at', 'least', 'i', 'had', 'a', 'blast']
# -----------
# lol.
#
# ['lol']
# -----------
# I dont know what else to say except that I love spending time w/ Joe.
#
# ['i', 'dont', 'know', 'what', 'else', 'to', 'say', 'except', 'that', 'i', 'love', 'spending', 'time', 'w', 'joe']
# -----------
# :) *sighs* lol.
#
# ['sighs', 'lol']
# -----------
# And hanging out w/ Celeste and Matt was totally awesome 2!!!
#
# ['and', 'hanging', 'out', 'w', 'celeste', 'and', 'matt', 'was', 'totally', 'awesome', '2']
# -----------
# Love u all!!
#
# ['love', 'u', 'all']
# -----------
# Exciting, no?
#
# ['exciting', 'no']
# -----------
# We had a great time catching up, and went out that night together as well.
#
# ['we', 'had', 'a', 'great', 'time', 'catching', 'up', 'and', 'went', 'out', 'that', 'night', 'together', 'as', 'well']
# -----------
# But it's certainly strange how you randomly run in to people you haven't seen in years, in little hole-in-the-walls in Europe.
#
# ['but', 'it', 'is', 'certainly', 'strange', 'how', 'you', 'randomly', 'run', 'in', 'to', 'people', 'you', 'haven', 'not', 'seen', 'in', 'years', 'in', 'little', 'hole', 'in', 'the', 'walls', 'in', 'europe']
# -----------
# Fun times.
#
# ['fun', 'times']
# -----------
# And this particular piece was by far the best play I have EVER seen.
#
# ['and', 'this', 'particular', 'piece', 'was', 'by', 'far', 'the', 'best', 'play', 'i', 'have', 'ever', 'seen']
# -----------
# It was also incredibly simple, cutting the normally huge cast down to only seven performers.
#
# ['it', 'was', 'also', 'incredibly', 'simple', 'cutting', 'the', 'normally', 'huge', 'cast', 'down', 'to', 'only', 'seven', 'performers']
# -----------
# I was lucky enough to be able to stay with some friends to cut down on the cost, and see a different side of London life.
#
# ['i', 'was', 'lucky', 'enough', 'to', 'be', 'able', 'to', 'stay', 'with', 'some', 'friends', 'to', 'cut', 'down', 'on', 'the', 'cost', 'and', 'see', 'a', 'different', 'side', 'of', 'london', 'life']
# -----------
# It was sooooo much fun!
#
# ['it', 'was', 'sooooo', 'much', 'fun']
# -----------
# The show was trash.
#
# ['the', 'show', 'was', 'trash']
# -----------
# Horrible.
#
# ['horrible']
# -----------
# Horribly acted, horribly directed, weak script.
#
# ['horribly', 'acted', 'horribly', 'directed', 'weak', 'script']
# -----------
# And interminably long!
#
# ['and', 'interminably', 'long']
# -----------
# Three hours of horror.
#
# ['three', 'hours', 'of', 'horror']
# -----------
# I wanted to leave at intermission, but my date was really enjoying it (should have been a sign) so we stayed.
#
# ['i', 'wanted', 'to', 'leave', 'at', 'intermission', 'but', 'my', 'date', 'was', 'really', 'enjoying', 'it', 'should', 'have', 'been', 'a', 'sign', 'so', 'we', 'stayed']
# -----------
# I guess the one good thing I took from it was that I know now that the British are just as capable as we are of producing really awful work.
#
# ['i', 'guess', 'the', 'one', 'good', 'thing', 'i', 'took', 'from', 'it', 'was', 'that', 'i', 'know', 'now', 'that', 'the', 'british', 'are', 'just', 'as', 'capable', 'as', 'we', 'are', 'of', 'producing', 'really', 'awful', 'work']
# -----------
# Now this was amazing.
#
# ['now', 'this', 'was', 'amazing']
# -----------
# The performers were incredible, and one of the generals was played by Geoffrey, the butler from Fresh Prince of Bellaire.
#
# ['the', 'performers', 'were', 'incredible', 'and', 'one', 'of', 'the', 'generals', 'was', 'played', 'by', 'geoffrey', 'the', 'butler', 'from', 'fresh', 'prince', 'of', 'bellaire']
# -----------
# That in itself was hilarious, and made us love the show even more.
#
# ['that', 'in', 'itself', 'was', 'hilarious', 'and', 'made', 'us', 'love', 'the', 'show', 'even', 'more']
# -----------
# I also saw Les Miserables for the first time, and it was fun.
#
# ['i', 'also', 'saw', 'les', 'miserables', 'for', 'the', 'first', 'time', 'and', 'it', 'was', 'fun']
# -----------
# Loved London.
#
# ['loved', 'london']
# -----------
# Loved the free museums.
#
# ['loved', 'the', 'free', 'museums']
# -----------
# And the funniest part, the two statues said they were donated by New Zealand.
#
# ['and', 'the', 'funniest', 'part', 'the', 'two', 'statues', 'said', 'they', 'were', 'donated', 'by', 'new', 'zealand']
# -----------
# Curious.
#
# ['curious']
# -----------
# The hordes of people would change from day to day, for instance there was a three day period where we had over 90,000 Swedes in the city, leading up to their dramatic defeat at the hands of Zeh Germans.
#
# ['the', 'hordes', 'of', 'people', 'would', 'change', 'from', 'day', 'to', 'day', 'for', 'instance', 'there', 'was', 'a', 'three', 'day', 'period', 'where', 'we', 'had', 'over', '90', '000', 'swedes', 'in', 'the', 'city', 'leading', 'up', 'to', 'their', 'dramatic', 'defeat', 'at', 'the', 'hands', 'of', 'zeh', 'germans']
# -----------
# Then there were the Brazilians, everywhere, singing-clapping-dancing-taking pictures, and of course the pale and pasty Brits with their cock-eyed stares and drinking songs.
#
# ['then', 'there', 'were', 'the', 'brazilians', 'everywhere', 'singing', 'clapping', 'dancing', 'taking', 'pictures', 'and', 'of', 'course', 'the', 'pale', 'and', 'pasty', 'brits', 'with', 'their', 'cock', 'eyed', 'stares', 'and', 'drinking', 'songs']
# -----------
# Loads of fun.
#
# ['loads', 'of', 'fun']
# -----------
# So to a French cafe for the France-Swiss game, a Tapas bar when Spain played, drank Caiprinhas with the passionate Brazilians, etc
# ['so', 'to', 'a', 'french', 'cafe', 'for', 'the', 'france', 'swiss', 'game', 'a', 'tapas', 'bar', 'when', 'spain', 'played', 'drank', 'caiprinhas', 'with', 'the', 'passionate', 'brazilians', 'etc']
# -----------
# Another interesting element was the latent patriotism that emerged during the Cup.
#
# ['another', 'interesting', 'element', 'was', 'the', 'latent', 'patriotism', 'that', 'emerged', 'during', 'the', 'cup']
# -----------
# And for what it's worth I agree with them, it makes me nervous too.
#
# ['and', 'for', 'what', 'it', 'is', 'worth', 'i', 'agree', 'with', 'them', 'it', 'makes', 'me', 'nervous', 'too']
# -----------
# People were genuinely excited about supporting their national team, and taking pride in its accomplishments.
#
# ['people', 'were', 'genuinely', 'excited', 'about', 'supporting', 'their', 'national', 'team', 'and', 'taking', 'pride', 'in', 'its', 'accomplishments']
# -----------
# Now this newfound enthusiasm certainly was not shared by everyone.
#
# ['now', 'this', 'newfound', 'enthusiasm', 'certainly', 'was', 'not', 'shared', 'by', 'everyone']
# -----------
# After a July of beautiful weather and great summer adventures, I traveled with my good Australian friend Kurt to a theater festival in Cyprus.
#
# ['after', 'a', 'july', 'of', 'beautiful', 'weather', 'and', 'great', 'summer', 'adventures', 'i', 'traveled', 'with', 'my', 'good', 'australian', 'friend', 'kurt', 'to', 'a', 'theater', 'festival', 'in', 'cyprus']
# -----------
# Now this was ridiculous amounts of fun!
#
# ['now', 'this', 'was', 'ridiculous', 'amounts', 'of', 'fun']
# -----------
# The city is a sweaty, dirty, polluted hole.
#
# ['the', 'city', 'is', 'a', 'sweaty', 'dirty', 'polluted', 'hole']
# -----------
# Now imagine the condensation from thousands of swamp box coolers pitter pattering on your head as you stroll down the trashy Athens streets.
#
# ['now', 'imagine', 'the', 'condensation', 'from', 'thousands', 'of', 'swamp', 'box', 'coolers', 'pitter', 'pattering', 'on', 'your', 'head', 'as', 'you', 'stroll', 'down', 'the', 'trashy', 'athens', 'streets']
# -----------
# And the city itself really is lovely, in it's own way.
#
# ['and', 'the', 'city', 'itself', 'really', 'is', 'lovely', 'in', 'it', 'is', 'own', 'way']
# -----------
# Now this was really amazing.
#
# ['now', 'this', 'was', 'really', 'amazing']
# -----------
# And then we watched in amazement with fifty other tourists as the sun went down in front of the temple, over the Mediterranean.
#
# ['and', 'then', 'we', 'watched', 'in', 'amazement', 'with', 'fifty', 'other', 'tourists', 'as', 'the', 'sun', 'went', 'down', 'in', 'front', 'of', 'the', 'temple', 'over', 'the', 'mediterranean']
# -----------
# The sky is so amazing in Greece, it feels like you could really reach up and touch it, it's so close!
#
# ['the', 'sky', 'is', 'so', 'amazing', 'in', 'greece', 'it', 'feels', 'like', 'you', 'could', 'really', 'reach', 'up', 'and', 'touch', 'it', 'it', 'is', 'so', 'close']
# -----------
# Cyprus was amazing.
#
# ['cyprus', 'was', 'amazing']
# -----------
# We saw Jessica's production of Medea, and were treated incredibly well by her colleagues at the festival.
#
# ['we', 'saw', 'jessica', 'is', 'production', 'of', 'medea', 'and', 'were', 'treated', 'incredibly', 'well', 'by', 'her', 'colleagues', 'at', 'the', 'festival']
# -----------
# We stayed in a tiny mountain village called Droushia, and these people brought hospitality to incredible new heights.
#
# ['we', 'stayed', 'in', 'a', 'tiny', 'mountain', 'village', 'called', 'droushia', 'and', 'these', 'people', 'brought', 'hospitality', 'to', 'incredible', 'new', 'heights']
# -----------
# They did everything they could to make us feel welcome, everything from putting us up in a beautiful hotel, refusing to let us pay for anything, and making sure that our stay on their island was as enchanting as the stories always make it out to be.
#
# ['they', 'did', 'everything', 'they', 'could', 'to', 'make', 'us', 'feel', 'welcome', 'everything', 'from', 'putting', 'us', 'up', 'in', 'a', 'beautiful', 'hotel', 'refusing', 'to', 'let', 'us', 'pay', 'for', 'anything', 'and', 'making', 'sure', 'that', 'our', 'stay', 'on', 'their', 'island', 'was', 'as', 'enchanting', 'as', 'the', 'stories', 'always', 'make', 'it', 'out', 'to', 'be']
# -----------
# Imagine the most incredible, horseshoe shaped cove, with unimaginably blue water, and a giant stone underneath the water, hundreds of meters long and wide, adding depth to the color.
#
# ['imagine', 'the', 'most', 'incredible', 'horseshoe', 'shaped', 'cove', 'with', 'unimaginably', 'blue', 'water', 'and', 'a', 'giant', 'stone', 'underneath', 'the', 'water', 'hundreds', 'of', 'meters', 'long', 'and', 'wide', 'adding', 'depth', 'to', 'the', 'color']
# -----------
# It was really interesting staying with them in this little mountain village, and getting to experience a bit of what their culture was all about.
#
# ['it', 'was', 'really', 'interesting', 'staying', 'with', 'them', 'in', 'this', 'little', 'mountain', 'village', 'and', 'getting', 'to', 'experience', 'a', 'bit', 'of', 'what', 'their', 'culture', 'was', 'all', 'about']
# -----------
# Oh and the food is incredible.
#
# ['oh', 'and', 'the', 'food', 'is', 'incredible']
# -----------
# Its really a testament to the vision of the ancients that in our world of skyscrapers and technical gadgetry, we are still fascinated by a two thousand year-old arrangement of stones.
#
# ['its', 'really', 'a', 'testament', 'to', 'the', 'vision', 'of', 'the', 'ancients', 'that', 'in', 'our', 'world', 'of', 'skyscrapers', 'and', 'technical', 'gadgetry', 'we', 'are', 'still', 'fascinated', 'by', 'a', 'two', 'thousand', 'year', 'old', 'arrangement', 'of', 'stones']
# -----------
# So I spent the next six days in a haze of working my final tours, partying, and showing Lance the city that I had come to love so much over the last two years.
#
# ['so', 'i', 'spent', 'the', 'next', 'six', 'days', 'in', 'a', 'haze', 'of', 'working', 'my', 'final', 'tours', 'partying', 'and', 'showing', 'lance', 'the', 'city', 'that', 'i', 'had', 'come', 'to', 'love', 'so', 'much', 'over', 'the', 'last', 'two', 'years']
# -----------
# We had a ball in Zurich.
#
# ['we', 'had', 'a', 'ball', 'in', 'zurich']
# -----------
# We went on a walking tour, went to the City Museum (located in an old castle, very cool), and had a good time relaxing and enjoying the AMAZING views.
#
# ['we', 'went', 'on', 'a', 'walking', 'tour', 'went', 'to', 'the', 'city', 'museum', 'located', 'in', 'an', 'old', 'castle', 'very', 'cool', 'and', 'had', 'a', 'good', 'time', 'relaxing', 'and', 'enjoying', 'the', 'amazing', 'views']
# -----------
# The city is incredibly beautiful, tucked into the Alps and right on the water.
#
# ['the', 'city', 'is', 'incredibly', 'beautiful', 'tucked', 'into', 'the', 'alps', 'and', 'right', 'on', 'the', 'water']
# -----------
# I think the most important thing I can say about this city, is that all of the rumors: That the city's dirty, the people are rude, the language barrier is insurmountable, the metro is incomprehensible, you things will be stolen, that they hate Americans.
#
# ['i', 'think', 'the', 'most', 'important', 'thing', 'i', 'can', 'say', 'about', 'this', 'city', 'is', 'that', 'all', 'of', 'the', 'rumors', 'that', 'the', 'city', 'is', 'dirty', 'the', 'people', 'are', 'rude', 'the', 'language', 'barrier', 'is', 'insurmountable', 'the', 'metro', 'is', 'incomprehensible', 'you', 'things', 'will', 'be', 'stolen', 'that', 'they', 'hate', 'americans']
# -----------
# The Eiffel Tower is breathtaking, and seeing it in person destroys its cliche and makes you fall in love with the thing.
#
# ['the', 'eiffel', 'tower', 'is', 'breathtaking', 'and', 'seeing', 'it', 'in', 'person', 'destroys', 'its', 'cliche', 'and', 'makes', 'you', 'fall', 'in', 'love', 'with', 'the', 'thing']
# -----------
# The people are absolutely LOVELY.
#
# ['the', 'people', 'are', 'absolutely', 'lovely']
# -----------
# We encountered so many genuinely wonderful, helpful, content people.
#
# ['we', 'encountered', 'so', 'many', 'genuinely', 'wonderful', 'helpful', 'content', 'people']
# -----------
# Everything from trying to order a baguette in the morning (my Francais is tres terrible) to asking directions or talking to cabbies, we were always pleasantly surprised at how open and welcoming they were.
#
# ['everything', 'from', 'trying', 'to', 'order', 'a', 'baguette', 'in', 'the', 'morning', 'my', 'francais', 'is', 'tres', 'terrible', 'to', 'asking', 'directions', 'or', 'talking', 'to', 'cabbies', 'we', 'were', 'always', 'pleasantly', 'surprised', 'at', 'how', 'open', 'and', 'welcoming', 'they', 'were']
# -----------
# And they all seem to really enjoy their city.
#
# ['and', 'they', 'all', 'seem', 'to', 'really', 'enjoy', 'their', 'city']
# -----------
# They know how beautiful it is, and they appreciate it.
#
# ['they', 'know', 'how', 'beautiful', 'it', 'is', 'and', 'they', 'appreciate', 'it']
# -----------
# And man, it is gorgeous.
#
# ['and', 'man', 'it', 'is', 'gorgeous']
# -----------
# There was a fabulous sense of community there.
#
# ['there', 'was', 'a', 'fabulous', 'sense', 'of', 'community', 'there']
# -----------
# My favorite part about the city parks were the 'nap chairs'.
#
# ['my', 'favorite', 'part', 'about', 'the', 'city', 'parks', 'were', 'the', 'nap', 'chairs']
# -----------
# I thought: "that's strange, what's that about?"
#
# ['i', 'thought', 'that', 'is', 'strange', 'what', 'is', 'that', 'about']
# -----------
# Vive la France!
#
# ['vive', 'la', 'france']
# -----------
# We really had a ball in Paris.
#
# ['we', 'really', 'had', 'a', 'ball', 'in', 'paris']
# -----------
# We went to Versailles, we went to Notre Dame, and on a fabulous bike tour.
#
# ['we', 'went', 'to', 'versailles', 'we', 'went', 'to', 'notre', 'dame', 'and', 'on', 'a', 'fabulous', 'bike', 'tour']
# -----------
# The most interesting thing we learned on the bike tour was that when the revolutionaries stormed the Bastille, there were only 7 prisoners left in it.
#
# ['the', 'most', 'interesting', 'thing', 'we', 'learned', 'on', 'the', 'bike', 'tour', 'was', 'that', 'when', 'the', 'revolutionaries', 'stormed', 'the', 'bastille', 'there', 'were', 'only', '7', 'prisoners', 'left', 'in', 'it']
# -----------
# It's a pretty breathtaking sight.
#
# ['it', 'is', 'a', 'pretty', 'breathtaking', 'sight']
# -----------
# On the steps there was always sort of an impromptu party with musicians and performers and other city-watchers gathering with a bottle of wine and a merry spirit.
#
# ['on', 'the', 'steps', 'there', 'was', 'always', 'sort', 'of', 'an', 'impromptu', 'party', 'with', 'musicians', 'and', 'performers', 'and', 'other', 'city', 'watchers', 'gathering', 'with', 'a', 'bottle', 'of', 'wine', 'and', 'a', 'merry', 'spirit']
# -----------
# Those evenings on the steps are some of my favorite memories from Paris.
#
# ['those', 'evenings', 'on', 'the', 'steps', 'are', 'some', 'of', 'my', 'favorite', 'memories', 'from', 'paris']
# -----------
# What an incredible end to an incredible journey.
#
# ['what', 'an', 'incredible', 'end', 'to', 'an', 'incredible', 'journey']
# -----------
# I was also lucky enough to be hired to direct a show for friendship high school, which went up last Sunday.
#
# ['i', 'was', 'also', 'lucky', 'enough', 'to', 'be', 'hired', 'to', 'direct', 'a', 'show', 'for', 'friendship', 'high', 'school', 'which', 'went', 'up', 'last', 'sunday']
# -----------
# It was a Commedia dell'Arte piece titled The Red Hat, and went extremely well.
#
# ['it', 'was', 'a', 'commedia', 'dell', 'arte', 'piece', 'titled', 'the', 'red', 'hat', 'and', 'went', 'extremely', 'well']
# -----------
# It was a nice way for me to get to stretch those theater muscles and earn a little something at the same time.
#
# ['it', 'was', 'a', 'nice', 'way', 'for', 'me', 'to', 'get', 'to', 'stretch', 'those', 'theater', 'muscles', 'and', 'earn', 'a', 'little', 'something', 'at', 'the', 'same', 'time']
# -----------
# I'm excited about the move, and the opportunities and challenges that await me there.
#
# ['i', 'am', 'excited', 'about', 'the', 'move', 'and', 'the', 'opportunities', 'and', 'challenges', 'that', 'await', 'me', 'there']
# -----------
# I hope all of you are well; that you have made it through the summer, and are excited about the upcoming (rapidly approaching) holiday season!
#
# ['i', 'hope', 'all', 'of', 'you', 'are', 'well', 'that', 'you', 'have', 'made', 'it', 'through', 'the', 'summer', 'and', 'are', 'excited', 'about', 'the', 'upcoming', 'rapidly', 'approaching', 'holiday', 'season']
# -----------
# I wish you all a fabulous week, and a warm and safe start to the wintry season.
#
# ['i', 'wish', 'you', 'all', 'a', 'fabulous', 'week', 'and', 'a', 'warm', 'and', 'safe', 'start', 'to', 'the', 'wintry', 'season']
# -----------
# But math just sucks, and I've accepted that.
#
# ['but', 'math', 'just', 'sucks', 'and', 'i', 'have', 'accepted', 'that']
# -----------
# Some of my teachers seem quite amazing, and others I know for a fact to be amazing.
#
# ['some', 'of', 'my', 'teachers', 'seem', 'quite', 'amazing', 'and', 'others', 'i', 'know', 'for', 'a', 'fact', 'to', 'be', 'amazing']
# -----------
# So, all-in-all, pretty good, right?
#
# ['so', 'all', 'in', 'all', 'pretty', 'good', 'right']
# -----------
# I also found out that Junior year, will, in fact, be a bitch.
#
# ['i', 'also', 'found', 'out', 'that', 'junior', 'year', 'will', 'in', 'fact', 'be', 'a', 'bitch']
# -----------
# You can handle high school drama.") Also, I have so many friends, and all of them are true, caring, trustworthy friends who love me and are supporting me 100%.
#
# ['you', 'can', 'handle', 'high', 'school', 'drama', 'also', 'i', 'have', 'so', 'many', 'friends', 'and', 'all', 'of', 'them', 'are', 'true', 'caring', 'trustworthy', 'friends', 'who', 'love', 'me', 'and', 'are', 'supporting', 'me', '100']
# -----------
# I can come through this year triumphantly and with grace.
#
# ['i', 'can', 'come', 'through', 'this', 'year', 'triumphantly', 'and', 'with', 'grace']
# -----------
# This is my year to be happy.
#
# ['this', 'is', 'my', 'year', 'to', 'be', 'happy']
# -----------
# This is my year to try new things and to succeed!
#
# ['this', 'is', 'my', 'year', 'to', 'try', 'new', 'things', 'and', 'to', 'succeed']
# -----------
# This is my first year of loving myself.
#
# ['this', 'is', 'my', 'first', 'year', 'of', 'loving', 'myself']
# -----------
# I also found out that Junior year, will, in fact, be a bitch.
#
# ['i', 'also', 'found', 'out', 'that', 'junior', 'year', 'will', 'in', 'fact', 'be', 'a', 'bitch']
# -----------
# You can handle high school drama.") Also, I have so many friends, and all of them are true, caring, trustworthy friends who love me and are supporting me 100%.
#
# ['you', 'can', 'handle', 'high', 'school', 'drama', 'also', 'i', 'have', 'so', 'many', 'friends', 'and', 'all', 'of', 'them', 'are', 'true', 'caring', 'trustworthy', 'friends', 'who', 'love', 'me', 'and', 'are', 'supporting', 'me', '100']
# -----------
# I can come through this year triumphantly and with grace.
#
# ['i', 'can', 'come', 'through', 'this', 'year', 'triumphantly', 'and', 'with', 'grace']
# -----------
# This is my year to be happy.
#
# ['this', 'is', 'my', 'year', 'to', 'be', 'happy']
# -----------
# This is my year to try new things and to succeed!
#
# ['this', 'is', 'my', 'year', 'to', 'try', 'new', 'things', 'and', 'to', 'succeed']
# -----------
# This is my first year of loving myself.
#
# ['this', 'is', 'my', 'first', 'year', 'of', 'loving', 'myself']
# -----------
# I look forward to learning and discovering even more of who I am, and loving every inch of it.
#
# ['i', 'look', 'forward', 'to', 'learning', 'and', 'discovering', 'even', 'more', 'of', 'who', 'i', 'am', 'and', 'loving', 'every', 'inch', 'of', 'it']
# -----------
# I cannot believe the nerve of this man
# ['i', 'cannot', 'believe', 'the', 'nerve', 'of', 'this', 'man']
# -----------
# kill something.
#
# ['kill', 'something']
# -----------
# What's even worse, it's copied so poorly that the last half inch of text on the far right side of the page is cut off, so as I try to read in preparation for the lab tomorrow I'm trying to coherently complete sentences and make sense of it all, which is often impossible because so much is left out.
#
# ['what', 'is', 'even', 'worse', 'it', 'is', 'copied', 'so', 'poorly', 'that', 'the', 'last', 'half', 'inch', 'of', 'text', 'on', 'the', 'far', 'right', 'side', 'of', 'the', 'page', 'is', 'cut', 'off', 'so', 'as', 'i', 'try', 'to', 'read', 'in', 'preparation', 'for', 'the', 'lab', 'tomorrow', 'i', 'am', 'trying', 'to', 'coherently', 'complete', 'sentences', 'and', 'make', 'sense', 'of', 'it', 'all', 'which', 'is', 'often', 'impossible', 'because', 'so', 'much', 'is', 'left', 'out']
# -----------
# Again, makes me so angry.
#
# ['again', 'makes', 'me', 'so', 'angry']
# -----------
# Poopy poopy poopy.
#
# ['poopy', 'poopy', 'poopy']
# -----------
# *cries* Such is life I suppose.
#
# ['cries', 'such', 'is', 'life', 'i', 'suppose']
# -----------
# I am in such a bad mood and I'm playing the blame game in my head, getting angry at people for things that are really quite trivial.
#
# ['i', 'am', 'in', 'such', 'a', 'bad', 'mood', 'and', 'i', 'am', 'playing', 'the', 'blame', 'game', 'in', 'my', 'head', 'getting', 'angry', 'at', 'people', 'for', 'things', 'that', 'are', 'really', 'quite', 'trivial']
# -----------
# I forgot how demeaning BME classes are.
#
# ['i', 'forgot', 'how', 'demeaning', 'bme', 'classes', 'are']
# -----------
# He was asking all these questions that I was completely baffled by and people were just spouting answers.
#
# ['he', 'was', 'asking', 'all', 'these', 'questions', 'that', 'i', 'was', 'completely', 'baffled', 'by', 'and', 'people', 'were', 'just', 'spouting', 'answers']
# -----------
# Sometimes I wonder how in the world I made it in, and every day I wonder how I'm going to make it through.
#
# ['sometimes', 'i', 'wonder', 'how', 'in', 'the', 'world', 'i', 'made', 'it', 'in', 'and', 'every', 'day', 'i', 'wonder', 'how', 'i', 'am', 'going', 'to', 'make', 'it', 'through']
# -----------
# I don't feel like I ever have that kind of privacy where I can talk to God and cry and figure things out.
#
# ['i', 'don', 'not', 'feel', 'like', 'i', 'ever', 'have', 'that', 'kind', 'of', 'privacy', 'where', 'i', 'can', 'talk', 'to', 'god', 'and', 'cry', 'and', 'figure', 'things', 'out']
# -----------
# I always tear up in church too, for different reasons.
#
# ['i', 'always', 'tear', 'up', 'in', 'church', 'too', 'for', 'different', 'reasons']
# -----------
# I love the way God brings people together.
#
# ['i', 'love', 'the', 'way', 'god', 'brings', 'people', 'together']
# -----------
# Girls, I highly recommend In Her Shoes, especially if you have a sister I'm enjoying it immensely and it has effectively distracted from my schoolwork almost all day.
#
# ['girls', 'i', 'highly', 'recommend', 'in', 'her', 'shoes', 'especially', 'if', 'you', 'have', 'a', 'sister', 'i', 'am', 'enjoying', 'it', 'immensely', 'and', 'it', 'has', 'effectively', 'distracted', 'from', 'my', 'schoolwork', 'almost', 'all', 'day']
# -----------
# These small indicators remind me that, in the Silvia Plath sense of the concept, I'm dying.
#
# ['these', 'small', 'indicators', 'remind', 'me', 'that', 'in', 'the', 'silvia', 'plath', 'sense', 'of', 'the', 'concept', 'i', 'am', 'dying']
# -----------
# Someday I will be no more than slime coating the expensive, cushiony, velvety inside of a coffin.
#
# ['someday', 'i', 'will', 'be', 'no', 'more', 'than', 'slime', 'coating', 'the', 'expensive', 'cushiony', 'velvety', 'inside', 'of', 'a', 'coffin']
# -----------
# The rickety deck I'm sitting on could fall, I could catch a stray bullet to the noggin on my way to my car in the parking lot, I could be nailed by a drunk, inattentive, careless, or simply unfortunate driver on the way home.
#
# ['the', 'rickety', 'deck', 'i', 'am', 'sitting', 'on', 'could', 'fall', 'i', 'could', 'catch', 'a', 'stray', 'bullet', 'to', 'the', 'noggin', 'on', 'my', 'way', 'to', 'my', 'car', 'in', 'the', 'parking', 'lot', 'i', 'could', 'be', 'nailed', 'by', 'a', 'drunk', 'inattentive', 'careless', 'or', 'simply', 'unfortunate', 'driver', 'on', 'the', 'way', 'home']
# ...
#
# ['fucking', 'seriously', 'kid']
# -----------
# Im rather sick of myspace.
#
# ['im', 'rather', 'sick', 'of', 'myspace']
# -----------
# Ive noticed an abundance are usually about me, and rather stupid.
#
# ['ive', 'noticed', 'an', 'abundance', 'are', 'usually', 'about', 'me', 'and', 'rather', 'stupid']
# -----------
# every once in awhile one or two titles will catch my eye and I will read it, but for the most part i really am sick and tired to stupid repetitive shit.
#
# ['every', 'once', 'in', 'awhile', 'one', 'or', 'two', 'titles', 'will', 'catch', 'my', 'eye', 'and', 'i', 'will', 'read', 'it', 'but', 'for', 'the', 'most', 'part', 'i', 'really', 'am', 'sick', 'and', 'tired', 'to', 'stupid', 'repetitive', 'shit']
# -----------
# Gag, enough on that crap.
#
# ['gag', 'enough', 'on', 'that', 'crap']
# -----------
# Court was intimidating but I did good.
#
# ['court', 'was', 'intimidating', 'but', 'i', 'did', 'good']
# -----------
# I actually got it pretty good.
#
# ['i', 'actually', 'got', 'it', 'pretty', 'good']
# -----------
# Every one was really nice, even the judge.
#
# ['every', 'one', 'was', 'really', 'nice', 'even', 'the', 'judge']
# -----------
# The exciting part of my day, as cliche as it sounds was a car fire.
#
# ['the', 'exciting', 'part', 'of', 'my', 'day', 'as', 'cliche', 'as', 'it', 'sounds', 'was', 'a', 'car', 'fire']
# -----------
# So i Told him it was on fire I dont think he heard me, So i grabbed his smeater and yanked him out of the car, he stumbled back, dropped his shit and looked at me pissed "what the fuck lady" we got about four or five steps from the vehicle when the gas tanked popped (not a hollywood explosion here people) and burning gas flew out everywhere, catching the grass on fire, blowing out both rear tires and because the door was open, the interior of the vehicle started going up in flames.
#
# ['so', 'i', 'told', 'him', 'it', 'was', 'on', 'fire', 'i', 'dont', 'think', 'he', 'heard', 'me', 'so', 'i', 'grabbed', 'his', 'smeater', 'and', 'yanked', 'him', 'out', 'of', 'the', 'car', 'he', 'stumbled', 'back', 'dropped', 'his', 'shit', 'and', 'looked', 'at', 'me', 'pissed', 'what', 'the', 'fuck', 'lady', 'we', 'got', 'about', 'four', 'or', 'five', 'steps', 'from', 'the', 'vehicle', 'when', 'the', 'gas', 'tanked', 'popped', 'not', 'a', 'hollywood', 'explosion', 'here', 'people', 'and', 'burning', 'gas', 'flew', 'out', 'everywhere', 'catching', 'the', 'grass', 'on', 'fire', 'blowing', 'out', 'both', 'rear', 'tires', 'and', 'because', 'the', 'door', 'was', 'open', 'the', 'interior', 'of', 'the', 'vehicle', 'started', 'going', 'up', 'in', 'flames']
# -----------
# after some silence from the driver his attitude changed and hes like "thanks that could have been me" and repeated "oh my god" while I got an ETA on police and fire from dispatch and gave her information.
#
# ['after', 'some', 'silence', 'from', 'the', 'driver', 'his', 'attitude', 'changed', 'and', 'hes', 'like', 'thanks', 'that', 'could', 'have', 'been', 'me', 'and', 'repeated', 'oh', 'my', 'god', 'while', 'i', 'got', 'an', 'eta', 'on', 'police', 'and', 'fire', 'from', 'dispatch', 'and', 'gave', 'her', 'information']
# -----------
# Point is it was exciting.
#
# ['point', 'is', 'it', 'was', 'exciting']
# -----------
# he gave me a hug, that was good.
#
# ['he', 'gave', 'me', 'a', 'hug', 'that', 'was', 'good']
# -----------
# How do you know that smoke is not from a tire, and the car could be on fire??
#
# ['how', 'do', 'you', 'know', 'that', 'smoke', 'is', 'not', 'from', 'a', 'tire', 'and', 'the', 'car', 'could', 'be', 'on', 'fire']
# -----------
# But uncle bee've saved the day and fixed a bunch of stuff for me
# ['but', 'uncle', 'bee', 'have', 'saved', 'the', 'day', 'and', 'fixed', 'a', 'bunch', 'of', 'stuff', 'for', 'me']
# -----------
# While I was in lakewood I surprised Brian and we met Scooty for lunch, suprised him too.
#
# ['while', 'i', 'was', 'in', 'lakewood', 'i', 'surprised', 'brian', 'and', 'we', 'met', 'scooty', 'for', 'lunch', 'suprised', 'him', 'too']
# -----------
# It was SOOOO nice to see them.
#
# ['it', 'was', 'soooo', 'nice', 'to', 'see', 'them']
# -----------
# I can't wait to go on a night drive with Brian and just chill out there for awhile.
#
# ['i', 'can', 'not', 'wait', 'to', 'go', 'on', 'a', 'night', 'drive', 'with', 'brian', 'and', 'just', 'chill', 'out', 'there', 'for', 'awhile']
# -----------
# It feels pretty good today.
#
# ['it', 'feels', 'pretty', 'good', 'today']
# -----------
# Good to love life.
#
# ['good', 'to', 'love', 'life']
# -----------
# They both just lost their husbands and Vegas grandma has had more time, were hoping she will help Canada grandma feel better.
#
# ['they', 'both', 'just', 'lost', 'their', 'husbands', 'and', 'vegas', 'grandma', 'has', 'had', 'more', 'time', 'were', 'hoping', 'she', 'will', 'help', 'canada', 'grandma', 'feel', 'better']
# -----------
# Which I am so happy for.
#
# ['which', 'i', 'am', 'so', 'happy', 'for']
# -----------
# I am so proud of my sister.
#
# ['i', 'am', 'so', 'proud', 'of', 'my', 'sister']
# -----------
# im sick of looking at a computer screen.
#
# ['im', 'sick', 'of', 'looking', 'at', 'a', 'computer', 'screen']
# -----------
# "I can't relate to 99% of humanity."
#
# ['i', 'can', 'not', 'relate', 'to', '99', 'of', 'humanity']
# -----------
# I am, quite honestly, furious and they WILL be getting an angry letter from me, even though won't care, I'm sure because as much as they would like you to think that they aren't part of the "machine" they are.
#
# ['i', 'am', 'quite', 'honestly', 'furious', 'and', 'they', 'will', 'be', 'getting', 'an', 'angry', 'letter', 'from', 'me', 'even', 'though', 'won', 'not', 'care', 'i', 'am', 'sure', 'because', 'as', 'much', 'as', 'they', 'would', 'like', 'you', 'to', 'think', 'that', 'they', 'are', 'not', 'part', 'of', 'the', 'machine', 'they', 'are']
# -----------
# Go ahead, care about the environment, but don't care about demeaning women.)
#
# ['go', 'ahead', 'care', 'about', 'the', 'environment', 'but', 'don', 'not', 'care', 'about', 'demeaning', 'women']
# -----------
# - I enjoy reading.
#
# ['i', 'enjoy', 'reading']
# -----------
# - I don't think money buys happiness.
#
# ['i', 'don', 'not', 'think', 'money', 'buys', 'happiness']
# -----------
# I don't think sex begets happiness.
#
# ['i', 'don', 'not', 'think', 'sex', 'begets', 'happiness']
# -----------
# - I actually take notice of nice days, smells, etc
# ['i', 'actually', 'take', 'notice', 'of', 'nice', 'days', 'smells', 'etc']
# -----------
# People are just rude and selfish, and I know I'm victim too, but I don't want to be like that.
#
# ['people', 'are', 'just', 'rude', 'and', 'selfish', 'and', 'i', 'know', 'i', 'am', 'victim', 'too', 'but', 'i', 'don', 'not', 'want', 'to', 'be', 'like', 'that']
# -----------
# So I kept walking straight, and the dog that crossed the street turned around and saw me and growled, I was like " oh shit Jorge, just keep walking."
#
# ['so', 'i', 'kept', 'walking', 'straight', 'and', 'the', 'dog', 'that', 'crossed', 'the', 'street', 'turned', 'around', 'and', 'saw', 'me', 'and', 'growled', 'i', 'was', 'like', 'oh', 'shit', 'jorge', 'just', 'keep', 'walking']
# -----------
# So i did, and then the second dog growls at me too, and Im like " Should I run or keep walking?"
#
# ['so', 'i', 'did', 'and', 'then', 'the', 'second', 'dog', 'growls', 'at', 'me', 'too', 'and', 'im', 'like', 'should', 'i', 'run', 'or', 'keep', 'walking']
# -----------
# So I kept walking and then the other dog that crossed the street comes back running at me and I said "OHH SSHHIITTT!!!"
#
# ['so', 'i', 'kept', 'walking', 'and', 'then', 'the', 'other', 'dog', 'that', 'crossed', 'the', 'street', 'comes', 'back', 'running', 'at', 'me', 'and', 'i', 'said', 'ohh', 'sshhiittt']
# -----------
# And I saw a house with the gate door opened slightly, and i squeezed in there sumhow sumway!!!
#
# ['and', 'i', 'saw', 'a', 'house', 'with', 'the', 'gate', 'door', 'opened', 'slightly', 'and', 'i', 'squeezed', 'in', 'there', 'sumhow', 'sumway']
# -----------
# I know im skinny but DAMN!!
#
# ['i', 'know', 'im', 'skinny', 'but', 'damn']
# -----------
# I WUZ SCARED!!!
#
# ['i', 'wuz', 'scared']
# -----------
# "It's the heart afraid of breaking that never learns to dance.
#
# ['it', 'is', 'the', 'heart', 'afraid', 'of', 'breaking', 'that', 'never', 'learns', 'to', 'dance']
# -----------
# It's the dream afraid of waking that never takes the chance.
#
# ['it', 'is', 'the', 'dream', 'afraid', 'of', 'waking', 'that', 'never', 'takes', 'the', 'chance']
# -----------
# And the soul afraid of dying that never learns to live.
#
# ['and', 'the', 'soul', 'afraid', 'of', 'dying', 'that', 'never', 'learns', 'to', 'live']
# -----------
# "When the night has been too lonely, and the road has been too long,
#
# ['when', 'the', 'night', 'has', 'been', 'too', 'lonely', 'and', 'the', 'road', 'has', 'been', 'too', 'long']
# -----------
# It's the second stanza that caught my attention; more specifically, it's those two first lines: "It's the heart afraid of breaking that never learns to dance./It's the dream afraid of waking that never takes the chance."
#
# ['it', 'is', 'the', 'second', 'stanza', 'that', 'caught', 'my', 'attention', 'more', 'specifically', 'it', 'is', 'those', 'two', 'first', 'lines', 'it', 'is', 'the', 'heart', 'afraid', 'of', 'breaking', 'that', 'never', 'learns', 'to', 'dance', 'it', 'is', 'the', 'dream', 'afraid', 'of', 'waking', 'that', 'never', 'takes', 'the', 'chance']
# -----------
# I have considered the possibility for a while now, but I have been apprehensive, and I did not act on what I felt.
#
# ['i', 'have', 'considered', 'the', 'possibility', 'for', 'a', 'while', 'now', 'but', 'i', 'have', 'been', 'apprehensive', 'and', 'i', 'did', 'not', 'act', 'on', 'what', 'i', 'felt']
# -----------
# And then, just the other day, I was driving down 470 on the way to college, listening to 105.5, and a beautiful song came on that I had not heard before.
#
# ['and', 'then', 'just', 'the', 'other', 'day', 'i', 'was', 'driving', 'down', '470', 'on', 'the', 'way', 'to', 'college', 'listening', 'to', '105', '5', 'and', 'a', 'beautiful', 'song', 'came', 'on', 'that', 'i', 'had', 'not', 'heard', 'before']
# -----------
# The words made me think Now I have thought, and thought, and you who know me best will not be surprised that I thought some more
#
# ['the', 'words', 'made', 'me', 'think', 'now', 'i', 'have', 'thought', 'and', 'thought', 'and', 'you', 'who', 'know', 'me', 'best', 'will', 'not', 'be', 'surprised', 'that', 'i', 'thought', 'some', 'more']
# -----------
# Internship was pretty awesome today.
#
# ['internship', 'was', 'pretty', 'awesome', 'today']
# -----------
# I did an SAT Lit practice test on each bus ride, because I am cool, and I did better than I expected.
#
# ['i', 'did', 'an', 'sat', 'lit', 'practice', 'test', 'on', 'each', 'bus', 'ride', 'because', 'i', 'am', 'cool', 'and', 'i', 'did', 'better', 'than', 'i', 'expected']
# -----------
# I totally loved it, because I am a geek.
#
# ['i', 'totally', 'loved', 'it', 'because', 'i', 'am', 'a', 'geek']
# -----------
# I love the two guys who work at that Starbucks - they're awesomely flamboyant and they told me about how Cameron Diaz came in for a latte during their shift last week (but without Justin!
#
# ['i', 'love', 'the', 'two', 'guys', 'who', 'work', 'at', 'that', 'starbucks', 'they', 'are', 'awesomely', 'flamboyant', 'and', 'they', 'told', 'me', 'about', 'how', 'cameron', 'diaz', 'came', 'in', 'for', 'a', 'latte', 'during', 'their', 'shift', 'last', 'week', 'but', 'without', 'justin']
# -----------
# I didn't see Will Smith (although the French Prince is usually my shit, I think I would have had to punch him on behalf of everyone who's heard "Switch"), but the girl on the elevator with me said she had just randomly seen Mike Myers.
#
# ['i', 'didn', 'not', 'see', 'will', 'smith', 'although', 'the', 'french', 'prince', 'is', 'usually', 'my', 'shit', 'i', 'think', 'i', 'would', 'have', 'had', 'to', 'punch', 'him', 'on', 'behalf', 'of', 'everyone', 'who', 'is', 'heard', 'switch', 'but', 'the', 'girl', 'on', 'the', 'elevator', 'with', 'me', 'said', 'she', 'had', 'just', 'randomly', 'seen', 'mike', 'myers']
# -----------
# That afternoon - *gulp* - Lawler came to observe me
# ['that', 'afternoon', 'gulp', 'lawler', 'came', 'to', 'observe', 'me']
# -----------
# Ms
# ['ms']
# -----------
# Then she proceeded to call me Meghan** and went through the required but hilariously inapplicable hazardous chemicals/safety concerns set of questions while the interns around me tried to stifle their laughter.
#
# ['then', 'she', 'proceeded', 'to', 'call', 'me', 'meghan', 'and', 'went', 'through', 'the', 'required', 'but', 'hilariously', 'inapplicable', 'hazardous', 'chemicals', 'safety', 'concerns', 'set', 'of', 'questions', 'while', 'the', 'interns', 'around', 'me', 'tried', 'to', 'stifle', 'their', 'laughter']
# -----------
# I'm kind of freaking out about debate but I'm kind of okay.
#
# ['i', 'am', 'kind', 'of', 'freaking', 'out', 'about', 'debate', 'but', 'i', 'am', 'kind', 'of', 'okay']
# -----------
# Good news.
#
# ['good', 'news']
# -----------
# I was psyched.
#
# ['i', 'was', 'psyched']
# -----------
# ugh.
#
# ['ugh']
# -----------
# At one point I apologized for being so nervous and they told me that there were people a lot worse and that I wasn't using the words "uh" and "um" as often as others had been.
#
# ['at', 'one', 'point', 'i', 'apologized', 'for', 'being', 'so', 'nervous', 'and', 'they', 'told', 'me', 'that', 'there', 'were', 'people', 'a', 'lot', 'worse', 'and', 'that', 'i', 'wasn', 'not', 'using', 'the', 'words', 'uh', 'and', 'um', 'as', 'often', 'as', 'others', 'had', 'been']
# -----------
# Everything looks good.
#
# ['everything', 'looks', 'good']
# -----------
# Where they will decide to place me is up to them, as long as I get the job, I'll be really happy.
#
# ['where', 'they', 'will', 'decide', 'to', 'place', 'me', 'is', 'up', 'to', 'them', 'as', 'long', 'as', 'i', 'get', 'the', 'job', 'i', 'll', 'be', 'really', 'happy']
# -----------
# I felt really awful through out the whole day too.
#
# ['i', 'felt', 'really', 'awful', 'through', 'out', 'the', 'whole', 'day', 'too']
# -----------
# That one chick I dislike with a passion because I think she is obsessed with Gareth and really likes him.
#
# ['that', 'one', 'chick', 'i', 'dislike', 'with', 'a', 'passion', 'because', 'i', 'think', 'she', 'is', 'obsessed', 'with', 'gareth', 'and', 'really', 'likes', 'him']
# -----------
# I really do hate it.
#
# ['i', 'really', 'do', 'hate', 'it']
# -----------
# So I did and I got so panicky that I only got to the 6th page.
#
# ['so', 'i', 'did', 'and', 'i', 'got', 'so', 'panicky', 'that', 'i', 'only', 'got', 'to', 'the', '6th', 'page']
# -----------
# and I was freak it.
#
# ['and', 'i', 'was', 'freak', 'it']
# -----------
# I left it, but through out the whole day I was really awful.
#
# ['i', 'left', 'it', 'but', 'through', 'out', 'the', 'whole', 'day', 'i', 'was', 'really', 'awful']
# -----------
# when I got home I was really nervous I had not talk to Gareth for 2 days because of college.
#
# ['when', 'i', 'got', 'home', 'i', 'was', 'really', 'nervous', 'i', 'had', 'not', 'talk', 'to', 'gareth', 'for', '2', 'days', 'because', 'of', 'college']
# -----------
# Really scared.
#
# ['really', 'scared']
# -----------
# So I tell him it took me FOREVER To tell him but i was shakey and nervous to.
#
# ['so', 'i', 'tell', 'him', 'it', 'took', 'me', 'forever', 'to', 'tell', 'him', 'but', 'i', 'was', 'shakey', 'and', 'nervous', 'to']
# -----------
# He's like, Would it make me happy that I delete her off my friends list and messenger.
#
# ['he', 'is', 'like', 'would', 'it', 'make', 'me', 'happy', 'that', 'i', 'delete', 'her', 'off', 'my', 'friends', 'list', 'and', 'messenger']
# -----------
# because I dislike her very much.
#
# ['because', 'i', 'dislike', 'her', 'very', 'much']
# -----------
# And I hate these mistakes I do.
#
# ['and', 'i', 'hate', 'these', 'mistakes', 'i', 'do']
# -----------
# Man
# ['man']
# -----------
# Ill miss you always forever and ever.
#
# ['ill', 'miss', 'you', 'always', 'forever', 'and', 'ever']
# -----------
# i'm so down right now i can't be anymore upset.
#
# ['i', 'am', 'so', 'down', 'right', 'now', 'i', 'can', 'not', 'be', 'anymore', 'upset']
# -----------
# ['this', 'was', 'the', 'best', 'summer', 'i', 'have', 'ever', 'experienced']

# %% [markdown]
# Les't determine the total and average number of words in each sentencesLes't determine the total and average number of words in each sentences

# %%
def maximum(sent):
    numWords = []
    for s in sent:
        counter = len(s)
        numWords.append(counter) 
    maxLengh = int(sum(numWords)/len(numWords))
    print("Average: ", maxLengh)
    return numWords,maxLengh
numWords,maxSeqLength = maximum(c_sent)
# Out:
# Average:  14

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
def histograma(numWords):
    plt.hist(numWords, 50)
    plt.xlabel('Sequence Length')
    plt.ylabel('Frequency')
    plt.axis([0, 70, 0, 500])
    plt.show()
histograma(numWords)

# %% [markdown]
# Converting each sentence into a vector and adding it into a matrix of 'ids'

# %%
def integerSenteces(sent,maximum):
    i = 0
    embbeding = 0
    matrix = np.zeros((len(sent), maximum)) #250 X 6 (numEjem X Maximun)
    for s in sent:
        vector = np.zeros((maximum), dtype='int32')
        bound = maximum
        if len(s) < maximum:
            bound = len(s)    

        for token in range(0,bound): #No encuentra macu, porque la corta
            if s[token] not in wordsList:
                vector[token] = embbeding # ???
                #print(s[token])
            else:
                vector[token] = (wordsList.index(s[token]))
                embbeding = vector[token]
        matrix[i] = (vector)
        i += 1
    return matrix

# %%
X = integerSenteces(c_sent,maxSeqLength) 
#print("Sentences integer representation: ",(X.shape))
#print("Sentences: ",len(c_sent))
#print("Integer format",X[249])
#print("Normal format",c_sent[249])

# %% [markdown]
# Split the Data (stratify) into : Train && Test Sets

# %%
print("Sentences: ",len(X),"  Labels: ",len(emotion))
X_train, X_test, Y_train, Y_test = train_test_split(X, emotion, test_size=0.20, random_state=random.randrange(50), stratify=emotion)
print("X_train: ",len(X_train),"  Y_train: ",len(Y_train),"  X_test: ",len(X_test),"  Y_test: ",len(Y_test))
# Out:
# Sentences:  1290   Labels:  1290
# X_train:  1032   Y_train:  1032   X_test:  258   Y_test:  258

# %% [markdown]
# Converting the Labels into Onehot Vectors

# %%
def toLabels(emo):
    classes = 6
    Y = np.zeros((len(emo), classes)) #Num Ejemplos X 6 emociones
    for e in range(0,len(emo)):
        vector = np.zeros((classes))
        vector[(emo[e] % (classes + 1)) - 1] = 1 
        Y[e] = vector
    return Y
 
Y_train = toLabels(Y_train)
Y_test = toLabels(Y_test)

# %%
print("Y_train: ",Y_train.shape," Num Ejem X # clases")
print("X_train: ",X_train.shape," Num Ejem X Maximun Lengh")
print("Y_test: ",Y_test.shape," Num Ejem X # clases")
print("X_test: ",X_test.shape," Num Ejem X Maximun Lengh")
# Out:
# Y_train:  (1032, 6)  Num Ejem X # clases
# X_train:  (1032, 14)  Num Ejem X Maximun Lengh
# Y_test:  (258, 6)  Num Ejem X # clases
# X_test:  (258, 14)  Num Ejem X Maximun Lengh

# %% [markdown]
# RNN Model

# %%
batchSize = 50 #Tiene que ser multiplo del NumEjem
lstmUnits = 64
numClasses = 6

# %% [markdown]
# Declarando placeholders para los labels (5 emotions) && data imput

# %%
import tensorflow as tf
tf.reset_default_graph()
numDimensions = 300 

#labels = tf.placeholder(tf.float32, [batchSize, numClasses])
#input_data = tf.placeholder(tf.int32, [batchSize, maxSeqLength])
labels = tf.placeholder(tf.float32, [None, numClasses])
input_data = tf.placeholder(tf.int32, [None, maxSeqLength])

# %% [markdown]
# Embeddings: Le damos el formato a nuestra data, aún no compilamos nada, solo declaramos

# %%
data = tf.Variable(tf.zeros([batchSize, maxSeqLength, numDimensions]),dtype=tf.float32)
data = tf.nn.embedding_lookup(wordVectors,input_data)

# %% [markdown]
# LSTM Model

# %%
lstmCell = tf.contrib.rnn.BasicLSTMCell(lstmUnits)
lstmCell = tf.contrib.rnn.DropoutWrapper(cell=lstmCell, output_keep_prob=0.75)
value, _ = tf.nn.dynamic_rnn(lstmCell, data, dtype=tf.float32)

# %%
weight = tf.Variable(tf.truncated_normal([lstmUnits, numClasses]))
bias = tf.Variable(tf.constant(0.1, shape=[numClasses]))
value = tf.transpose(value, [1, 0, 2])
last = tf.gather(value, int(value.get_shape()[0]) - 1)
prediction = (tf.matmul(last, weight) + bias)

# %%
correctPred = tf.equal(tf.argmax(prediction,1), tf.argmax(labels,1))
accuracy = tf.reduce_mean(tf.cast(correctPred, tf.float32))

# %%
learning_rate = 0.004
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=prediction, labels=labels))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)
# Out:
# C:\Users\UX310UQ\Anaconda3\envs\IaTopicos\lib\site-packages\tensorflow\python\ops\gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %% [markdown]
# Tensorboar

# %%
import datetime
def board(sess):
    tf.summary.scalar('Loss', loss)
    tf.summary.scalar('Accuracy', accuracy)
    tf.summary.histogram("Histogrma/hAccu", accuracy)
    merged = tf.summary.merge_all()
    logdir = "board/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + "/"
    writer = tf.summary.FileWriter(logdir, sess.graph)
    return merged,writer

# %% [markdown]
# Confusion Matrix Plot

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
# Initializing the variables
init = tf.global_variables_initializer()
display_step = 100
numEjemplos = 1032
iterations = 100

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    #Calling tensorboard function
    #---merged,writer = board(sess)
    
    # Training cycle
    for epoch in range(iterations):
        avg_cost = 0.
        avg_accu = 0.
        total_batch = int(numEjemplos/batchSize)
        
        #Create X groups of (50,5) Labels && (50,maximum) Examples
        X_batches = np.array_split(X_train, total_batch)
        Y_batches = np.array_split(Y_train, total_batch)
        # Loop over all batches
        for i in range(total_batch):
            batch_x, batch_y = X_batches[i], Y_batches[i]
            #print("X: ",batch_x.shape)
            #print("Y: ",batch_y.shape)
            # Run optimization op (backprop) and cost op (to get loss value)
            _, c , accu= sess.run([optimizer, loss, accuracy], feed_dict={input_data: batch_x,
                                                          labels: batch_y})
            # Compute average loss
            avg_cost += c / total_batch
            avg_accu += accu / total_batch

            #Write summary to Tensorboard
            '''if (epoch % 10 == 0):
                summary = sess.run(merged, {input_data: batch_x, labels: batch_y})
                writer.add_summary(summary, epoch)'''
            

            #Save the network every 10,000 training iterations
            #if (i % 10000 == 0 and i != 0):
                # save_path = saver.save(sess, "models/pretrained_lstm.ckpt", global_step=i)
                 # print("saved to %s" % save_path)
            #writer.close()

        if epoch % display_step == 0:
            print("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(avg_cost)," accuracy=", "{:.9f}".format(avg_accu*100))
    print("Optimization Finished!")
    
    #Test Model LSTM  
    correctPred = tf.equal(tf.argmax(prediction,1), tf.argmax(labels,1))
    # Calculate accuracy
    accuracy = tf.reduce_mean(tf.cast(correctPred, "float"))
    print("Accuracy:", accuracy.eval({input_data: X_test, labels: Y_test}))
    
    #Matriz de confusion

    #print("Test Samples, Class Predictions: ")
    result = tf.argmax(prediction , 1).eval({input_data: X_test, labels: Y_test})
    #print(result.shape)
    
    
    #print("Test Samples: ")
    test = (tf.argmax(Y_test , 1).eval()) #Convierte de [0,0,1,0,0] a [2] y lo hace np.array
    #print(test.shape)
      

    from sklearn.metrics import confusion_matrix
    y_true = test
    y_pred = result
    #print(confusion_matrix(y_true, y_pred))
    class_names = ["Hapinnes","Sadness","Anger","Disust","Surprise","Fear"]
    
    from sklearn.metrics import precision_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import recall_score
    print("Precision: ",precision_score(y_true, y_pred, average=None))
    print("Recall: ",recall_score(y_true, y_pred, average=None))
    print("F1: ",f1_score(y_true, y_pred, average=None))

    # Compute confusion matrix
    cnf_matrix = confusion_matrix(y_true, y_pred)
    np.set_printoptions(precision=2)

    # Plot non-normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names,
                          title='Confusion matrix, without normalization')

    # Plot normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                          title='Normalized confusion matrix')

    plt.show()
# Out:
# Epoch: 0001 cost= 1.764039469  accuracy= 37.015460208
# Optimization Finished!
# Accuracy: 0.5813953
# Precision:  [0.5  0.45 0.44 0.35 0.4  0.75]
# Recall:  [0.37 0.56 0.47 0.26 0.43 0.78]
# F1:  [0.43 0.5  0.46 0.3  0.42 0.76]
# Confusion matrix, without normalization
# [[13  6  5  1  2  8]
#  [ 0 20  5  3  3  5]
#  [ 2  6 16  0  3  7]
#  [ 6  0  1  6  4  6]
#  [ 3  4  4  1 10  1]
#  [ 2  8  5  6  3 83]]
# Normalized confusion matrix
# [[0.37 0.17 0.14 0.03 0.06 0.23]
#  [0.   0.56 0.14 0.08 0.08 0.14]
#  [0.06 0.18 0.47 0.   0.09 0.21]
#  [0.26 0.   0.04 0.26 0.17 0.26]
#  [0.13 0.17 0.17 0.04 0.43 0.04]
#  [0.02 0.07 0.05 0.06 0.03 0.78]]

# %%
#Recuerda que cambiaste el sample
#Falta "balancear" la data
#Menos vueltas > acuracy
#Con 0.009
