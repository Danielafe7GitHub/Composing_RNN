# %%
#!/usr/bin/python
import nltk
import numpy as np
import re
import tensorflow as tf
from nltk.tokenize import WordPunctTokenizer
from random import randint

# %% [markdown]
# Importing Glove and  40000 words list

# %%
wordsList = np.load('wordsList.npy')
print('Loaded the word list!')
wordsList = wordsList.tolist() #Originally loaded as numpy array
wordsList = [word.decode('UTF-8') for word in wordsList] #Encode words as UTF-8
wordVectors = np.load('wordVectors.npy')
print ('Loaded the word vectors!')
print(len(wordsList))
print(wordVectors.shape)
print(wordsList[5066])
print(wordVectors[5066][:])
# Out:
# Loaded the word list!
# Loaded the word vectors!
# 400000
# (400000, 50)
# closure
# [ 0.51  0.12 -0.12 -0.21 -1.07 -0.18  0.16  0.77  0.26 -0.16  0.03 -0.65
#  -0.45 -0.19  0.45  1.1   0.05 -0.37  0.17  0.28  0.85 -0.55 -1.18  0.07
#  -0.59 -0.85  0.19  0.38  0.94  0.63  2.39 -0.41 -0.12  0.05 -0.42 -0.06
#   1.5  -0.94 -0.16  0.8  -0.44 -0.5   0.07  0.28 -0.28 -0.01 -0.37  0.49
#  -0.35  0.04]

# %% [markdown]
# Extract data from Affective Text a News Headlines from Google News or CNN

# %%
#--------------------Extracting Id && sentences from corpus
def extract(dataset):
    f = open(dataset, 'r+')
    linea = f.readline()
    _id = []
    sentences = []
    
    while linea != "":    
        #print(linea.split("#"))
        linea = linea.split("#")
        _id.append(linea[0])
        sentences.append(linea[1])
        linea = f.readline()
    f.close()
    return sentences,_id

dataset = "Affective_Text/affectivetext_trial.xml"
sentences,_id = extract(dataset)
print(_id[0]," ",sentences[0])
# Out:
# 1   Mortar assault leaves at least 18 dead

# %% [markdown]
# Extracting Emotion from Affective Text dataset : {happiness, sadness, anger, disgust, surprise, and fear}

# %%
#--------------------Extracting the most high emotion 
def extract_emo(dataset):
    f = open(dataset, 'r+')
    linea = f.readline()
    emotions = []
    while linea != "":    
        linea = linea.split(" ")
        linea.pop(0)
        _max = linea.index(max(linea))
        emotions.append(_max)
        linea = f.readline()
    f.close()
    return emotions

dataset = "Affective_Text/affectivetext_trial.emotions.gold"
emotions = extract_emo(dataset)
print(emotions)
# Out:
# [4, 3, 3, 2, 5, 3, 3, 5, 3, 3, 3, 4, 3, 5, 4, 0, 3, 4, 3, 4, 3, 2, 3, 5, 0, 3, 1, 2, 5, 2, 1, 3, 3, 0, 3, 2, 0, 4, 2, 5, 4, 4, 5, 4, 4, 2, 4, 5, 2, 2, 2, 1, 0, 3, 3, 4, 5, 5, 0, 1, 2, 4, 2, 5, 3, 5, 2, 2, 4, 3, 5, 2, 0, 0, 0, 3, 1, 4, 3, 5, 1, 2, 3, 3, 3, 5, 5, 2, 0, 3, 3, 4, 3, 4, 3, 0, 2, 0, 2, 2, 0, 1, 1, 3, 3, 4, 3, 3, 3, 4, 5, 4, 1, 2, 0, 4, 0, 3, 3, 0, 5, 3, 0, 2, 0, 0, 1, 2, 3, 3, 1, 2, 5, 4, 2, 0, 0, 0, 5, 3, 3, 2, 0, 1, 3, 4, 2, 3, 5, 5, 5, 3, 3, 2, 4, 4, 4, 0, 2, 5, 5, 0, 2, 2, 2, 5, 2, 3, 3, 4, 1, 3, 3, 5, 4, 4, 3, 3, 2, 2, 5, 5, 5, 5, 1, 5, 3, 4, 3, 0, 0, 5, 0, 4, 0, 2, 4, 2, 3, 1, 3, 4, 4, 5, 4, 4, 0, 3, 2, 1, 0, 4, 4, 1, 0, 5, 0, 2, 5, 3, 5, 3, 5, 5, 3, 0, 3, 0, 2, 5, 3, 4, 3, 3, 3, 5, 3, 3, 0, 5, 3, 5, 4, 4, 5, 4, 3, 3, 2, 1]

# %% [markdown]
# Preprocesing of Sentences

# %%
def decontracted(phrase):
    # specific
    '''phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)'''

    if phrase == "t":
        phrase = "not"
    elif phrase == "re":
        phrase = "are"
    elif phrase == "s":
        phrase = "is"
    elif phrase == "d":
        phrase = "would"
    elif phrase == "ve":
        phrase = "have"
    elif phrase == "m":
        phrase = "am"
    elif phrase == "ca":
        phrase = "can"
    elif phrase == "isn":
        phrase = "is"
    elif phrase == "aren":
        phrase = "are"
    elif phrase == "wouldn":
        phrase = "would"

    # general
    '''phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)'''
    return phrase

# %%
#----------------Cleanning Sentences--------------
def cleaner(sent):
    for s in range(0,len(sent)):
        print(sent[s])
        sent[s] = sent[s].lower()
        sent[s] = WordPunctTokenizer().tokenize(sent[s])#nltk.word_tokenize(sent[s])
        #print(sent[s])
        for word in range(0,len(sent[s])):
            sent[s][word] = decontracted(sent[s][word])
            sent[s][word] = re.sub(r'[^a-zA-Z0-9\s]', ' ', sent[s][word])
            sent[s][word] = sent[s][word].strip()
            
        sent[s] = list(filter(None, sent[s])) # fastest
        print(sent[s])
        print("-----------")
    return sent

c_sent = sentences[:]    
c_sent = cleaner(c_sent)
print(c_sent[0])
# Out:
# Mortar assault leaves at least 18 dead
#
# ['mortar', 'assault', 'leaves', 'at', 'least', '18', 'dead']
# -----------
# Goal delight for Sheva
#
# ['goal', 'delight', 'for', 'sheva']
# -----------
# Nigeria hostage feared dead is freed
#
# ['nigeria', 'hostage', 'feared', 'dead', 'is', 'freed']
# -----------
# Bombers kill shoppers
#
# ['bombers', 'kill', 'shoppers']
# -----------
# Vegetables, not fruit, slow brain decline
#
# ['vegetables', 'not', 'fruit', 'slow', 'brain', 'decline']
# -----------
# PM: Havana deal a good experiment
#
# ['pm', 'havana', 'deal', 'a', 'good', 'experiment']
# -----------
# Kate is marrying Doherty
#
# ['kate', 'is', 'marrying', 'doherty']
# -----------
# NASA revisiting life on Mars question
#
# ['nasa', 'revisiting', 'life', 'on', 'mars', 'question']
# -----------
# Happy birthday, iPod
#
# ['happy', 'birthday', 'ipod']
# -----------
# Alonso would be happy to retire with three titles
#
# ['alonso', 'would', 'be', 'happy', 'to', 'retire', 'with', 'three', 'titles']
# -----------
# Madonna's New Tot 'Happy at Home' in London
#
# ['madonna', 'is', 'new', 'tot', 'happy', 'at', 'home', 'in', 'london']
# -----------
# Nicole Kidman asks dad to help stop husband's drinking
#
# ['nicole', 'kidman', 'asks', 'dad', 'to', 'help', 'stop', 'husband', 'is', 'drinking']
# -----------
# United Finds Good Connection in Win
#
# ['united', 'finds', 'good', 'connection', 'in', 'win']
# -----------
# 'Runway': Making Good Without Making Nice
#
# ['runway', 'making', 'good', 'without', 'making', 'nice']
# -----------
# We were 'arrogant and stupid' over Iraq, says US diplomat
#
# ['we', 'were', 'arrogant', 'and', 'stupid', 'over', 'iraq', 'says', 'us', 'diplomat']
# -----------
# Bad reasons to be good
#
# ['bad', 'reasons', 'to', 'be', 'good']
# -----------
# Madonna's new baby's daddy didn't realize adoption was `for good'
#
# ['madonna', 'is', 'new', 'baby', 'is', 'daddy', 'didn', 'not', 'realize', 'adoption', 'was', 'for', 'good']
# -----------
# Women in their 60s 'are perfectly good mothers'
#
# ['women', 'in', 'their', '60s', 'are', 'perfectly', 'good', 'mothers']
# -----------
# We're a pretty kind 'bully'
#
# ['we', 'are', 'a', 'pretty', 'kind', 'bully']
# -----------
# Moderate drinking reduces men's heart attack risk
#
# ['moderate', 'drinking', 'reduces', 'men', 'is', 'heart', 'attack', 'risk']
# -----------
# Tom Cruise and Katie Holmes set wedding date
#
# ['tom', 'cruise', 'and', 'katie', 'holmes', 'set', 'wedding', 'date']
# -----------
# Kidnapped AP photographer freed in Gaza
#
# ['kidnapped', 'ap', 'photographer', 'freed', 'in', 'gaza']
# -----------
# Bush Insists Troops Stay in Iraq, Predicts Midterm Victory
#
# ['bush', 'insists', 'troops', 'stay', 'in', 'iraq', 'predicts', 'midterm', 'victory']
# -----------
# Hurricane Paul Weakens To Tropical Storm
#
# ['hurricane', 'paul', 'weakens', 'to', 'tropical', 'storm']
# -----------
# UK announces immigration restrictions
#
# ['uk', 'announces', 'immigration', 'restrictions']
# -----------
# Three found alive from missing Russian ship -report
#
# ['three', 'found', 'alive', 'from', 'missing', 'russian', 'ship', 'report']
# -----------
# Poison Pill to Swallow: Hawks Hurting After Loss to Vikes
#
# ['poison', 'pill', 'to', 'swallow', 'hawks', 'hurting', 'after', 'loss', 'to', 'vikes']
# -----------
# Injured Marathon Winner Leaves Hospital
#
# ['injured', 'marathon', 'winner', 'leaves', 'hospital']
# -----------
# Hacker unlocks Apple music download protection
#
# ['hacker', 'unlocks', 'apple', 'music', 'download', 'protection']
# -----------
# Spanish journalist seized in Gaza
#
# ['spanish', 'journalist', 'seized', 'in', 'gaza']
# -----------
# Sudan urges UN to replace its special envoy
#
# ['sudan', 'urges', 'un', 'to', 'replace', 'its', 'special', 'envoy']
# -----------
# Resolution approved for international games
#
# ['resolution', 'approved', 'for', 'international', 'games']
# -----------
# Pair of Satellites Will Document Sun in 3-D
#
# ['pair', 'of', 'satellites', 'will', 'document', 'sun', 'in', '3', 'would']
# -----------
# Martian Life Could Have Evaded Detection by Viking Landers
#
# ['martian', 'life', 'could', 'have', 'evaded', 'detection', 'by', 'viking', 'landers']
# -----------
# The sweet tune of an anniversary
#
# ['the', 'sweet', 'tune', 'of', 'an', 'anniversary']
# -----------
# Did Viking Probes Miss Life on Mars?
#
# ['did', 'viking', 'probes', 'miss', 'life', 'on', 'mars']
# -----------
# Diplomat acknowledges US arrogance in Iraq
#
# ['diplomat', 'acknowledges', 'us', 'arrogance', 'in', 'iraq']
# -----------
# More Human Remains Found at Ground Zero
#
# ['more', 'human', 'remains', 'found', 'at', 'ground', 'zero']
# -----------
# How to Prevent Iraq From Getting Even Worse
#
# ['how', 'to', 'prevent', 'iraq', 'from', 'getting', 'even', 'worse']
# -----------
# Tensions as Hungary marks uprising
#
# ['tensions', 'as', 'hungary', 'marks', 'uprising']
# -----------
# Stanford study warns of Internet addiction
#
# ['stanford', 'study', 'warns', 'of', 'internet', 'addiction']
# -----------
# No evidence of ice reserves on the moon
#
# ['no', 'evidence', 'of', 'ice', 'reserves', 'on', 'the', 'moon']
# -----------
# A Picture and A Thousand Words
#
# ['a', 'picture', 'and', 'a', 'thousand', 'words']
# -----------
# Parachutist dies at bridge-jump festival
#
# ['parachutist', 'dies', 'at', 'bridge', 'jump', 'festival']
# -----------
# US Troops Killed In October In Iraq
#
# ['us', 'troops', 'killed', 'in', 'october', 'in', 'iraq']
# -----------
# Chefs not counting calories, study finds
#
# ['chefs', 'not', 'counting', 'calories', 'study', 'finds']
# -----------
# Deaths linked to flu vaccine
#
# ['deaths', 'linked', 'to', 'flu', 'vaccine']
# -----------
# Perfect lives lose their focus
#
# ['perfect', 'lives', 'lose', 'their', 'focus']
# -----------
# Bread-Heavy Diet Linked to Kidney Cancer
#
# ['bread', 'heavy', 'diet', 'linked', 'to', 'kidney', 'cancer']
# -----------
# Beating poverty in a small way
#
# ['beating', 'poverty', 'in', 'a', 'small', 'way']
# -----------
# Israel insists on Lebanon overflights
#
# ['israel', 'insists', 'on', 'lebanon', 'overflights']
# -----------
# Britain to restrict immigrants from new EU members
#
# ['britain', 'to', 'restrict', 'immigrants', 'from', 'new', 'eu', 'members']
# -----------
# Confusion Reigns In the Expanding Digital World
#
# ['confusion', 'reigns', 'in', 'the', 'expanding', 'digital', 'world']
# -----------
# Game on! London exhibition celebrates the history of video games
#
# ['game', 'on', 'london', 'exhibition', 'celebrates', 'the', 'history', 'of', 'video', 'games']
# -----------
# Making peace from victory over poverty
#
# ['making', 'peace', 'from', 'victory', 'over', 'poverty']
# -----------
# Marine killed in fighting west of Baghdad
#
# ['marine', 'killed', 'in', 'fighting', 'west', 'of', 'baghdad']
# -----------
# Scientists create first cloaking device
#
# ['scientists', 'create', 'first', 'cloaking', 'device']
# -----------
# Amateur rocket scientists reach for space
#
# ['amateur', 'rocket', 'scientists', 'reach', 'for', 'space']
# -----------
# Confusion Reigns In the Expanding Digital World
#
# ['confusion', 'reigns', 'in', 'the', 'expanding', 'digital', 'world']
# -----------
# Deaths linked to flu vaccine
#
# ['deaths', 'linked', 'to', 'flu', 'vaccine']
# -----------
# Israel admits using phosphorous shells in Lebanon
#
# ['israel', 'admits', 'using', 'phosphorous', 'shells', 'in', 'lebanon']
# -----------
# 4th person dies after receiving flu shot
#
# ['4th', 'person', 'dies', 'after', 'receiving', 'flu', 'shot']
# -----------
# Police and shoppers targeted in growing Iraq violence
#
# ['police', 'and', 'shoppers', 'targeted', 'in', 'growing', 'iraq', 'violence']
# -----------
# Scientists discover miracle in the depths
#
# ['scientists', 'discover', 'miracle', 'in', 'the', 'depths']
# -----------
# Doctors Seeing Patients Who Think They're Internet Addicted
#
# ['doctors', 'seeing', 'patients', 'who', 'think', 'they', 'are', 'internet', 'addicted']
# -----------
# China launches two satellites into orbit
#
# ['china', 'launches', 'two', 'satellites', 'into', 'orbit']
# -----------
# Vegetables May Boost Brain Power in Older Adults
#
# ['vegetables', 'may', 'boost', 'brain', 'power', 'in', 'older', 'adults']
# -----------
# Hurricane Paul nears Category 3 status
#
# ['hurricane', 'paul', 'nears', 'category', '3', 'status']
# -----------
# Russian ship sinks, 18-member crew missing
#
# ['russian', 'ship', 'sinks', '18', 'member', 'crew', 'missing']
# -----------
# Iran's president urges higher birth rate
#
# ['iran', 'is', 'president', 'urges', 'higher', 'birth', 'rate']
# -----------
# Apple set for massive market gains
#
# ['apple', 'set', 'for', 'massive', 'market', 'gains']
# -----------
# Tumor Types May Explain Survival Rates for Cancer
#
# ['tumor', 'types', 'may', 'explain', 'survival', 'rates', 'for', 'cancer']
# -----------
# Routine mission turns into hunt for missing comrade
#
# ['routine', 'mission', 'turns', 'into', 'hunt', 'for', 'missing', 'comrade']
# -----------
# Bad weather slows S.Korean search for Russian ship
#
# ['bad', 'weather', 'slows', 'is', 'korean', 'search', 'for', 'russian', 'ship']
# -----------
# Tailors and housewives busy as Muslims celebrate Eid
#
# ['tailors', 'and', 'housewives', 'busy', 'as', 'muslims', 'celebrate', 'eid']
# -----------
# Active peace brings the promise of development
#
# ['active', 'peace', 'brings', 'the', 'promise', 'of', 'development']
# -----------
# Abbas condemns Israeli massacre in northern Gaza Strip
#
# ['abbas', 'condemns', 'israeli', 'massacre', 'in', 'northern', 'gaza', 'strip']
# -----------
# Bangladesh ferry sinks, 15 dead
#
# ['bangladesh', 'ferry', 'sinks', '15', 'dead']
# -----------
# Bucs find a new kick in life
#
# ['bucs', 'find', 'a', 'new', 'kick', 'in', 'life']
# -----------
# Google to unveil election mashup
#
# ['google', 'to', 'unveil', 'election', 'mashup']
# -----------
# Police warn of child exploitation online
#
# ['police', 'warn', 'of', 'child', 'exploitation', 'online']
# -----------
# Breast Cancer Awareness is Important
#
# ['breast', 'cancer', 'awareness', 'is', 'important']
# -----------
# Hungary police tackle violent protestors
#
# ['hungary', 'police', 'tackle', 'violent', 'protestors']
# -----------
# Three drivers had reason to be proud in Brazil
#
# ['three', 'drivers', 'had', 'reason', 'to', 'be', 'proud', 'in', 'brazil']
# -----------
# Celebrities Protest Malibu Gas Facility
#
# ['celebrities', 'protest', 'malibu', 'gas', 'facility']
# -----------
# Lebo: A life lived on the edge
#
# ['lebo', 'a', 'life', 'lived', 'on', 'the', 'edge']
# -----------
# Presto! He's Batman, then magic man
#
# ['presto', 'he', 'is', 'batman', 'then', 'magic', 'man']
# -----------
# Heavy use of mobile phones can make men infertile, scientists say
#
# ['heavy', 'use', 'of', 'mobile', 'phones', 'can', 'make', 'men', 'infertile', 'scientists', 'say']
# -----------
# Russian ship sinks in Pacific
#
# ['russian', 'ship', 'sinks', 'in', 'pacific']
# -----------
# China Successfully Launches Two Satellites
#
# ['china', 'successfully', 'launches', 'two', 'satellites']
# -----------
# Prestige has magic touch
#
# ['prestige', 'has', 'magic', 'touch']
# -----------
# Lies, damned lies, and divorce
#
# ['lies', 'damned', 'lies', 'and', 'divorce']
# -----------
# Manning inspires Giants to victory in Dallas
#
# ['manning', 'inspires', 'giants', 'to', 'victory', 'in', 'dallas']
# -----------
# Riot warning for France suburbs
#
# ['riot', 'warning', 'for', 'france', 'suburbs']
# -----------
# Full recovery expected for marathon winner
#
# ['full', 'recovery', 'expected', 'for', 'marathon', 'winner']
# -----------
# Sony apologises for global battery recall
#
# ['sony', 'apologises', 'for', 'global', 'battery', 'recall']
# -----------
# Questions on credit card safety
#
# ['questions', 'on', 'credit', 'card', 'safety']
# -----------
# Budapest calm after night of violent protests
#
# ['budapest', 'calm', 'after', 'night', 'of', 'violent', 'protests']
# -----------
# Vegetables May Boost Brain Power in Older Adults
#
# ['vegetables', 'may', 'boost', 'brain', 'power', 'in', 'older', 'adults']
# -----------
# Report criticises US press freedoms
#
# ['report', 'criticises', 'us', 'press', 'freedoms']
# -----------
# French suburb riots could resume
#
# ['french', 'suburb', 'riots', 'could', 'resume']
# -----------
# Photographer kidnapping condemned
#
# ['photographer', 'kidnapping', 'condemned']
# -----------
# Photographer kidnapped in Gaza
#
# ['photographer', 'kidnapped', 'in', 'gaza']
# -----------
# Baseball: Rogers enjoys his muddied streak
#
# ['baseball', 'rogers', 'enjoys', 'his', 'muddied', 'streak']
# -----------
# Cultural revolutionary, the iPod is five
#
# ['cultural', 'revolutionary', 'the', 'ipod', 'is', 'five']
# -----------
# Life on Mars? Maybe We Missed It
#
# ['life', 'on', 'mars', 'maybe', 'we', 'missed', 'it']
# -----------
# Three found alive from missing Russian ship -report
#
# ['three', 'found', 'alive', 'from', 'missing', 'russian', 'ship', 'report']
# -----------
# Moderate drinking reduces men's heart attack risk
#
# ['moderate', 'drinking', 'reduces', 'men', 'is', 'heart', 'attack', 'risk']
# -----------
# The sweet tune of an anniversary
#
# ['the', 'sweet', 'tune', 'of', 'an', 'anniversary']
# -----------
# Inconvenient truths
#
# ['inconvenient', 'truths']
# -----------
# Dating difficult for Harry Potter
#
# ['dating', 'difficult', 'for', 'harry', 'potter']
# -----------
# Students lose their rite of passage
#
# ['students', 'lose', 'their', 'rite', 'of', 'passage']
# -----------
# Putin vows to tackle illegal immigration
#
# ['putin', 'vows', 'to', 'tackle', 'illegal', 'immigration']
# -----------
# Ottawa must redefine 'terror'
#
# ['ottawa', 'must', 'redefine', 'terror']
# -----------
# Britain to Limit Workers from Romania, Bulgaria
#
# ['britain', 'to', 'limit', 'workers', 'from', 'romania', 'bulgaria']
# -----------
# Top General Optimistic on Iraq
#
# ['top', 'general', 'optimistic', 'on', 'iraq']
# -----------
# Kim Osorio Wins Sexual Harrassment Suit Against The Source
#
# ['kim', 'osorio', 'wins', 'sexual', 'harrassment', 'suit', 'against', 'the', 'source']
# -----------
# Silly and substantial
#
# ['silly', 'and', 'substantial']
# -----------
# Official laughs for Borat
#
# ['official', 'laughs', 'for', 'borat']
# -----------
# Speaker Hastert testifies before panel probing sex scandal
#
# ['speaker', 'hastert', 'testifies', 'before', 'panel', 'probing', 'sex', 'scandal']
# -----------
# On Educating Sexes Separately
#
# ['on', 'educating', 'sexes', 'separately']
# -----------
# Tom Cruise and Katie Holmes set wedding date
#
# ['tom', 'cruise', 'and', 'katie', 'holmes', 'set', 'wedding', 'date']
# -----------
# Martian Life Could Have Evaded Detection by Viking Landers
#
# ['martian', 'life', 'could', 'have', 'evaded', 'detection', 'by', 'viking', 'landers']
# -----------
# Ukraine gas deal marred by fears
#
# ['ukraine', 'gas', 'deal', 'marred', 'by', 'fears']
# -----------
# Marathon victory comes at heavy cost
#
# ['marathon', 'victory', 'comes', 'at', 'heavy', 'cost']
# -----------
# College tuition continues climbing
#
# ['college', 'tuition', 'continues', 'climbing']
# -----------
# German paper shows soldiers desecrating skull
#
# ['german', 'paper', 'shows', 'soldiers', 'desecrating', 'skull']
# -----------
# War is close, Ethiopia tells Somali rebels
#
# ['war', 'is', 'close', 'ethiopia', 'tells', 'somali', 'rebels']
# -----------
# Advantage Cardinals with Suppan in Game 4
#
# ['advantage', 'cardinals', 'with', 'suppan', 'in', 'game', '4']
# -----------
# NASA spacecraft to measure Sun
#
# ['nasa', 'spacecraft', 'to', 'measure', 'sun']
# -----------
# Sony Hates Europeans, Will Prevent The Importing of PS3
#
# ['sony', 'hates', 'europeans', 'will', 'prevent', 'the', 'importing', 'of', 'ps3']
# -----------
# Flu Vaccine Appears Safe for Young Children
#
# ['flu', 'vaccine', 'appears', 'safe', 'for', 'young', 'children']
# -----------
# Google To Launch Yet Another Search Tool
#
# ['google', 'to', 'launch', 'yet', 'another', 'search', 'tool']
# -----------
# Tropical Storm Paul's Outer Bands Hit Mexico's Baja California
#
# ['tropical', 'storm', 'paul', 'is', 'outer', 'bands', 'hit', 'mexico', 'is', 'baja', 'california']
# -----------
# Israeli Bomblets Plague Lebanon
#
# ['israeli', 'bomblets', 'plague', 'lebanon']
# -----------
# New Indonesia Calamity, a Mud Bath, Is Man-Made
#
# ['new', 'indonesia', 'calamity', 'a', 'mud', 'bath', 'is', 'man', 'made']
# -----------
# U.S. Weighs Sanctions Against North Korea
#
# ['u', 'is', 'weighs', 'sanctions', 'against', 'north', 'korea']
# -----------
# Rice, in Baghdad, Insists That Iraqis Are
#
# ['rice', 'in', 'baghdad', 'insists', 'that', 'iraqis', 'are']
# -----------
# Senator Says U.S. Should Rethink Iraq Strategy
#
# ['senator', 'says', 'u', 'is', 'should', 'rethink', 'iraq', 'strategy']
# -----------
# German Chief Forges Accord on Financing Health Care
#
# ['german', 'chief', 'forges', 'accord', 'on', 'financing', 'health', 'care']
# -----------
# Turkish Writers Say Efforts to Stifle Speech May Backfire
#
# ['turkish', 'writers', 'say', 'efforts', 'to', 'stifle', 'speech', 'may', 'backfire']
# -----------
# Kurdish Lawmaker Killed in an Attack in Baghdad
#
# ['kurdish', 'lawmaker', 'killed', 'in', 'an', 'attack', 'in', 'baghdad']
# -----------
# Anti-U.S. Attack Videos Spread on the Internet
#
# ['anti', 'u', 'is', 'attack', 'videos', 'spread', 'on', 'the', 'internet']
# -----------
# Women Face Greatest Threat of Violence at Home, Study Finds
#
# ['women', 'face', 'greatest', 'threat', 'of', 'violence', 'at', 'home', 'study', 'finds']
# -----------
# Appeal by Chinese Researcher for Times May Soon Be Heard
#
# ['appeal', 'by', 'chinese', 'researcher', 'for', 'times', 'may', 'soon', 'be', 'heard']
# -----------
# Brazil Air Force Cites Faults and Confusion in Fatal Crash
#
# ['brazil', 'air', 'force', 'cites', 'faults', 'and', 'confusion', 'in', 'fatal', 'crash']
# -----------
# A Mix of Oil and Environmentalism
#
# ['a', 'mix', 'of', 'oil', 'and', 'environmentalism']
# -----------
# Immigrants and French Reach Deal in Standoff
#
# ['immigrants', 'and', 'french', 'reach', 'deal', 'in', 'standoff']
# -----------
# Genghis Khan Beer? Mongolia Grimaces
#
# ['genghis', 'khan', 'beer', 'mongolia', 'grimaces']
# -----------
# Dead Bachelors in Remote China Still Find Wives
#
# ['dead', 'bachelors', 'in', 'remote', 'china', 'still', 'find', 'wives']
# -----------
# Managua Journal: Hold the Mojito and Margarita, Nicaragua Has el Macu
#
# ['managua', 'journal', 'hold', 'the', 'mojito', 'and', 'margarita', 'nicaragua', 'has', 'el', 'macu']
# -----------
# Paris Journal: Smoking No Longer Tres Chic in France
#
# ['paris', 'journal', 'smoking', 'no', 'longer', 'tres', 'chic', 'in', 'france']
# -----------
# An Old Letter Casts Doubts on Iran's Goal for Uranium
#
# ['an', 'old', 'letter', 'casts', 'doubts', 'on', 'iran', 'is', 'goal', 'for', 'uranium']
# -----------
# U.S. Warns North Koreans About Nuclear Test
#
# ['u', 'is', 'warns', 'north', 'koreans', 'about', 'nuclear', 'test']
# -----------
# Global Sludge Ends in Tragedy for Ivory Coast
#
# ['global', 'sludge', 'ends', 'in', 'tragedy', 'for', 'ivory', 'coast']
# -----------
# Equipment on Plane in Brazil Collision May Have Been Faulty
#
# ['equipment', 'on', 'plane', 'in', 'brazil', 'collision', 'may', 'have', 'been', 'faulty']
# -----------
# New Indonesia Calamity, a Mud Bath, Is Man-Made
#
# ['new', 'indonesia', 'calamity', 'a', 'mud', 'bath', 'is', 'man', 'made']
# -----------
# Iraqi Journalists Add Laws to List of Dangers
#
# ['iraqi', 'journalists', 'add', 'laws', 'to', 'list', 'of', 'dangers']
# -----------
# U.N. Force Is Treading Lightly on Lebanese Soil
#
# ['u', 'n', 'force', 'is', 'treading', 'lightly', 'on', 'lebanese', 'soil']
# -----------
# Cleric Said to Lose Reins Over Part of Iraqi Militia
#
# ['cleric', 'said', 'to', 'lose', 'reins', 'over', 'part', 'of', 'iraqi', 'militia']
# -----------
# Citing Spy Agencies' Study, Democrats Seek Iraq Changes
#
# ['citing', 'spy', 'agencies', 'study', 'democrats', 'seek', 'iraq', 'changes']
# -----------
# Opera Canceled Over a Depiction of Muhammad
#
# ['opera', 'canceled', 'over', 'a', 'depiction', 'of', 'muhammad']
# -----------
# Military Officials Add to U.S. Criticism of Iraq's Government
#
# ['military', 'officials', 'add', 'to', 'u', 'is', 'criticism', 'of', 'iraq', 'is', 'government']
# -----------
# Teacher in Hiding After Attack on Islam Stirs Threats
#
# ['teacher', 'in', 'hiding', 'after', 'attack', 'on', 'islam', 'stirs', 'threats']
# -----------
# Combative Bush Releases Parts of Terror Study
#
# ['combative', 'bush', 'releases', 'parts', 'of', 'terror', 'study']
# -----------
# Growing Unarmed Battalion in Qaeda Army Is Using Internet to Get the Message Out
#
# ['growing', 'unarmed', 'battalion', 'in', 'qaeda', 'army', 'is', 'using', 'internet', 'to', 'get', 'the', 'message', 'out']
# -----------
# Iraqi Linked to Sunni Bloc Is Held in Plot, Military Says
#
# ['iraqi', 'linked', 'to', 'sunni', 'bloc', 'is', 'held', 'in', 'plot', 'military', 'says']
# -----------
# Seduced by Snacks? No, Not You
#
# ['seduced', 'by', 'snacks', 'no', 'not', 'you']
# -----------
# Friends for Life: An Emerging Biology of Emotional Healing
#
# ['friends', 'for', 'life', 'an', 'emerging', 'biology', 'of', 'emotional', 'healing']
# -----------
# Alzheimer's Drugs Offer No Help, Study Finds
#
# ['alzheimer', 'is', 'drugs', 'offer', 'no', 'help', 'study', 'finds']
# -----------
# Across Europe, Worries on Islam Spread to Center
#
# ['across', 'europe', 'worries', 'on', 'islam', 'spread', 'to', 'center']
# -----------
# Cooking Defines Sephardic Jews at Sukkot
#
# ['cooking', 'defines', 'sephardic', 'jews', 'at', 'sukkot']
# -----------
# Fitness: Bodies in Motion, Clean and Sober
#
# ['fitness', 'bodies', 'in', 'motion', 'clean', 'and', 'sober']
# -----------
# In God's Name: Religion-Based Tax Breaks: Housing to Paychecks to Books
#
# ['in', 'god', 'is', 'name', 'religion', 'based', 'tax', 'breaks', 'housing', 'to', 'paychecks', 'to', 'books']
# -----------
# Yankee Dies in Plane Crash, Official Says
#
# ['yankee', 'dies', 'in', 'plane', 'crash', 'official', 'says']
# -----------
# An Elephant Crackup?
#
# ['an', 'elephant', 'crackup']
# -----------
# With YouTube, Grad Student Hits Jackpot Again
#
# ['with', 'youtube', 'grad', 'student', 'hits', 'jackpot', 'again']
# -----------
# Dow flirts with record highs again
#
# ['dow', 'flirts', 'with', 'record', 'highs', 'again']
# -----------
# Tropical Storm Isaac forms in Atlantic
#
# ['tropical', 'storm', 'isaac', 'forms', 'in', 'atlantic']
# -----------
# New Iraq terror tape calls for abducting foreigners
#
# ['new', 'iraq', 'terror', 'tape', 'calls', 'for', 'abducting', 'foreigners']
# -----------
# 'Deep regret' for ex-HP exec
#
# ['deep', 'regret', 'for', 'ex', 'hp', 'exec']
# -----------
# 'Opportunity' knocks on geologist's dream crater
#
# ['opportunity', 'knocks', 'on', 'geologist', 'is', 'dream', 'crater']
# -----------
# Squirrel jumps boy in park; rabies suspected
#
# ['squirrel', 'jumps', 'boy', 'in', 'park', 'rabies', 'suspected']
# -----------
# Girl left comatose after dental visit dies
#
# ['girl', 'left', 'comatose', 'after', 'dental', 'visit', 'dies']
# -----------
# Porn star candidate campaigns on campus
#
# ['porn', 'star', 'candidate', 'campaigns', 'on', 'campus']
# -----------
# School ends football season after 0-4 start
#
# ['school', 'ends', 'football', 'season', 'after', '0', '4', 'start']
# -----------
# Charlie Sheen to become highest-paid sitcom star
#
# ['charlie', 'sheen', 'to', 'become', 'highest', 'paid', 'sitcom', 'star']
# -----------
# Jon Stewart mocks benefits of CNN's I
#
# ['jon', 'stewart', 'mocks', 'benefits', 'of', 'cnn', 'is', 'i']
# -----------
# Ashton Kutcher tells secret to Ryan Seacrest
#
# ['ashton', 'kutcher', 'tells', 'secret', 'to', 'ryan', 'seacrest']
# -----------
# Nails-on-chalkboard study earns Ig
#
# ['nails', 'on', 'chalkboard', 'study', 'earns', 'ig']
# -----------
# Gunman 'fine' before shooting
#
# ['gunman', 'fine', 'before', 'shooting']
# -----------
# Marijuana may stave off Alzheimer's
#
# ['marijuana', 'may', 'stave', 'off', 'alzheimer', 'is']
# -----------
# Kentucky seeks alcohol huffing ban
#
# ['kentucky', 'seeks', 'alcohol', 'huffing', 'ban']
# -----------
# Toddler died from tainted spinach
#
# ['toddler', 'died', 'from', 'tainted', 'spinach']
# -----------
# Judge dismisses Karr's porn case
#
# ['judge', 'dismisses', 'karr', 'is', 'porn', 'case']
# -----------
# 10 die in 22-hour Kashmir standoff
#
# ['10', 'die', 'in', '22', 'hour', 'kashmir', 'standoff']
# -----------
# Slain Amish girls laid to rest
#
# ['slain', 'amish', 'girls', 'laid', 'to', 'rest']
# -----------
# 5,000 flee plant fire
#
# ['5', '000', 'flee', 'plant', 'fire']
# -----------
# Cher auction fetches double pre-sale estimates
#
# ['cher', 'auction', 'fetches', 'double', 'pre', 'sale', 'estimates']
# -----------
# Stars scuffle on 'Grey's Anatomy'
#
# ['stars', 'scuffle', 'on', 'grey', 'is', 'anatomy']
# -----------
# Probe under way in Yankee crash
#
# ['probe', 'under', 'way', 'in', 'yankee', 'crash']
# -----------
# Amish schoolhouse torn down
#
# ['amish', 'schoolhouse', 'torn', 'down']
# -----------
# Warner will not run in '08
#
# ['warner', 'will', 'not', 'run', 'in', '08']
# -----------
# Reid land deal under scrutiny
#
# ['reid', 'land', 'deal', 'under', 'scrutiny']
# -----------
# Flooding washes out road to Valdez, Alaska
#
# ['flooding', 'washes', 'out', 'road', 'to', 'valdez', 'alaska']
# -----------
# Briton admits U.S. bomb plot role
#
# ['briton', 'admits', 'u', 'is', 'bomb', 'plot', 'role']
# -----------
# Commentary: Minutemen have a right to be idiotic
#
# ['commentary', 'minutemen', 'have', 'a', 'right', 'to', 'be', 'idiotic']
# -----------
# Madonna files adoption papers
#
# ['madonna', 'files', 'adoption', 'papers']
# -----------
# Gunmen kill 9 at Iraqi TV station
#
# ['gunmen', 'kill', '9', 'at', 'iraqi', 'tv', 'station']
# -----------
# Hastert sorry for scandal but not quitting
#
# ['hastert', 'sorry', 'for', 'scandal', 'but', 'not', 'quitting']
# -----------
# Ex-JonBenet suspect: Child porn case dropped
#
# ['ex', 'jonbenet', 'suspect', 'child', 'porn', 'case', 'dropped']
# -----------
# Waste plant fire forces 5,000 to evacuate
#
# ['waste', 'plant', 'fire', 'forces', '5', '000', 'to', 'evacuate']
# -----------
# Toddler died from E. coli tainted spinach
#
# ['toddler', 'died', 'from', 'e', 'coli', 'tainted', 'spinach']
# -----------
# Disturbing finds in child sex raids
#
# ['disturbing', 'finds', 'in', 'child', 'sex', 'raids']
# -----------
# Magazine lists women who had abortions
#
# ['magazine', 'lists', 'women', 'who', 'had', 'abortions']
# -----------
# Pot smokers may avoid Alzheimer's, study says
#
# ['pot', 'smokers', 'may', 'avoid', 'alzheimer', 'is', 'study', 'says']
# -----------
# Student starts white men's club on campus
#
# ['student', 'starts', 'white', 'men', 'is', 'club', 'on', 'campus']
# -----------
# Kentucky wants to ban alcohol inhalers
#
# ['kentucky', 'wants', 'to', 'ban', 'alcohol', 'inhalers']
# -----------
# Peter Pan flies into chapter two
#
# ['peter', 'pan', 'flies', 'into', 'chapter', 'two']
# -----------
# Teen repellent inventor wins infamous prize
#
# ['teen', 'repellent', 'inventor', 'wins', 'infamous', 'prize']
# -----------
# Cher's dress, car, bed have new owners
#
# ['cher', 'is', 'dress', 'car', 'bed', 'have', 'new', 'owners']
# -----------
# Dow hits new record, eyes 12,000
#
# ['dow', 'hits', 'new', 'record', 'eyes', '12', '000']
# -----------
# Ex-Virginia gov not running for president
#
# ['ex', 'virginia', 'gov', 'not', 'running', 'for', 'president']
# -----------
# Yankee pitcher's pilot log found
#
# ['yankee', 'pitcher', 'is', 'pilot', 'log', 'found']
# -----------
# Dem leader's $1 million land deal under scrutiny
#
# ['dem', 'leader', 'is', '1', 'million', 'land', 'deal', 'under', 'scrutiny']
# -----------
# Dad locked up son, watched on TV, police say
#
# ['dad', 'locked', 'up', 'son', 'watched', 'on', 'tv', 'police', 'say']
# -----------
# Navarrette: Minutemen have a right to be idiotic
#
# ['navarrette', 'minutemen', 'have', 'a', 'right', 'to', 'be', 'idiotic']
# -----------
# Pit bulls jump miniature pony, leave her bloody
#
# ['pit', 'bulls', 'jump', 'miniature', 'pony', 'leave', 'her', 'bloody']
# -----------
# Alaska town cut off from rest of state by flood
#
# ['alaska', 'town', 'cut', 'off', 'from', 'rest', 'of', 'state', 'by', 'flood']
# -----------
# Trailblazing trio protects City by the Bay
#
# ['trailblazing', 'trio', 'protects', 'city', 'by', 'the', 'bay']
# -----------
# Madonna files adoption papers in Malawi
#
# ['madonna', 'files', 'adoption', 'papers', 'in', 'malawi']
# -----------
# 'Dr. McDreamy' choked in 'Grey's' scuffle
#
# ['dr', 'mcdreamy', 'choked', 'in', 'grey', 'is', 'scuffle']
# -----------
# $10,000 poetry prize awarded
#
# ['10', '000', 'poetry', 'prize', 'awarded']
# -----------
# Las Vegas honour for tiger pair
#
# ['las', 'vegas', 'honour', 'for', 'tiger', 'pair']
# -----------
# UK characters boosting box office
#
# ['uk', 'characters', 'boosting', 'box', 'office']
# -----------
# Cher items snapped up at auction
#
# ['cher', 'items', 'snapped', 'up', 'at', 'auction']
# -----------
# Griffiths scorns Withnail 'play'
#
# ['griffiths', 'scorns', 'withnail', 'play']
# -----------
# Lily Allen wins web music award
#
# ['lily', 'allen', 'wins', 'web', 'music', 'award']
# -----------
# Costner appeals in casino wrangle
#
# ['costner', 'appeals', 'in', 'casino', 'wrangle']
# -----------
# Beyonce copyright claim rejected
#
# ['beyonce', 'copyright', 'claim', 'rejected']
# -----------
# Cohn gunman jailed for 36 years
#
# ['cohn', 'gunman', 'jailed', 'for', '36', 'years']
# -----------
# Melua's deep sea gig sets record
#
# ['melua', 'is', 'deep', 'sea', 'gig', 'sets', 'record']
# -----------
# Sri Lanka clashes kill 129 troops
#
# ['sri', 'lanka', 'clashes', 'kill', '129', 'troops']
# -----------
# Gunmen kill 11 in Iraq TV raid
#
# ['gunmen', 'kill', '11', 'in', 'iraq', 'tv', 'raid']
# -----------
# Italy drops Sicily bridge plans
#
# ['italy', 'drops', 'sicily', 'bridge', 'plans']
# -----------
# Amish killings school demolished
#
# ['amish', 'killings', 'school', 'demolished']
# -----------
# Pamuk wins Nobel Literature prize
#
# ['pamuk', 'wins', 'nobel', 'literature', 'prize']
# -----------
# Madonna adoption bid approved
#
# ['madonna', 'adoption', 'bid', 'approved']
# -----------
# Man admits UK-US terror bomb plot
#
# ['man', 'admits', 'uk', 'us', 'terror', 'bomb', 'plot']
# -----------
# Who are you calling fat?
#
# ['who', 'are', 'you', 'calling', 'fat']
# -----------
# ['mortar', 'assault', 'leaves', 'at', 'least', '18', 'dead']

# %% [markdown]
# Les't determine the total and average number of words in each sentences

# %%
def maximum(sent):
    numWords = []
    for s in sent:
        counter = len(s)
        numWords.append(counter) 
    maxLengh = int(sum(numWords)/len(numWords))
    print("Average: ", maxLengh)
    return numWords,maxLengh
numWords,maxSeqLength = maximum(c_sent)
# Out:
# Average:  6

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
def histograma(numWords):
    plt.hist(numWords, 50)
    plt.xlabel('Sequence Length')
    plt.ylabel('Frequency')
    plt.axis([0, 30, 0, 80])
    plt.show()
histograma(numWords)

# %% [markdown]
# Converting each sentence into a vector and adding it into a matrix of 'ids'

# %%
def integerSenteces(sent,maximum):
    i = 0
    embbeding = 0
    matrix = np.zeros((len(sent), maximum)) #250 X 6 (numEjem X Maximun)
    for s in sent:
        vector = np.zeros((maximum), dtype='int32')
        bound = maximum
        if len(s) < maximum:
            bound = len(s)    

        for token in range(0,bound): #No encuentra macu, porque la corta
            if s[token] not in wordsList:
                vector[token] = embbeding # ???
                print(s[token],"*---*",sent[i])
            else:
                vector[token] = (wordsList.index(s[token]))
                embbeding = vector[token]
        matrix[i] = (vector)
        i += 1
    return matrix

# %%
X_train = integerSenteces(c_sent,maxSeqLength) 
print("Sentences integer representation: ",(X_train.shape))
print("Sentences: ",len(c_sent))
print("Integer format",X_train[249])
print("Normal format",c_sent[249])
# Out:
# Sentences integer representation:  (250, 6)
# Sentences:  250
# Integer format [  38.   32.   81. 1525. 3747.    0.]
# Normal format ['who', 'are', 'you', 'calling', 'fat']

# %% [markdown]
# Writting the labels : Y train Labels

# %%
def toLabels(emo):
    Y = np.zeros((len(emo), 5))
    for e in range(0,len(emo)):
        vector = np.zeros((5))
        vector[(emo[e] % 6) - 1] = 1 
        Y[e] = vector
    return Y
 
Y_train = toLabels(emotions)
print("Y_train: ",Y_train.shape," Num Ejem X 5 clases")
print("X_train: ",X_train.shape," Num Ejem X Maximun Lengh")
# Out:
# Y_train:  (250, 5)  Num Ejem X 5 clases
# X_train:  (250, 6)  Num Ejem X Maximun Lengh

# %% [markdown]
# Preparing Test Data

# %%
#Separamos Sentences && ids
dataset = "Affective_Text/affectivetext_test.xml"
sent_test , id_test = extract(dataset)
print(id_test[0]," ",sent_test[0])

#Escogemos the most hight emotion
dataset = "Affective_Text/affectivetext_test.emotions.gold"
test_emotions = extract_emo(dataset)
print(test_emotions)

#Limpiamos las Sentences
c_sent_test = sent_test[:]    
c_sent_test = cleaner(c_sent_test)
print(c_sent_test[0])

#Calculamos la oracion promedio
test_numWords,test_maxSeqLength = maximum(c_sent_test)
histograma(test_numWords)

#Convertimos Sentences a su representacion en Integers
X_test = integerSenteces(c_sent_test,test_maxSeqLength) 
print("Sentences integer representation: ",(X_test.shape))
print("Sentences: ",len(c_sent_test))
print("Integer format",X_test[0])
print("Normal format",c_sent_test[0])

#Transformamos cada emocion {1,2,3,4,5} a one-hot vectors
Y_test = toLabels(test_emotions)
print("Y_train: ",Y_test.shape," Num Ejem X 5 clases")
print("X_train: ",X_test.shape," Num Ejem X Maximun Lengh")
# Out:
# 500   Test to predict breast cancer relapse is approved
#
# [4, 5, 5, 3, 5, 0, 5, 2, 4, 4, 5, 5, 1, 5, 0, 3, 5, 0, 4, 5, 0, 4, 1, 1, 5, 5, 3, 5, 1, 5, 4, 1, 5, 2, 3, 5, 4, 4, 3, 1, 3, 3, 4, 4, 2, 3, 0, 4, 5, 0, 0, 1, 3, 2, 4, 5, 3, 5, 2, 3, 2, 1, 1, 2, 3, 4, 3, 3, 5, 2, 0, 5, 0, 5, 2, 3, 1, 0, 2, 0, 3, 0, 2, 2, 2, 4, 3, 5, 3, 4, 2, 2, 3, 3, 5, 2, 5, 5, 2, 5, 5, 2, 5, 2, 4, 4, 5, 3, 4, 2, 5, 5, 5, 3, 3, 0, 0, 0, 3, 3, 1, 2, 2, 2, 2, 5, 5, 3, 3, 4, 2, 3, 2, 5, 2, 3, 5, 1, 5, 5, 1, 3, 3, 0, 1, 1, 0, 3, 2, 3, 5, 5, 4, 0, 3, 1, 2, 2, 2, 5, 3, 5, 5, 5, 4, 2, 3, 2, 4, 5, 5, 2, 2, 5, 4, 3, 1, 2, 4, 2, 3, 2, 3, 5, 5, 3, 1, 0, 5, 0, 4, 4, 0, 4, 3, 2, 4, 5, 1, 5, 5, 0, 3, 5, 5, 2, 2, 5, 5, 4, 4, 5, 4, 4, 3, 3, 0, 0, 5, 3, 3, 3, 3, 2, 4, 5, 4, 5, 5, 3, 3, 3, 0, 4, 2, 3, 2, 3, 0, 5, 4, 5, 4, 2, 3, 5, 3, 2, 4, 5, 3, 3, 1, 4, 4, 1, 5, 1, 5, 3, 3, 0, 0, 5, 5, 3, 4, 4, 3, 3, 0, 2, 3, 5, 4, 5, 4, 3, 5, 2, 3, 1, 5, 3, 2, 2, 2, 5, 0, 1, 2, 0, 2, 0, 5, 0, 4, 5, 1, 5, 3, 0, 0, 3, 5, 5, 4, 5, 3, 4, 3, 4, 5, 5, 1, 1, 4, 4, 4, 0, 3, 4, 1, 5, 5, 3, 3, 2, 3, 3, 4, 3, 5, 2, 4, 3, 2, 3, 3, 2, 0, 1, 2, 0, 1, 2, 0, 5, 2, 5, 2, 2, 0, 5, 4, 2, 0, 0, 3, 5, 3, 1, 0, 5, 3, 5, 3, 2, 5, 3, 4, 4, 2, 5, 2, 3, 5, 3, 5, 5, 2, 2, 4, 3, 3, 5, 4, 4, 1, 0, 1, 0, 3, 3, 5, 2, 4, 1, 2, 3, 2, 0, 1, 1, 0, 0, 2, 0, 5, 5, 2, 3, 1, 3, 0, 5, 0, 3, 2, 3, 4, 4, 3, 5, 5, 1, 3, 5, 5, 4, 2, 5, 3, 3, 3, 2, 3, 1, 3, 2, 2, 5, 0, 4, 4, 4, 5, 5, 3, 2, 4, 5, 3, 3, 4, 5, 5, 2, 0, 3, 5, 3, 2, 5, 5, 0, 2, 3, 0, 2, 2, 2, 3, 4, 0, 2, 3, 1, 3, 5, 3, 5, 2, 4, 4, 2, 3, 0, 3, 1, 5, 2, 1, 5, 4, 3, 4, 3, 4, 3, 2, 1, 1, 2, 3, 1, 2, 1, 0, 4, 2, 0, 2, 3, 0, 3, 2, 0, 2, 4, 5, 4, 3, 3, 5, 3, 0, 5, 5, 5, 5, 2, 2, 3, 2, 2, 3, 5, 5, 4, 5, 4, 3, 4, 0, 3, 4, 2, 3, 4, 1, 0, 3, 5, 3, 0, 5, 1, 2, 3, 5, 1, 2, 5, 1, 2, 1, 3, 3, 4, 4, 2, 2, 5, 2, 2, 4, 3, 2, 5, 5, 2, 3, 5, 3, 2, 2, 2, 2, 5, 5, 4, 4, 2, 2, 4, 4, 2, 5, 0, 5, 4, 5, 2, 1, 2, 3, 2, 3, 3, 5, 2, 4, 5, 3, 5, 2, 3, 3, 3, 0, 3, 1, 5, 4, 2, 1, 3, 3, 2, 1, 3, 3, 3, 3, 4, 0, 3, 2, 3, 3, 2, 5, 4, 5, 3, 5, 3, 4, 4, 4, 3, 3, 3, 3, 3, 4, 0, 5, 4, 0, 4, 4, 3, 3, 4, 3, 4, 0, 5, 5, 3, 3, 4, 3, 4, 2, 5, 5, 4, 4, 0, 2, 1, 0, 5, 3, 0, 3, 1, 1, 1, 5, 5, 2, 5, 4, 2, 1, 1, 3, 3, 3, 3, 4, 3, 3, 4, 3, 0, 3, 4, 1, 3, 3, 2, 4, 1, 5, 3, 0, 3, 5, 3, 3, 3, 3, 5, 4, 4, 5, 4, 3, 3, 2, 4, 3, 0, 3, 3, 0, 0, 3, 5, 4, 0, 2, 5, 4, 0, 4, 3, 2, 2, 4, 3, 2, 3, 4, 3, 5, 4, 0, 5, 5, 3, 2, 3, 2, 3, 3, 3, 2, 3, 3, 4, 3, 5, 4, 3, 4, 4, 2, 1, 3, 4, 4, 5, 3, 5, 3, 5, 2, 2, 3, 3, 3, 2, 3, 3, 0, 4, 5, 1, 2, 5, 1, 3, 2, 4, 3, 0, 2, 5, 5, 3, 4, 0, 3, 4, 0, 4, 3, 2, 5, 2, 3, 3, 0, 1, 5, 2, 0, 5, 4, 5, 3, 4, 2, 3, 2, 1, 3, 2, 2, 4, 4, 3, 3, 5, 5, 3, 4, 5, 1, 3, 5, 4, 2, 3, 1, 3, 5, 4, 5, 5, 4, 0, 1, 3, 3, 0, 5, 4, 4, 3, 3, 3, 4, 1, 4, 2, 0, 3, 5, 5, 0, 3, 4, 4, 3, 1, 3, 2, 1, 0, 1, 0, 2, 4, 5, 4, 0, 4, 0, 1, 5, 2, 3, 5, 5, 3, 5, 5, 4, 0, 4, 2, 3, 5, 5, 2, 5, 5, 2, 3, 5, 4, 3, 5, 4, 2, 2, 4, 5, 5, 4, 5, 5, 5, 1, 0, 3, 3, 5, 3, 1, 3, 2, 5, 2, 5, 1, 5, 3, 1, 0, 3, 3, 1, 0, 5, 3, 2, 0, 3, 2, 4, 3, 3, 5, 5, 2, 3, 3, 5, 2, 1, 2, 5, 3, 0, 1, 4, 2, 4, 4, 5, 4, 2, 0, 4, 4, 3, 5, 4, 4, 5, 5, 1]
# Test to predict breast cancer relapse is approved
#
# ['test', 'to', 'predict', 'breast', 'cancer', 'relapse', 'is', 'approved']
# -----------
# Two Hussein allies are hanged, Iraqi official says
#
# ['two', 'hussein', 'allies', 'are', 'hanged', 'iraqi', 'official', 'says']
# -----------
# Sights and sounds from CES
#
# ['sights', 'and', 'sounds', 'from', 'ces']
# -----------
# Schuey sees Ferrari unveil new car
#
# ['schuey', 'sees', 'ferrari', 'unveil', 'new', 'car']
# -----------
# Closings and cancellations top advice on flu outbreak
#
# ['closings', 'and', 'cancellations', 'top', 'advice', 'on', 'flu', 'outbreak']
# -----------
# Trucks swallowed in subway collapse
#
# ['trucks', 'swallowed', 'in', 'subway', 'collapse']
# -----------
# Sarkozy letter surprises French cartoons hearing
#
# ['sarkozy', 'letter', 'surprises', 'french', 'cartoons', 'hearing']
# -----------
# Building a memorial to a son, one child at a time
#
# ['building', 'a', 'memorial', 'to', 'a', 'son', 'one', 'child', 'at', 'a', 'time']
# -----------
# Lawmaker seeks iPod ban in crosswalks in New York
#
# ['lawmaker', 'seeks', 'ipod', 'ban', 'in', 'crosswalks', 'in', 'new', 'york']
# -----------
# Diabetic waits months for eyeglasses
#
# ['diabetic', 'waits', 'months', 'for', 'eyeglasses']
# -----------
# Sudan tells United Nations envoy to leave in 72 hours
#
# ['sudan', 'tells', 'united', 'nations', 'envoy', 'to', 'leave', 'in', '72', 'hours']
# -----------
# 5000 years on but couple still hugging
#
# ['5000', 'years', 'on', 'but', 'couple', 'still', 'hugging']
# -----------
# Defense to challenge Russert's credibility
#
# ['defense', 'to', 'challenge', 'russert', 'is', 'credibility']
# -----------
# Ozzy, a Hero for the hard-rocking masses
#
# ['ozzy', 'a', 'hero', 'for', 'the', 'hard', 'rocking', 'masses']
# -----------
# CIA leak trial summary
#
# ['cia', 'leak', 'trial', 'summary']
# -----------
# Dance movie takes over No. 1
#
# ['dance', 'movie', 'takes', 'over', 'no', '1']
# -----------
# Asian nations urge Myanmar reform
#
# ['asian', 'nations', 'urge', 'myanmar', 'reform']
# -----------
# After Iraq trip, Clinton proposes war limits
#
# ['after', 'iraq', 'trip', 'clinton', 'proposes', 'war', 'limits']
# -----------
# 7 dead in apartment building fire
#
# ['7', 'dead', 'in', 'apartment', 'building', 'fire']
# -----------
# Male sweat boosts women's hormone levels
#
# ['male', 'sweat', 'boosts', 'women', 'is', 'hormone', 'levels']
# -----------
# Carphone Warehouse's mixed signals
#
# ['carphone', 'warehouse', 'is', 'mixed', 'signals']
# -----------
# Democrats plot Bush troop increase censure
#
# ['democrats', 'plot', 'bush', 'troop', 'increase', 'censure']
# -----------
# Cisco sues Apple over iPhone name
#
# ['cisco', 'sues', 'apple', 'over', 'iphone', 'name']
# -----------
# BB star Jackson denies Goody comments
#
# ['bb', 'star', 'jackson', 'denies', 'goody', 'comments']
# -----------
# Inter Milan set Serie A win record
#
# ['inter', 'milan', 'set', 'serie', 'a', 'win', 'record']
# -----------
# US Airways boosts bid for Delta
#
# ['us', 'airways', 'boosts', 'bid', 'for', 'delta']
# -----------
# Press sees hope in Mecca talks
#
# ['press', 'sees', 'hope', 'in', 'mecca', 'talks']
# -----------
# Bears fan loses bet and changes name
#
# ['bears', 'fan', 'loses', 'bet', 'and', 'changes', 'name']
# -----------
# Global National	Major child porn ring bust
#
# ['global', 'national', 'major', 'child', 'porn', 'ring', 'bust']
# -----------
# 'Human hair' clue in hunt for airliner
#
# ['human', 'hair', 'clue', 'in', 'hunt', 'for', 'airliner']
# -----------
# Johnny Depp to make movie of spy poisoning
#
# ['johnny', 'depp', 'to', 'make', 'movie', 'of', 'spy', 'poisoning']
# -----------
# Really?: The claim: the pill can make you put on weight
#
# ['really', 'the', 'claim', 'the', 'pill', 'can', 'make', 'you', 'put', 'on', 'weight']
# -----------
# 5 money makeovers
#
# ['5', 'money', 'makeovers']
# -----------
# TBS to pay $2M fine for ad campaign bomb scare
#
# ['tbs', 'to', 'pay', '2m', 'fine', 'for', 'ad', 'campaign', 'bomb', 'scare']
# -----------
# "Stomp the Yard" has winning moves in its weekend debut
#
# ['stomp', 'the', 'yard', 'has', 'winning', 'moves', 'in', 'its', 'weekend', 'debut']
# -----------
# Discovered boys bring shock, joy
#
# ['discovered', 'boys', 'bring', 'shock', 'joy']
# -----------
# Bernhard set to leave Volkswagen
#
# ['bernhard', 'set', 'to', 'leave', 'volkswagen']
# -----------
# Pacers' Jackson misses gun hearing
#
# ['pacers', 'jackson', 'misses', 'gun', 'hearing']
# -----------
# Cases: when the simple solution is the right one
#
# ['cases', 'when', 'the', 'simple', 'solution', 'is', 'the', 'right', 'one']
# -----------
# Two Muslim groups sue French newspaper International
#
# ['two', 'muslim', 'groups', 'sue', 'french', 'newspaper', 'international']
# -----------
# Golden Globes on their way
#
# ['golden', 'globes', 'on', 'their', 'way']
# -----------
# At New OZZFEST, Freedom Ain't Free
#
# ['at', 'new', 'ozzfest', 'freedom', 'ain', 'not', 'free']
# -----------
# Federer handed tough Aussie draw
#
# ['federer', 'handed', 'tough', 'aussie', 'draw']
# -----------
# Protesters end strike as Nepal PM concedes demands
#
# ['protesters', 'end', 'strike', 'as', 'nepal', 'pm', 'concedes', 'demands']
# -----------
# Turner pays for Boston "bombing"
#
# ['turner', 'pays', 'for', 'boston', 'bombing']
# -----------
# Two detained in body parts mailing
#
# ['two', 'detained', 'in', 'body', 'parts', 'mailing']
# -----------
# Essay: about that mean streak of yours: psychiatry can do only so much
#
# ['essay', 'about', 'that', 'mean', 'streak', 'of', 'yours', 'psychiatry', 'can', 'do', 'only', 'so', 'much']
# -----------
# Hussein's niece pleads for father's life
#
# ['hussein', 'is', 'niece', 'pleads', 'for', 'father', 'is', 'life']
# -----------
# Sarkozy heads for clash in cartoons row
#
# ['sarkozy', 'heads', 'for', 'clash', 'in', 'cartoons', 'row']
# -----------
# Global web of suspects in child-rape download
#
# ['global', 'web', 'of', 'suspects', 'in', 'child', 'rape', 'download']
# -----------
# Blake defeats Moya to retain title
#
# ['blake', 'defeats', 'moya', 'to', 'retain', 'title']
# -----------
# Storms kill, knock out power, cancel flights
#
# ['storms', 'kill', 'knock', 'out', 'power', 'cancel', 'flights']
# -----------
# Aquarium puts ailing beluga whale to sleep
#
# ['aquarium', 'puts', 'ailing', 'beluga', 'whale', 'to', 'sleep']
# -----------
# Microsoft, Sony, we have a problem
#
# ['microsoft', 'sony', 'we', 'have', 'a', 'problem']
# -----------
# A police state? The issues
#
# ['a', 'police', 'state', 'the', 'issues']
# -----------
# Move to ban iPods from crossing the street
#
# ['move', 'to', 'ban', 'ipods', 'from', 'crossing', 'the', 'street']
# -----------
# India's Taj Mahal gets facelift
#
# ['india', 'is', 'taj', 'mahal', 'gets', 'facelift']
# -----------
# Cheney to Congress: Can't run Iraq war by committee
#
# ['cheney', 'to', 'congress', 'can', 'not', 'run', 'iraq', 'war', 'by', 'committee']
# -----------
# Ganguly handed India squad call-up
#
# ['ganguly', 'handed', 'india', 'squad', 'call', 'up']
# -----------
# Fortune: Looking beyond the iPhone
#
# ['fortune', 'looking', 'beyond', 'the', 'iphone']
# -----------
# Really?: The claim: the back seat of a car is the safest place to sit
#
# ['really', 'the', 'claim', 'the', 'back', 'seat', 'of', 'a', 'car', 'is', 'the', 'safest', 'place', 'to', 'sit']
# -----------
# Vaccine mandate upsets legislators
#
# ['vaccine', 'mandate', 'upsets', 'legislators']
# -----------
# News analysis: Iranian boast is put to test
#
# ['news', 'analysis', 'iranian', 'boast', 'is', 'put', 'to', 'test']
# -----------
# Panel issues bleak report on climate change
#
# ['panel', 'issues', 'bleak', 'report', 'on', 'climate', 'change']
# -----------
# Virtual 'American Idol' hits right notes
#
# ['virtual', 'american', 'idol', 'hits', 'right', 'notes']
# -----------
# Iraq car bombings kill 22 People, wound more than 60
#
# ['iraq', 'car', 'bombings', 'kill', '22', 'people', 'wound', 'more', 'than', '60']
# -----------
# 'Stomp' steps to No. 1 at box office
#
# ['stomp', 'steps', 'to', 'no', '1', 'at', 'box', 'office']
# -----------
# Google executive acts as goodwill envoy
#
# ['google', 'executive', 'acts', 'as', 'goodwill', 'envoy']
# -----------
# Filipino woman kidnapped in Nigeria
#
# ['filipino', 'woman', 'kidnapped', 'in', 'nigeria']
# -----------
# Seahawks, Bears vie for shot at NFL title
#
# ['seahawks', 'bears', 'vie', 'for', 'shot', 'at', 'nfl', 'title']
# -----------
# Brown not buried as estate issues loom
#
# ['brown', 'not', 'buried', 'as', 'estate', 'issues', 'loom']
# -----------
# Will Rob Cohen Direct Third 'Mummy'?
#
# ['will', 'rob', 'cohen', 'direct', 'third', 'mummy']
# -----------
# EU will urge China to go green
#
# ['eu', 'will', 'urge', 'china', 'to', 'go', 'green']
# -----------
# 17th-Century Remedy; 21st-Century Potency
#
# ['17th', 'century', 'remedy', '21st', 'century', 'potency']
# -----------
# Forecasters expect toasty 2007
#
# ['forecasters', 'expect', 'toasty', '2007']
# -----------
# 'Sunshine' Goydos wins Sony open
#
# ['sunshine', 'goydos', 'wins', 'sony', 'open']
# -----------
# Teacher charged with sex assault
#
# ['teacher', 'charged', 'with', 'sex', 'assault']
# -----------
# Merck: Gardasil may fight more strains
#
# ['merck', 'gardasil', 'may', 'fight', 'more', 'strains']
# -----------
# Mountain glaciers melting faster, United Nations says
#
# ['mountain', 'glaciers', 'melting', 'faster', 'united', 'nations', 'says']
# -----------
# Snow causes airport closures in Britain
#
# ['snow', 'causes', 'airport', 'closures', 'in', 'britain']
# -----------
# Bananaconda inventor is top poet of kids
#
# ['bananaconda', 'inventor', 'is', 'top', 'poet', 'of', 'kids']
# -----------
# Shareholders sue Apple
#
# ['shareholders', 'sue', 'apple']
# -----------
# Israelis retaliate after attack by Lebanese Army
#
# ['israelis', 'retaliate', 'after', 'attack', 'by', 'lebanese', 'army']
# -----------
# Deadly bird flu confirmed in British Turkeys
#
# ['deadly', 'bird', 'flu', 'confirmed', 'in', 'british', 'turkeys']
# -----------
# Too little sleep may mean too fat kids
#
# ['too', 'little', 'sleep', 'may', 'mean', 'too', 'fat', 'kids']
# -----------
# Bathing mom awakes to find baby dead
#
# ['bathing', 'mom', 'awakes', 'to', 'find', 'baby', 'dead']
# -----------
# Visitors to Eiffel Tower climb to record in 2006
#
# ['visitors', 'to', 'eiffel', 'tower', 'climb', 'to', 'record', 'in', '2006']
# -----------
# More sleep, healthier slimmer children
#
# ['more', 'sleep', 'healthier', 'slimmer', 'children']
# -----------
# Queen battles Bond for Baftas
#
# ['queen', 'battles', 'bond', 'for', 'baftas']
# -----------
# Walters on Trump: 'Poor, pathetic man'
#
# ['walters', 'on', 'trump', 'poor', 'pathetic', 'man']
# -----------
# Ice storm smacks roads, power
#
# ['ice', 'storm', 'smacks', 'roads', 'power']
# -----------
# Iran says it will strike US interests if Attacked
#
# ['iran', 'says', 'it', 'will', 'strike', 'us', 'interests', 'if', 'attacked']
# -----------
# Palestinian factions to resume talks
#
# ['palestinian', 'factions', 'to', 'resume', 'talks']
# -----------
# Study: men's sweat triggers high sexual arousal in women
#
# ['study', 'men', 'is', 'sweat', 'triggers', 'high', 'sexual', 'arousal', 'in', 'women']
# -----------
# Outcry at N Korea 'nuclear test'
#
# ['outcry', 'at', 'n', 'korea', 'nuclear', 'test']
# -----------
# Russia plans major military build-up
#
# ['russia', 'plans', 'major', 'military', 'build', 'up']
# -----------
# Archaeologists find remains of couple locked in a hug
#
# ['archaeologists', 'find', 'remains', 'of', 'couple', 'locked', 'in', 'a', 'hug']
# -----------
# Stenson defends his title at Dubai
#
# ['stenson', 'defends', 'his', 'title', 'at', 'dubai']
# -----------
# Taking the plunge
#
# ['taking', 'the', 'plunge']
# -----------
# Updates on world's top stories
#
# ['updates', 'on', 'world', 'is', 'top', 'stories']
# -----------
# Man rides stationary bike for 85 hours
#
# ['man', 'rides', 'stationary', 'bike', 'for', '85', 'hours']
# -----------
# Ice storm coating Midwest
#
# ['ice', 'storm', 'coating', 'midwest']
# -----------
# A Mistrial for Lieut. Watada
#
# ['a', 'mistrial', 'for', 'lieut', 'watada']
# -----------
# Iran warns will hit back at US if attacked
#
# ['iran', 'warns', 'will', 'hit', 'back', 'at', 'us', 'if', 'attacked']
# -----------
# ASEAN talks end on energy-security
#
# ['asean', 'talks', 'end', 'on', 'energy', 'security']
# -----------
# Iraqi death toll exceeded 34,000 in 2006, United Nations says
#
# ['iraqi', 'death', 'toll', 'exceeded', '34', '000', 'in', '2006', 'united', 'nations', 'says']
# -----------
# Israel intensifies military flights over Lebanon
#
# ['israel', 'intensifies', 'military', 'flights', 'over', 'lebanon']
# -----------
# New gadgets galore at tech show
#
# ['new', 'gadgets', 'galore', 'at', 'tech', 'show']
# -----------
# Another death at Georgia Aquarium
#
# ['another', 'death', 'at', 'georgia', 'aquarium']
# -----------
# US to urge Nato Afghan spring offensive
#
# ['us', 'to', 'urge', 'nato', 'afghan', 'spring', 'offensive']
# -----------
# UK letter bombs may be from extremist drivers
#
# ['uk', 'letter', 'bombs', 'may', 'be', 'from', 'extremist', 'drivers']
# -----------
# Asia seeks breakthrough on North Korea
#
# ['asia', 'seeks', 'breakthrough', 'on', 'north', 'korea']
# -----------
# Federer overcomes a ragged start
#
# ['federer', 'overcomes', 'a', 'ragged', 'start']
# -----------
# Rowdy fans ejected from the Open
#
# ['rowdy', 'fans', 'ejected', 'from', 'the', 'open']
# -----------
# Terai protesters hail 'historic' victory over government
#
# ['terai', 'protesters', 'hail', 'historic', 'victory', 'over', 'government']
# -----------
# Anger at release of two held over beheading plot
#
# ['anger', 'at', 'release', 'of', 'two', 'held', 'over', 'beheading', 'plot']
# -----------
# Bush adamant on troops to Iraq
#
# ['bush', 'adamant', 'on', 'troops', 'to', 'iraq']
# -----------
# Bebe Neuwirth gets to 'wiggle again'
#
# ['bebe', 'neuwirth', 'gets', 'to', 'wiggle', 'again']
# -----------
# Beckham to L.A.: For the game not fame
#
# ['beckham', 'to', 'l', 'a', 'for', 'the', 'game', 'not', 'fame']
# -----------
# Sleep more to fight childhood obesity
#
# ['sleep', 'more', 'to', 'fight', 'childhood', 'obesity']
# -----------
# Abbas rejects temporary state
#
# ['abbas', 'rejects', 'temporary', 'state']
# -----------
# Investigation of child porn site hits 77 nations
#
# ['investigation', 'of', 'child', 'porn', 'site', 'hits', '77', 'nations']
# -----------
# Sleuths close in on Odysseus home
#
# ['sleuths', 'close', 'in', 'on', 'odysseus', 'home']
# -----------
# Variety: Johnny Depp to make movie of spy poisoning
#
# ['variety', 'johnny', 'depp', 'to', 'make', 'movie', 'of', 'spy', 'poisoning']
# -----------
# Ice storm cripples central U.S.
#
# ['ice', 'storm', 'cripples', 'central', 'u', 'is']
# -----------
# Park stars as United maintain lead
#
# ['park', 'stars', 'as', 'united', 'maintain', 'lead']
# -----------
# Prehistoric Romeo and Juliet discovered
#
# ['prehistoric', 'romeo', 'and', 'juliet', 'discovered']
# -----------
# India's famous landmark gets facelift
#
# ['india', 'is', 'famous', 'landmark', 'gets', 'facelift']
# -----------
# Joseph Wambaugh's new start
#
# ['joseph', 'wambaugh', 'is', 'new', 'start']
# -----------
# Participant in water-drinking contest dies
#
# ['participant', 'in', 'water', 'drinking', 'contest', 'dies']
# -----------
# Apple drops bombshell with iPhone
#
# ['apple', 'drops', 'bombshell', 'with', 'iphone']
# -----------
# Bollywood's 'Brangelina' engaged
#
# ['bollywood', 'is', 'brangelina', 'engaged']
# -----------
# Shiite fighters arrested in crackdown, Iraq says
#
# ['shiite', 'fighters', 'arrested', 'in', 'crackdown', 'iraq', 'says']
# -----------
# Rio De Janeiro journal: drawing lines across the sand, between classes
#
# ['rio', 'de', 'janeiro', 'journal', 'drawing', 'lines', 'across', 'the', 'sand', 'between', 'classes']
# -----------
# Models' health guidelines -- will they help?
#
# ['models', 'health', 'guidelines', 'will', 'they', 'help']
# -----------
# Stepping back in time at ski resort
#
# ['stepping', 'back', 'in', 'time', 'at', 'ski', 'resort']
# -----------
# Test cricketer jailed over killing
#
# ['test', 'cricketer', 'jailed', 'over', 'killing']
# -----------
# Walnuts 'combat unhealthy fats'
#
# ['walnuts', 'combat', 'unhealthy', 'fats']
# -----------
# Apple to Vista upgraders: 'Wait'
#
# ['apple', 'to', 'vista', 'upgraders', 'wait']
# -----------
# Injured Sarwan to miss one-dayers
#
# ['injured', 'sarwan', 'to', 'miss', 'one', 'dayers']
# -----------
# Firms on alert for letter bombs
#
# ['firms', 'on', 'alert', 'for', 'letter', 'bombs']
# -----------
# Studios sign off on movie downloads
#
# ['studios', 'sign', 'off', 'on', 'movie', 'downloads']
# -----------
# Asif returns with four-wicket haul
#
# ['asif', 'returns', 'with', 'four', 'wicket', 'haul']
# -----------
# Bush authorized Iranians' arrest in Iraq, Rice says
#
# ['bush', 'authorized', 'iranians', 'arrest', 'in', 'iraq', 'rice', 'says']
# -----------
# Porn ring scandal reaches Australia
#
# ['porn', 'ring', 'scandal', 'reaches', 'australia']
# -----------
# Deputy health minister arrested in US-Iraqi raid
#
# ['deputy', 'health', 'minister', 'arrested', 'in', 'us', 'iraqi', 'raid']
# -----------
# Senator Carl Krueger thinks iPods can kill you
#
# ['senator', 'carl', 'krueger', 'thinks', 'ipods', 'can', 'kill', 'you']
# -----------
# Finally, Senate okays anti-terror bill Manila
#
# ['finally', 'senate', 'okays', 'anti', 'terror', 'bill', 'manila']
# -----------
# Somalia declares state of emergency
#
# ['somalia', 'declares', 'state', 'of', 'emergency']
# -----------
# Matt shines with his Alpine finish
#
# ['matt', 'shines', 'with', 'his', 'alpine', 'finish']
# -----------
# BP CEO Browne to step down in June
#
# ['bp', 'ceo', 'browne', 'to', 'step', 'down', 'in', 'june']
# -----------
# An iPhone by any other name? Surely not
#
# ['an', 'iphone', 'by', 'any', 'other', 'name', 'surely', 'not']
# -----------
# Life in Gaza steadily worsens
#
# ['life', 'in', 'gaza', 'steadily', 'worsens']
# -----------
# The energy challenge | Exotic visions: how to cool a planet (maybe)
#
# ['the', 'energy', 'challenge', 'exotic', 'visions', 'how', 'to', 'cool', 'a', 'planet', 'maybe']
# -----------
# Easy ways to (really) save $400,000
#
# ['easy', 'ways', 'to', 'really', 'save', '400', '000']
# -----------
# Shareholders sue Apple
#
# ['shareholders', 'sue', 'apple']
# -----------
# Findings: Can humanity survive? Want to bet on it?
#
# ['findings', 'can', 'humanity', 'survive', 'want', 'to', 'bet', 'on', 'it']
# -----------
# Iran steps up production of weapons-grade uranium
#
# ['iran', 'steps', 'up', 'production', 'of', 'weapons', 'grade', 'uranium']
# -----------
# Rig-threat cargo ship towed ashore
#
# ['rig', 'threat', 'cargo', 'ship', 'towed', 'ashore']
# -----------
# Palestinians say clashes hurt their cause
#
# ['palestinians', 'say', 'clashes', 'hurt', 'their', 'cause']
# -----------
# Male sweat can raise hormones
#
# ['male', 'sweat', 'can', 'raise', 'hormones']
# -----------
# Vital Signs: Hazards: Antidepressant linked to fractures in older people
#
# ['vital', 'signs', 'hazards', 'antidepressant', 'linked', 'to', 'fractures', 'in', 'older', 'people']
# -----------
# Peron held over '70s rights abuses
#
# ['peron', 'held', 'over', '70s', 'rights', 'abuses']
# -----------
# Space life search turns to TV
#
# ['space', 'life', 'search', 'turns', 'to', 'tv']
# -----------
# Super Bowl ads of cartoonish violence, perhaps reflecting toll of war
#
# ['super', 'bowl', 'ads', 'of', 'cartoonish', 'violence', 'perhaps', 'reflecting', 'toll', 'of', 'war']
# -----------
# YouTube told to drop celeb sex video
#
# ['youtube', 'told', 'to', 'drop', 'celeb', 'sex', 'video']
# -----------
# Beckham & Posh and more athlete-celebrity couples
#
# ['beckham', 'posh', 'and', 'more', 'athlete', 'celebrity', 'couples']
# -----------
# City sets up ice storm shelters
#
# ['city', 'sets', 'up', 'ice', 'storm', 'shelters']
# -----------
# Libby prosecutors await judge's rulings
#
# ['libby', 'prosecutors', 'await', 'judge', 'is', 'rulings']
# -----------
# Review: 'Alpha Dog' misses the point
#
# ['review', 'alpha', 'dog', 'misses', 'the', 'point']
# -----------
# Republicans plan to block Iraq debate
#
# ['republicans', 'plan', 'to', 'block', 'iraq', 'debate']
# -----------
# Mixed reaction to China's Africa push
#
# ['mixed', 'reaction', 'to', 'china', 'is', 'africa', 'push']
# -----------
# Snowed in the Canadian Rockies
#
# ['snowed', 'in', 'the', 'canadian', 'rockies']
# -----------
# Skip the showers: male sweat turns women on, study says
#
# ['skip', 'the', 'showers', 'male', 'sweat', 'turns', 'women', 'on', 'study', 'says']
# -----------
# Gently Weeps' lyrics sheet up for sale
#
# ['gently', 'weeps', 'lyrics', 'sheet', 'up', 'for', 'sale']
# -----------
# Canete wins inaugural Joburg Open
#
# ['canete', 'wins', 'inaugural', 'joburg', 'open']
# -----------
# Rights group halts violent Nepal strikes
#
# ['rights', 'group', 'halts', 'violent', 'nepal', 'strikes']
# -----------
# Real suffer Carlos injury setback
#
# ['real', 'suffer', 'carlos', 'injury', 'setback']
# -----------
# Astronaut may have buckled under stress
#
# ['astronaut', 'may', 'have', 'buckled', 'under', 'stress']
# -----------
# Gunmen abduct Filipino woman in Nigeria
#
# ['gunmen', 'abduct', 'filipino', 'woman', 'in', 'nigeria']
# -----------
# NFL team's fan of the year: 'Flag Lady'
#
# ['nfl', 'team', 'is', 'fan', 'of', 'the', 'year', 'flag', 'lady']
# -----------
# No 10 rejects police state claim
#
# ['no', '10', 'rejects', 'police', 'state', 'claim']
# -----------
# Malaysian AirAsia X to fly in July
#
# ['malaysian', 'airasia', 'x', 'to', 'fly', 'in', 'july']
# -----------
# 10 kidnapped at Nigeria oil base
#
# ['10', 'kidnapped', 'at', 'nigeria', 'oil', 'base']
# -----------
# Guy sweat is babe magnet
#
# ['guy', 'sweat', 'is', 'babe', 'magnet']
# -----------
# Township tourism booming in South Africa
#
# ['township', 'tourism', 'booming', 'in', 'south', 'africa']
# -----------
# 'Alpha Dog' misses the point
#
# ['alpha', 'dog', 'misses', 'the', 'point']
# -----------
# Iran leader pays Nicaragua a visit
#
# ['iran', 'leader', 'pays', 'nicaragua', 'a', 'visit']
# -----------
# 'Grey's,' 'Pirates' lead People's Choice
#
# ['grey', 'is', 'pirates', 'lead', 'people', 'is', 'choice']
# -----------
# Terror network
#
# ['terror', 'network']
# -----------
# Now it's official: Iraq's a mess
#
# ['now', 'it', 'is', 'official', 'iraq', 'is', 'a', 'mess']
# -----------
# Snow brings travel misery to England
#
# ['snow', 'brings', 'travel', 'misery', 'to', 'england']
# -----------
# James Brown's 5-year-old son left out of will
#
# ['james', 'brown', 'is', '5', 'year', 'old', 'son', 'left', 'out', 'of', 'will']
# -----------
# Two men killed by London tube train
#
# ['two', 'men', 'killed', 'by', 'london', 'tube', 'train']
# -----------
# US millions fail to buy influence in deadly Gaza power play
#
# ['us', 'millions', 'fail', 'to', 'buy', 'influence', 'in', 'deadly', 'gaza', 'power', 'play']
# -----------
# PLO ministers agreed upon in Mecca
#
# ['plo', 'ministers', 'agreed', 'upon', 'in', 'mecca']
# -----------
# Squadron apologies over 'friendly-fire' death
#
# ['squadron', 'apologies', 'over', 'friendly', 'fire', 'death']
# -----------
# New Orleans violence sparks tourism fears
#
# ['new', 'orleans', 'violence', 'sparks', 'tourism', 'fears']
# -----------
# Friendly fire pilot 'experienced'
#
# ['friendly', 'fire', 'pilot', 'experienced']
# -----------
# SPACE.com: Black hole triplets spotted
#
# ['space', 'com', 'black', 'hole', 'triplets', 'spotted']
# -----------
# Vaccines: Mandate or choice?
#
# ['vaccines', 'mandate', 'or', 'choice']
# -----------
# Congolese soldiers riot, loot over pay issue
#
# ['congolese', 'soldiers', 'riot', 'loot', 'over', 'pay', 'issue']
# -----------
# Commodities lead Europe higher
#
# ['commodities', 'lead', 'europe', 'higher']
# -----------
# Ingredient in male sweat raises women's hormone levels
#
# ['ingredient', 'in', 'male', 'sweat', 'raises', 'women', 'is', 'hormone', 'levels']
# -----------
# Goetschl ends Austrian win drought
#
# ['goetschl', 'ends', 'austrian', 'win', 'drought']
# -----------
# Doomsday Clock ticking away
#
# ['doomsday', 'clock', 'ticking', 'away']
# -----------
# Troops massing around Somali town
#
# ['troops', 'massing', 'around', 'somali', 'town']
# -----------
# Tariq Ramadan has an identity issue
#
# ['tariq', 'ramadan', 'has', 'an', 'identity', 'issue']
# -----------
# Peretz orders IDF to respond with force to north border attacks
#
# ['peretz', 'orders', 'idf', 'to', 'respond', 'with', 'force', 'to', 'north', 'border', 'attacks']
# -----------
# Trains crash near Thai resort town
#
# ['trains', 'crash', 'near', 'thai', 'resort', 'town']
# -----------
# Hamas, Fatah return to unity gov't talks in Mecca
#
# ['hamas', 'fatah', 'return', 'to', 'unity', 'gov', 'not', 'talks', 'in', 'mecca']
# -----------
# Pats' fourth-quarter rally finishes Chargers
#
# ['pats', 'fourth', 'quarter', 'rally', 'finishes', 'chargers']
# -----------
# 7 Die As US Helicopter Crashes in Iraq
#
# ['7', 'die', 'as', 'us', 'helicopter', 'crashes', 'in', 'iraq']
# -----------
# Millionaire secret Santa dies
#
# ['millionaire', 'secret', 'santa', 'dies']
# -----------
# Morrissey may cheer up Eurovision
#
# ['morrissey', 'may', 'cheer', 'up', 'eurovision']
# -----------
# Christian values guide Dungy and the Colts
#
# ['christian', 'values', 'guide', 'dungy', 'and', 'the', 'colts']
# -----------
# Israeli woman's tirade spurs PM outrage
#
# ['israeli', 'woman', 'is', 'tirade', 'spurs', 'pm', 'outrage']
# -----------
# Passing exchange becomes political flashpoint
#
# ['passing', 'exchange', 'becomes', 'political', 'flashpoint']
# -----------
# Police probe 2 church fires half mile apart
#
# ['police', 'probe', '2', 'church', 'fires', 'half', 'mile', 'apart']
# -----------
# Italy to try US soldier for agent's Iraq death
#
# ['italy', 'to', 'try', 'us', 'soldier', 'for', 'agent', 'is', 'iraq', 'death']
# -----------
# Depp to star in spy poisoning film
#
# ['depp', 'to', 'star', 'in', 'spy', 'poisoning', 'film']
# -----------
# '24's' Jack Bauer returns
#
# ['24', 'is', 'jack', 'bauer', 'returns']
# -----------
# US Airways boosts bid for Delta
#
# ['us', 'airways', 'boosts', 'bid', 'for', 'delta']
# -----------
# Even before its release, world climate report is criticized as too optimistic
#
# ['even', 'before', 'its', 'release', 'world', 'climate', 'report', 'is', 'criticized', 'as', 'too', 'optimistic']
# -----------
# Second hanging also went awry, Iraq tape shows
#
# ['second', 'hanging', 'also', 'went', 'awry', 'iraq', 'tape', 'shows']
# -----------
# Howell takes one shot lead in Sony Open
#
# ['howell', 'takes', 'one', 'shot', 'lead', 'in', 'sony', 'open']
# -----------
# Psych checks reviewed after astronaut's crack-up
#
# ['psych', 'checks', 'reviewed', 'after', 'astronaut', 'is', 'crack', 'up']
# -----------
# Pap Test, a mainstay against cervical cancer, may be fading
#
# ['pap', 'test', 'a', 'mainstay', 'against', 'cervical', 'cancer', 'may', 'be', 'fading']
# -----------
# Martins leads Newcastle fightback
#
# ['martins', 'leads', 'newcastle', 'fightback']
# -----------
# PS3 pricey but impressive
#
# ['ps3', 'pricey', 'but', 'impressive']
# -----------
# Pluto's revenge: 'Word of the Year' award
#
# ['pluto', 'is', 'revenge', 'word', 'of', 'the', 'year', 'award']
# -----------
# European Space Agency
#
# ['european', 'space', 'agency']
# -----------
# Hackers strike at key Internet servers
#
# ['hackers', 'strike', 'at', 'key', 'internet', 'servers']
# -----------
# Hussein co-defendants executed
#
# ['hussein', 'co', 'defendants', 'executed']
# -----------
# Memo from Frankfurt: Germany relives 1970s terror as 2 seek release from jail
#
# ['memo', 'from', 'frankfurt', 'germany', 'relives', '1970s', 'terror', 'as', '2', 'seek', 'release', 'from', 'jail']
# -----------
# Blissing out in Ojai
#
# ['blissing', 'out', 'in', 'ojai']
# -----------
# Houston, she's got some problems
#
# ['houston', 'she', 'is', 'got', 'some', 'problems']
# -----------
# Amazon.com has 'best ever' sales
#
# ['amazon', 'com', 'has', 'best', 'ever', 'sales']
# -----------
# Hackers attack root servers
#
# ['hackers', 'attack', 'root', 'servers']
# -----------
# Video games can improve your vision
#
# ['video', 'games', 'can', 'improve', 'your', 'vision']
# -----------
# Internet attacked! (Did anyone notice?)
#
# ['internet', 'attacked', 'did', 'anyone', 'notice']
# -----------
# In Washington, contractors take on biggest role ever
#
# ['in', 'washington', 'contractors', 'take', 'on', 'biggest', 'role', 'ever']
# -----------
# Floods force Malaysia evacuations
#
# ['floods', 'force', 'malaysia', 'evacuations']
# -----------
# On MySpace, girls seek friends, boys flirt
#
# ['on', 'myspace', 'girls', 'seek', 'friends', 'boys', 'flirt']
# -----------
# Tests of drug to block H.I.V. infection are halted over safety
#
# ['tests', 'of', 'drug', 'to', 'block', 'h', 'i', 'v', 'infection', 'are', 'halted', 'over', 'safety']
# -----------
# Zoo polar bear to have root canal
#
# ['zoo', 'polar', 'bear', 'to', 'have', 'root', 'canal']
# -----------
# Europe take big Royal Trophy lead
#
# ['europe', 'take', 'big', 'royal', 'trophy', 'lead']
# -----------
# Israel to install cameras to show live Mughrabi footage
#
# ['israel', 'to', 'install', 'cameras', 'to', 'show', 'live', 'mughrabi', 'footage']
# -----------
# 'We lit our last candle yesterday'
#
# ['we', 'lit', 'our', 'last', 'candle', 'yesterday']
# -----------
# Google buys YouTube for $1.65bn
#
# ['google', 'buys', 'youtube', 'for', '1', '65bn']
# -----------
# PSP number one Sony platform in Japan
#
# ['psp', 'number', 'one', 'sony', 'platform', 'in', 'japan']
# -----------
# England include Giles in WC squad
#
# ['england', 'include', 'giles', 'in', 'wc', 'squad']
# -----------
# Beckham 'won't play again for Real'
#
# ['beckham', 'won', 'not', 'play', 'again', 'for', 'real']
# -----------
# Eight years for Damilola killers
#
# ['eight', 'years', 'for', 'damilola', 'killers']
# -----------
# PC World editor slain at California home
#
# ['pc', 'world', 'editor', 'slain', 'at', 'california', 'home']
# -----------
# Hands on 'Doomsday Clock' move forward
#
# ['hands', 'on', 'doomsday', 'clock', 'move', 'forward']
# -----------
# Zach Braff says he has 'mild depression'
#
# ['zach', 'braff', 'says', 'he', 'has', 'mild', 'depression']
# -----------
# Investigation of child porn site hits 77 nations USA Today
#
# ['investigation', 'of', 'child', 'porn', 'site', 'hits', '77', 'nations', 'usa', 'today']
# -----------
# Science panel calls global warming unequivocal
#
# ['science', 'panel', 'calls', 'global', 'warming', 'unequivocal']
# -----------
# News Baby pandas! Baby pandas! Baby pandas!
#
# ['news', 'baby', 'pandas', 'baby', 'pandas', 'baby', 'pandas']
# -----------
# Get ready for the earnings
#
# ['get', 'ready', 'for', 'the', 'earnings']
# -----------
# Germany agonizes over a brain drain
#
# ['germany', 'agonizes', 'over', 'a', 'brain', 'drain']
# -----------
# Iran and Nicaraguan leaders meet
#
# ['iran', 'and', 'nicaraguan', 'leaders', 'meet']
# -----------
# Secret hotels in Irish countryside
#
# ['secret', 'hotels', 'in', 'irish', 'countryside']
# -----------
# Fine wines in British Columbia
#
# ['fine', 'wines', 'in', 'british', 'columbia']
# -----------
# Philippine president welcomes Senate approval of anti-terror bill
#
# ['philippine', 'president', 'welcomes', 'senate', 'approval', 'of', 'anti', 'terror', 'bill']
# -----------
# Small jet crashes on takeoff, killing 2
#
# ['small', 'jet', 'crashes', 'on', 'takeoff', 'killing', '2']
# -----------
# Bigger, more aggressive rats infesting UK
#
# ['bigger', 'more', 'aggressive', 'rats', 'infesting', 'uk']
# -----------
# Travel+Leisure: Next island hot spot: St. Lucia
#
# ['travel', 'leisure', 'next', 'island', 'hot', 'spot', 'st', 'lucia']
# -----------
# Real Mallorca rock leaders Sevilla
#
# ['real', 'mallorca', 'rock', 'leaders', 'sevilla']
# -----------
# Iran's boast on uranium enrichment is put to test
#
# ['iran', 'is', 'boast', 'on', 'uranium', 'enrichment', 'is', 'put', 'to', 'test']
# -----------
# Personal health: for teenagers, the car is the danger zone
#
# ['personal', 'health', 'for', 'teenagers', 'the', 'car', 'is', 'the', 'danger', 'zone']
# -----------
# Bird watchers flock to see rare owl
#
# ['bird', 'watchers', 'flock', 'to', 'see', 'rare', 'owl']
# -----------
# Eye on cosmos is lost to short circuit on hubble
#
# ['eye', 'on', 'cosmos', 'is', 'lost', 'to', 'short', 'circuit', 'on', 'hubble']
# -----------
# Too young for this: facing cancer under 40
#
# ['too', 'young', 'for', 'this', 'facing', 'cancer', 'under', '40']
# -----------
# Unilever group names new chairman
#
# ['unilever', 'group', 'names', 'new', 'chairman']
# -----------
# Minister slams airlines on carbon
#
# ['minister', 'slams', 'airlines', 'on', 'carbon']
# -----------
# Rare optimism as North Korea talks reach crossroads
#
# ['rare', 'optimism', 'as', 'north', 'korea', 'talks', 'reach', 'crossroads']
# -----------
# Man beheaded in southern Thailand
#
# ['man', 'beheaded', 'in', 'southern', 'thailand']
# -----------
# China's 'nightmare scenario'
#
# ['china', 'is', 'nightmare', 'scenario']
# -----------
# Annual diving contest in South Korea proves a chilly challenge
#
# ['annual', 'diving', 'contest', 'in', 'south', 'korea', 'proves', 'a', 'chilly', 'challenge']
# -----------
# Blair says he regrets delays in British soldier's inquest
#
# ['blair', 'says', 'he', 'regrets', 'delays', 'in', 'british', 'soldier', 'is', 'inquest']
# -----------
# Iraqi forces detain official suspected in Shia conspiracy
#
# ['iraqi', 'forces', 'detain', 'official', 'suspected', 'in', 'shia', 'conspiracy']
# -----------
# Wellcome awards anti-fat research
#
# ['wellcome', 'awards', 'anti', 'fat', 'research']
# -----------
# Fingers crossed for North Korea
#
# ['fingers', 'crossed', 'for', 'north', 'korea']
# -----------
# No intention of war with Iran, US says
#
# ['no', 'intention', 'of', 'war', 'with', 'iran', 'us', 'says']
# -----------
# What Newsom faces in aftermath of scandal
#
# ['what', 'newsom', 'faces', 'in', 'aftermath', 'of', 'scandal']
# -----------
# Maggie Gyllenhaal's Globes babysitter: Mom
#
# ['maggie', 'gyllenhaal', 'is', 'globes', 'babysitter', 'mom']
# -----------
# As inflation soars, Zimbabwe economy plunges
#
# ['as', 'inflation', 'soars', 'zimbabwe', 'economy', 'plunges']
# -----------
# Pledge: I was abused in frat hazing
#
# ['pledge', 'i', 'was', 'abused', 'in', 'frat', 'hazing']
# -----------
# Experts: Fear likely shackled boy
#
# ['experts', 'fear', 'likely', 'shackled', 'boy']
# -----------
# What's behind the chopper crashes in Iraq
#
# ['what', 'is', 'behind', 'the', 'chopper', 'crashes', 'in', 'iraq']
# -----------
# Freed Muslim terror suspect says Britain is "police state"
#
# ['freed', 'muslim', 'terror', 'suspect', 'says', 'britain', 'is', 'police', 'state']
# -----------
# Blair apologises over friendly fire inquest
#
# ['blair', 'apologises', 'over', 'friendly', 'fire', 'inquest']
# -----------
# Depp 'to make Litvinenko movie'
#
# ['depp', 'to', 'make', 'litvinenko', 'movie']
# -----------
# Why gas follows oil up but not down
#
# ['why', 'gas', 'follows', 'oil', 'up', 'but', 'not', 'down']
# -----------
# 'Cravings' still there, sez Tara
#
# ['cravings', 'still', 'there', 'sez', 'tara']
# -----------
# Bill would strip convicted legislators of pensions
#
# ['bill', 'would', 'strip', 'convicted', 'legislators', 'of', 'pensions']
# -----------
# Bears watch as lead slips away
#
# ['bears', 'watch', 'as', 'lead', 'slips', 'away']
# -----------
# In clue to addiction, brain injury halts smoking
#
# ['in', 'clue', 'to', 'addiction', 'brain', 'injury', 'halts', 'smoking']
# -----------
# In rigorous test, talk therapy works for panic disorder
#
# ['in', 'rigorous', 'test', 'talk', 'therapy', 'works', 'for', 'panic', 'disorder']
# -----------
# Rice: U.S. won't pull plug on Iraq
#
# ['rice', 'u', 'is', 'won', 'not', 'pull', 'plug', 'on', 'iraq']
# -----------
# On road to Kosovo independence, a warning: go slow
#
# ['on', 'road', 'to', 'kosovo', 'independence', 'a', 'warning', 'go', 'slow']
# -----------
# Mistrial for officer who refused to go to Iraq
#
# ['mistrial', 'for', 'officer', 'who', 'refused', 'to', 'go', 'to', 'iraq']
# -----------
# Rebels to join Nepal parliament
#
# ['rebels', 'to', 'join', 'nepal', 'parliament']
# -----------
# EMI warns on profits, boss goes
#
# ['emi', 'warns', 'on', 'profits', 'boss', 'goes']
# -----------
# Subway collapse caught on camera
#
# ['subway', 'collapse', 'caught', 'on', 'camera']
# -----------
# Stinky but true: men's sweat is made for love
#
# ['stinky', 'but', 'true', 'men', 'is', 'sweat', 'is', 'made', 'for', 'love']
# -----------
# POLITICS-US: reprieve for officer who denounced "Immoral War"
#
# ['politics', 'us', 'reprieve', 'for', 'officer', 'who', 'denounced', 'immoral', 'war']
# -----------
# Hunters stalk world's tallest trees
#
# ['hunters', 'stalk', 'world', 'is', 'tallest', 'trees']
# -----------
# Fuel spill may lead to missing jet
#
# ['fuel', 'spill', 'may', 'lead', 'to', 'missing', 'jet']
# -----------
# Sri Lanka floods displace 60,000
#
# ['sri', 'lanka', 'floods', 'displace', '60', '000']
# -----------
# Justin Timberlake, Cameron Diaz announce split
#
# ['justin', 'timberlake', 'cameron', 'diaz', 'announce', 'split']
# -----------
# Iran to hit US interests if attacked
#
# ['iran', 'to', 'hit', 'us', 'interests', 'if', 'attacked']
# -----------
# Israel says hopes to keep Lebanon border calm
#
# ['israel', 'says', 'hopes', 'to', 'keep', 'lebanon', 'border', 'calm']
# -----------
# Cisco sues Apple over iPhone name
#
# ['cisco', 'sues', 'apple', 'over', 'iphone', 'name']
# -----------
# Two Palestinians killed near fence
#
# ['two', 'palestinians', 'killed', 'near', 'fence']
# -----------
# EarthLink CEO dies at age 49
#
# ['earthlink', 'ceo', 'dies', 'at', 'age', '49']
# -----------
# A star dies, a family feud is born
#
# ['a', 'star', 'dies', 'a', 'family', 'feud', 'is', 'born']
# -----------
# Carter was a disaster, said Ford
#
# ['carter', 'was', 'a', 'disaster', 'said', 'ford']
# -----------
# Super Bowl MVP Manning insists he's one of the guys
#
# ['super', 'bowl', 'mvp', 'manning', 'insists', 'he', 'is', 'one', 'of', 'the', 'guys']
# -----------
# Personal health: the importance of knowing what the doctor is talking about
#
# ['personal', 'health', 'the', 'importance', 'of', 'knowing', 'what', 'the', 'doctor', 'is', 'talking', 'about']
# -----------
# Israel's Peretz urges halt to contentious Jerusalem construction
#
# ['israel', 'is', 'peretz', 'urges', 'halt', 'to', 'contentious', 'jerusalem', 'construction']
# -----------
# Peter Jackson will never work for me again
#
# ['peter', 'jackson', 'will', 'never', 'work', 'for', 'me', 'again']
# -----------
# U.S. keeps Iran options open
#
# ['u', 'is', 'keeps', 'iran', 'options', 'open']
# -----------
# European shares hit fresh highs
#
# ['european', 'shares', 'hit', 'fresh', 'highs']
# -----------
# For women, nothing's like the smell of men's sweat
#
# ['for', 'women', 'nothing', 'is', 'like', 'the', 'smell', 'of', 'men', 'is', 'sweat']
# -----------
# Looking beyond the iPhone
#
# ['looking', 'beyond', 'the', 'iphone']
# -----------
# Freed kidnap suspect: my terror at police raid
#
# ['freed', 'kidnap', 'suspect', 'my', 'terror', 'at', 'police', 'raid']
# -----------
# Far away, Super Bowl's losers will be champs
#
# ['far', 'away', 'super', 'bowl', 'is', 'losers', 'will', 'be', 'champs']
# -----------
# Woman dies after water binge
#
# ['woman', 'dies', 'after', 'water', 'binge']
# -----------
# Mancuso sparks U.S. celebrations
#
# ['mancuso', 'sparks', 'u', 'is', 'celebrations']
# -----------
# ASEAN urges North Korea resolution
#
# ['asean', 'urges', 'north', 'korea', 'resolution']
# -----------
# Late penalty costs Roma the points
#
# ['late', 'penalty', 'costs', 'roma', 'the', 'points']
# -----------
# Mistrial declared in teacher-student rape case
#
# ['mistrial', 'declared', 'in', 'teacher', 'student', 'rape', 'case']
# -----------
# 'Bookworm Adventures' wordsmith's joy
#
# ['bookworm', 'adventures', 'wordsmith', 'is', 'joy']
# -----------
# Kylie's love split
#
# ['kylie', 'is', 'love', 'split']
# -----------
# iPod good for video games
#
# ['ipod', 'good', 'for', 'video', 'games']
# -----------
# Review: virtual 'American Idol' hits right notes
#
# ['review', 'virtual', 'american', 'idol', 'hits', 'right', 'notes']
# -----------
# Leo battles himself
#
# ['leo', 'battles', 'himself']
# -----------
# Attorneys point fingers in fight between Ryan O'Neal and son
#
# ['attorneys', 'point', 'fingers', 'in', 'fight', 'between', 'ryan', 'o', 'neal', 'and', 'son']
# -----------
# John Grisham set for court drama
#
# ['john', 'grisham', 'set', 'for', 'court', 'drama']
# -----------
# Bill Gates and Craig Mundie: vista is Secure, employees are not
#
# ['bill', 'gates', 'and', 'craig', 'mundie', 'vista', 'is', 'secure', 'employees', 'are', 'not']
# -----------
# Iraqis fault delayed U.S. plan in attack
#
# ['iraqis', 'fault', 'delayed', 'u', 'is', 'plan', 'in', 'attack']
# -----------
# Boy Scouts blamed for starting wildfire
#
# ['boy', 'scouts', 'blamed', 'for', 'starting', 'wildfire']
# -----------
# China urges UN action on N Korea
#
# ['china', 'urges', 'un', 'action', 'on', 'n', 'korea']
# -----------
# Scorpion on a plane, a pantful of pain
#
# ['scorpion', 'on', 'a', 'plane', 'a', 'pantful', 'of', 'pain']
# -----------
# Male sweat boosts women's hormone levels
#
# ['male', 'sweat', 'boosts', 'women', 'is', 'hormone', 'levels']
# -----------
# Mbeki on the big visit from the Chinese
#
# ['mbeki', 'on', 'the', 'big', 'visit', 'from', 'the', 'chinese']
# -----------
# French right nominates Sarkozy
#
# ['french', 'right', 'nominates', 'sarkozy']
# -----------
# Israeli, Lebanese clash on border
#
# ['israeli', 'lebanese', 'clash', 'on', 'border']
# -----------
# North Korea claims nuclear test
#
# ['north', 'korea', 'claims', 'nuclear', 'test']
# -----------
# Talks begin on Somalia peacekeepers
#
# ['talks', 'begin', 'on', 'somalia', 'peacekeepers']
# -----------
# Action games improve eyesight
#
# ['action', 'games', 'improve', 'eyesight']
# -----------
# A small part of the brain, and its profound effects
#
# ['a', 'small', 'part', 'of', 'the', 'brain', 'and', 'its', 'profound', 'effects']
# -----------
# IDF shells Lebanese Army positions across northern border
#
# ['idf', 'shells', 'lebanese', 'army', 'positions', 'across', 'northern', 'border']
# -----------
# Thailand: missing 25 years after taking wrong bus
#
# ['thailand', 'missing', '25', 'years', 'after', 'taking', 'wrong', 'bus']
# -----------
# Ballerina sparks anti-fascist row
#
# ['ballerina', 'sparks', 'anti', 'fascist', 'row']
# -----------
# Internet boom in China is built on virtual fun
#
# ['internet', 'boom', 'in', 'china', 'is', 'built', 'on', 'virtual', 'fun']
# -----------
# Review: PS3 pricey but impressive
#
# ['review', 'ps3', 'pricey', 'but', 'impressive']
# -----------
# Machinery orders drive Asia upward
#
# ['machinery', 'orders', 'drive', 'asia', 'upward']
# -----------
# 'Lost's' Fox: 'I'm a liar and a cheat'
#
# ['lost', 'is', 'fox', 'i', 'am', 'a', 'liar', 'and', 'a', 'cheat']
# -----------
# Russia to strengthen its military muscle
#
# ['russia', 'to', 'strengthen', 'its', 'military', 'muscle']
# -----------
# At Libby trial, Russert of NBC gives and gets
#
# ['at', 'libby', 'trial', 'russert', 'of', 'nbc', 'gives', 'and', 'gets']
# -----------
# North Korea ready to discuss first steps to nuclear resolution
#
# ['north', 'korea', 'ready', 'to', 'discuss', 'first', 'steps', 'to', 'nuclear', 'resolution']
# -----------
# Victim: Gunman bought drink after shooting
#
# ['victim', 'gunman', 'bought', 'drink', 'after', 'shooting']
# -----------
# Ferrer victorious in Spanish duel
#
# ['ferrer', 'victorious', 'in', 'spanish', 'duel']
# -----------
# UK workers on alert for letter bombs
#
# ['uk', 'workers', 'on', 'alert', 'for', 'letter', 'bombs']
# -----------
# Did NASA accidentally kill life on Mars?
#
# ['did', 'nasa', 'accidentally', 'kill', 'life', 'on', 'mars']
# -----------
# New vaccine for cervical cancer could prove useful in men, too
#
# ['new', 'vaccine', 'for', 'cervical', 'cancer', 'could', 'prove', 'useful', 'in', 'men', 'too']
# -----------
# Search on for victims of subway collapse
#
# ['search', 'on', 'for', 'victims', 'of', 'subway', 'collapse']
# -----------
# Human error caused Helios crash
#
# ['human', 'error', 'caused', 'helios', 'crash']
# -----------
# US to prod NATO allies for more troops to defeat Taliban
#
# ['us', 'to', 'prod', 'nato', 'allies', 'for', 'more', 'troops', 'to', 'defeat', 'taliban']
# -----------
# Microsoft supports OpenID authentication standard
#
# ['microsoft', 'supports', 'openid', 'authentication', 'standard']
# -----------
# No buyer in sight for Napster
#
# ['no', 'buyer', 'in', 'sight', 'for', 'napster']
# -----------
# Briefly: preloaded iPods, Wal-Mart movies, Apple stores
#
# ['briefly', 'preloaded', 'ipods', 'wal', 'mart', 'movies', 'apple', 'stores']
# -----------
# China says rich countries should take lead on global warming
#
# ['china', 'says', 'rich', 'countries', 'should', 'take', 'lead', 'on', 'global', 'warming']
# -----------
# North Korea may begin to dismantle nukes
#
# ['north', 'korea', 'may', 'begin', 'to', 'dismantle', 'nukes']
# -----------
# Tracking down hi-tech crime
#
# ['tracking', 'down', 'hi', 'tech', 'crime']
# -----------
# Barack Obama formally announces bid for president
#
# ['barack', 'obama', 'formally', 'announces', 'bid', 'for', 'president']
# -----------
# Kidnappers seize two in Nigeria
# ['kidnappers', 'seize', 'two', 'in', 'nigeria']
# -----------
# Indonesia may sell, not give, bird flu virus to scientists
#
# ['indonesia', 'may', 'sell', 'not', 'give', 'bird', 'flu', 'virus', 'to', 'scientists']
# -----------
# Attack video saddens "friendly fire" widow
#
# ['attack', 'video', 'saddens', 'friendly', 'fire', 'widow']
# -----------
# Europe retain trophy with big win
#
# ['europe', 'retain', 'trophy', 'with', 'big', 'win']
# -----------
# Cutting edge accessories for digital music players
#
# ['cutting', 'edge', 'accessories', 'for', 'digital', 'music', 'players']
# -----------
# Ice storm descends on central U.S.
#
# ['ice', 'storm', 'descends', 'on', 'central', 'u', 'is']
# -----------
# Snow brings travel misery to England
#
# ['snow', 'brings', 'travel', 'misery', 'to', 'england']
# -----------
# Indonesia flood forces 340,000 from homes
#
# ['indonesia', 'flood', 'forces', '340', '000', 'from', 'homes']
# -----------
# Iraqi health minister seized in raid
#
# ['iraqi', 'health', 'minister', 'seized', 'in', 'raid']
# -----------
# Ice storm brings chaos in U.S.
#
# ['ice', 'storm', 'brings', 'chaos', 'in', 'u', 'is']
# -----------
# Stinky flower mystery solved
#
# ['stinky', 'flower', 'mystery', 'solved']
# -----------
# Congressman rebukes U.S. allies for lack of support in Afghanistan
#
# ...
# -----------
# Peru leader questioned in massacre probe
#
# ['peru', 'leader', 'questioned', 'in', 'massacre', 'probe']
# -----------
# U.S. commander: Iraq not hopeless
#
# ['u', 'is', 'commander', 'iraq', 'not', 'hopeless']
# -----------
# Australian PM stands by Obama attack
#
# ['australian', 'pm', 'stands', 'by', 'obama', 'attack']
# -----------
# Mardi Gras rebound in the offing for New Orleans?
#
# ['mardi', 'gras', 'rebound', 'in', 'the', 'offing', 'for', 'new', 'orleans']
# -----------
# Siestas may cut heart disease risk
#
# ['siestas', 'may', 'cut', 'heart', 'disease', 'risk']
# -----------
# Oregon snorkeler mistaken for rodent, shot in face
#
# ['oregon', 'snorkeler', 'mistaken', 'for', 'rodent', 'shot', 'in', 'face']
# -----------
# Petraeus takes command in Iraq
#
# ['petraeus', 'takes', 'command', 'in', 'iraq']
# -----------
# 6 dead after Utah Mall shooting rampage
#
# ['6', 'dead', 'after', 'utah', 'mall', 'shooting', 'rampage']
# -----------
# Sharks kill four people in 'dull' year
#
# ['sharks', 'kill', 'four', 'people', 'in', 'dull', 'year']
# -----------
# Record-shattering day on Wall St.
#
# ['record', 'shattering', 'day', 'on', 'wall', 'st']
# -----------
# Comedian says government silences critics
#
# ['comedian', 'says', 'government', 'silences', 'critics']
# -----------
# Rockers big winners at Brit Awards
#
# ['rockers', 'big', 'winners', 'at', 'brit', 'awards']
# -----------
# Samba school leader killed before Rio carnival
#
# ['samba', 'school', 'leader', 'killed', 'before', 'rio', 'carnival']
# -----------
# Taiwan's 'Mr. Clean' indicted, steps down
#
# ['taiwan', 'is', 'mr', 'clean', 'indicted', 'steps', 'down']
# -----------
# Woman fights to keep drunken driver in jail
# ['woman', 'fights', 'to', 'keep', 'drunken', 'driver', 'in', 'jail']
# -----------
# Al Qaeda group calls for attacks on U.S. oil
#
# ['al', 'qaeda', 'group', 'calls', 'for', 'attacks', 'on', 'u', 'is', 'oil']
# -----------
# Cousin: Gunman was Srebrenica survivor
#
# ['cousin', 'gunman', 'was', 'srebrenica', 'survivor']
# -----------
# Turkmenistan votes for president
#
# ['turkmenistan', 'votes', 'for', 'president']
# -----------
# Here is some advice to take to heart...
#
# ['here', 'is', 'some', 'advice', 'to', 'take', 'to', 'heart']
# -----------
# 10 don't-miss tax breaks
#
# ['10', 'don', 'not', 'miss', 'tax', 'breaks']
# -----------
# Police break up Kosovo protests
#
# ['police', 'break', 'up', 'kosovo', 'protests']
# -----------
# Messi makes Barcelona squad return
#
# ['messi', 'makes', 'barcelona', 'squad', 'return']
# -----------
# Jump reported in accidental drug-overdose deaths
#
# ['jump', 'reported', 'in', 'accidental', 'drug', 'overdose', 'deaths']
# -----------
# Catania punished for fan violence
#
# ['catania', 'punished', 'for', 'fan', 'violence']
# -----------
# Isinbayeva sets 20th world record
#
# ['isinbayeva', 'sets', '20th', 'world', 'record']
# -----------
# Lawmakers blast FDA drug safety oversight
#
# ['lawmakers', 'blast', 'fda', 'drug', 'safety', 'oversight']
# -----------
# Regular naps make hearts healthy
#
# ['regular', 'naps', 'make', 'hearts', 'healthy']
# -----------
# Ice stops trolleys cold
#
# ['ice', 'stops', 'trolleys', 'cold']
# -----------
# U.S. gunman 'was Srebrenica survivor'
#
# ['u', 'is', 'gunman', 'was', 'srebrenica', 'survivor']
# -----------
# Outdated baby food found on shelves
#
# ['outdated', 'baby', 'food', 'found', 'on', 'shelves']
# -----------
# Tow truck drivers accused of stealing cars
#
# ['tow', 'truck', 'drivers', 'accused', 'of', 'stealing', 'cars']
# -----------
# Bush: It's time for Congress to back energy plan
#
# ['bush', 'it', 'is', 'time', 'for', 'congress', 'to', 'back', 'energy', 'plan']
# -----------
# UK soldiers cleared of Iraq abuse
#
# ['uk', 'soldiers', 'cleared', 'of', 'iraq', 'abuse']
# -----------
# FDA revises label warnings on the antibiotic Ketek
#
# ['fda', 'revises', 'label', 'warnings', 'on', 'the', 'antibiotic', 'ketek']
# -----------
# Toshiba Portege R400
#
# ['toshiba', 'portege', 'r400']
# -----------
# South Africa mourns Adelaide Tambo
#
# ['south', 'africa', 'mourns', 'adelaide', 'tambo']
# -----------
# Evacuees can return home after plant blast
#
# ['evacuees', 'can', 'return', 'home', 'after', 'plant', 'blast']
# -----------
# Anna Nicole Smith's body lies in legal limbo
#
# ['anna', 'nicole', 'smith', 'is', 'body', 'lies', 'in', 'legal', 'limbo']
# -----------
# Former teacher poses for Playboy
#
# ['former', 'teacher', 'poses', 'for', 'playboy']
# -----------
# France rejects Rwandan investigators
#
# ['france', 'rejects', 'rwandan', 'investigators']
# -----------
# A nap a day may keep the heart doctor away
#
# ['a', 'nap', 'a', 'day', 'may', 'keep', 'the', 'heart', 'doctor', 'away']
# -----------
# Higley, Gonzalez lead in Malaysia
#
# ['higley', 'gonzalez', 'lead', 'in', 'malaysia']
# -----------
# Grammys ready to name winners
#
# ['grammys', 'ready', 'to', 'name', 'winners']
# -----------
# Pound will not drop Armstrong case
#
# ['pound', 'will', 'not', 'drop', 'armstrong', 'case']
# -----------
# Reunited Police to start world tour in May
#
# ['reunited', 'police', 'to', 'start', 'world', 'tour', 'in', 'may']
# -----------
# Turkmen acting leader sworn in as new president
#
# ['turkmen', 'acting', 'leader', 'sworn', 'in', 'as', 'new', 'president']
# -----------
# Allen and Okur get All-Star call
#
# ['allen', 'and', 'okur', 'get', 'all', 'star', 'call']
# -----------
# Svindal claims are golden double
#
# ['svindal', 'claims', 'are', 'golden', 'double']
# -----------
# Trolley Square shooting leaves 6 dead, including gunman
#
# ['trolley', 'square', 'shooting', 'leaves', '6', 'dead', 'including', 'gunman']
# -----------
# Bridge blast stops I-95 traffic
#
# ['bridge', 'blast', 'stops', 'i', '95', 'traffic']
# -----------
# Mother, daughter stabbed near school
#
# ['mother', 'daughter', 'stabbed', 'near', 'school']
# -----------
# Excerpt: Politicians and the press
#
# ['excerpt', 'politicians', 'and', 'the', 'press']
# -----------
# North Korea gets 'money and respect'
#
# ['north', 'korea', 'gets', 'money', 'and', 'respect']
# -----------
# Beyonce in a bikini as SI's swimsuit cover model
#
# ['beyonce', 'in', 'a', 'bikini', 'as', 'si', 'is', 'swimsuit', 'cover', 'model']
# -----------
# Loving with all your ... brain
#
# ['loving', 'with', 'all', 'your', 'brain']
# -----------
# Shoplifters' choice: Police or T-shirt of shame
#
# ['shoplifters', 'choice', 'police', 'or', 'not', 'shirt', 'of', 'shame']
# -----------
# Cuban official: Web a 'wild colt'
#
# ['cuban', 'official', 'web', 'a', 'wild', 'colt']
# -----------
# Slow 'Music and Lyrics'
#
# ['slow', 'music', 'and', 'lyrics']
# -----------
# Mexican navy helps in hunt for U.S. engineer
#
# ['mexican', 'navy', 'helps', 'in', 'hunt', 'for', 'u', 'is', 'engineer']
# -----------
# Smith baby may not be pot of gold
#
# ['smith', 'baby', 'may', 'not', 'be', 'pot', 'of', 'gold']
# -----------
# Latest updates on world's top stories
#
# ['latest', 'updates', 'on', 'world', 'is', 'top', 'stories']
# -----------
# Beating leaves teen in coma
#
# ['beating', 'leaves', 'teen', 'in', 'coma']
# -----------
# Tiempo Libre has Grammy dreams
#
# ['tiempo', 'libre', 'has', 'grammy', 'dreams']
# -----------
# GPS sneakers locate with press of a button
#
# ['gps', 'sneakers', 'locate', 'with', 'press', 'of', 'a', 'button']
# -----------
# Embattled Edwards blogger quits campaign
#
# ['embattled', 'edwards', 'blogger', 'quits', 'campaign']
# -----------
# Britons deported from Somalia held under Terrorism Act
#
# ['britons', 'deported', 'from', 'somalia', 'held', 'under', 'terrorism', 'act']
# -----------
# Updates on world's top stories
#
# ['updates', 'on', 'world', 'is', 'top', 'stories']
# -----------
# Breast cancer drug promises hope
#
# ['breast', 'cancer', 'drug', 'promises', 'hope']
# -----------
# Ancient coin shows Cleopatra was no beauty
#
# ['ancient', 'coin', 'shows', 'cleopatra', 'was', 'no', 'beauty']
# -----------
# YouTube yields surprising payback
#
# ['youtube', 'yields', 'surprising', 'payback']
# -----------
# Up to 22 inches of snow in forecast
#
# ['up', 'to', '22', 'inches', 'of', 'snow', 'in', 'forecast']
# -----------
# Werder make 10-man Ajax pay price
#
# ['werder', 'make', '10', 'man', 'ajax', 'pay', 'price']
# -----------
# EU condemns 'illegal' CIA flights
#
# ['eu', 'condemns', 'illegal', 'cia', 'flights']
# -----------
# Report links humans to global warming
#
# ['report', 'links', 'humans', 'to', 'global', 'warming']
# -----------
# UN nuclear watchdog slashes Iran aid
#
# ['un', 'nuclear', 'watchdog', 'slashes', 'iran', 'aid']
# -----------
# Survey: Tech a tool in teen dating abuse
#
# ['survey', 'tech', 'a', 'tool', 'in', 'teen', 'dating', 'abuse']
# -----------
# The breast cancer breakthrough saving 1000 women a year
#
# ['the', 'breast', 'cancer', 'breakthrough', 'saving', '1000', 'women', 'a', 'year']
# -----------
# Tourist spot resists gravity, but not progress
#
# ['tourist', 'spot', 'resists', 'gravity', 'but', 'not', 'progress']
# -----------
# The NFL's 20 biggest potential free agents
#
# ['the', 'nfl', 'is', '20', 'biggest', 'potential', 'free', 'agents']
# -----------
# World tourism sets record in 2006
#
# ['world', 'tourism', 'sets', 'record', 'in', '2006']
# -----------
# BA to charge $470 for an extra bag
#
# ['ba', 'to', 'charge', '470', 'for', 'an', 'extra', 'bag']
# -----------
# Kuerten returns to winners' circle
#
# ['kuerten', 'returns', 'to', 'winners', 'circle']
# -----------
# World's oldest newspaper now exists only online
#
# ['world', 'is', 'oldest', 'newspaper', 'now', 'exists', 'only', 'online']
# -----------
# Japanese whaler afire in Antarctic
#
# ['japanese', 'whaler', 'afire', 'in', 'antarctic']
# -----------
# EU document: Iranian bomb unstoppable
#
# ['eu', 'document', 'iranian', 'bomb', 'unstoppable']
# -----------
# U.S. urged to lead on 'green' actions
#
# ['u', 'is', 'urged', 'to', 'lead', 'on', 'green', 'actions']
# -----------
# See if your city is one of the United States' top 10 fittest or fattest
#
# ['see', 'if', 'your', 'city', 'is', 'one', 'of', 'the', 'united', 'states', 'top', '10', 'fittest', 'or', 'fattest']
# -----------
# Lee in pre-World Cup injury scare
#
# ['lee', 'in', 'pre', 'world', 'cup', 'injury', 'scare']
# -----------
# New cancer drug to save a thousand lives a year
#
# ['new', 'cancer', 'drug', 'to', 'save', 'a', 'thousand', 'lives', 'a', 'year']
# -----------
# Ex-teacher guilty in nude-pictures scheme
#
# ['ex', 'teacher', 'guilty', 'in', 'nude', 'pictures', 'scheme']
# -----------
# Fire extinguisher part of Tennessee execution kit
#
# ['fire', 'extinguisher', 'part', 'of', 'tennessee', 'execution', 'kit']
# -----------
# Founder returns to Dell helm
#
# ['founder', 'returns', 'to', 'dell', 'helm']
# -----------
# Charles Gibson takes over first place
#
# ['charles', 'gibson', 'takes', 'over', 'first', 'place']
# -----------
# Ex-Border Patrol agent beaten in prison
#
# ['ex', 'border', 'patrol', 'agent', 'beaten', 'in', 'prison']
# -----------
# 'Made in China' irks some Burberry shoppers
#
# ['made', 'in', 'china', 'irks', 'some', 'burberry', 'shoppers']
# -----------
# Stonehenge workers' village found
#
# ['stonehenge', 'workers', 'village', 'found']
# -----------
# Who is Prince Frederic von Anhalt?
#
# ['who', 'is', 'prince', 'frederic', 'von', 'anhalt']
# -----------
# Latest food-fad -- 'space potatoes'
#
# ['latest', 'food', 'fad', 'space', 'potatoes']
# -----------
# Ethiopia readies for millennium all its own
#
# ['ethiopia', 'readies', 'for', 'millennium', 'all', 'its', 'own']
# -----------
# Good news for slackers: Naps may cut risk for heart problems
#
# ['good', 'news', 'for', 'slackers', 'naps', 'may', 'cut', 'risk', 'for', 'heart', 'problems']
# -----------
# Snowbirds shortening their Florida stays
#
# ['snowbirds', 'shortening', 'their', 'florida', 'stays']
# -----------
# Win a (concert) date with the Police
#
# ['win', 'a', 'concert', 'date', 'with', 'the', 'police']
# -----------
# Snow begins, heavy accumulations expected
#
# ['snow', 'begins', 'heavy', 'accumulations', 'expected']
# -----------
# Jet flips in snowstorm, none dead
#
# ['jet', 'flips', 'in', 'snowstorm', 'none', 'dead']
# -----------
# Frantic 911 call in Ryan O'Neal case
#
# ['frantic', '911', 'call', 'in', 'ryan', 'o', 'neal', 'case']
# -----------
# Durant's success trumps the Gators
#
# ['durant', 'is', 'success', 'trumps', 'the', 'gators']
# -----------
# Scientist snoops in astronauts' journals
#
# ['scientist', 'snoops', 'in', 'astronauts', 'journals']
# -----------
# YouTube founders split $650M payout
#
# ['youtube', 'founders', 'split', '650m', 'payout']
# -----------
# African nation hopes Whoopi can help
#
# ['african', 'nation', 'hopes', 'whoopi', 'can', 'help']
# -----------
# United hang on to six-point lead
#
# ['united', 'hang', 'on', 'to', 'six', 'point', 'lead']
# -----------
# Lawyer seizes Smith's Bahamas home
#
# ['lawyer', 'seizes', 'smith', 'is', 'bahamas', 'home']
# -----------
# Was Prince's super show too revealing?
#
# ['was', 'prince', 'is', 'super', 'show', 'too', 'revealing']
# -----------
# Clijsters looks for a long goodbye
#
# ['clijsters', 'looks', 'for', 'a', 'long', 'goodbye']
# -----------
# Snow's too deep even for snowmobiles
#
# ['snow', 'is', 'too', 'deep', 'even', 'for', 'snowmobiles']
# -----------
# Study: Female seals picky about mates
#
# ['study', 'female', 'seals', 'picky', 'about', 'mates']
# -----------
# ROUNDUP: Protests erupt despite "state of siege" In Guinea
#
# ['roundup', 'protests', 'erupt', 'despite', 'state', 'of', 'siege', 'in', 'guinea']
# -----------
# Study: More kids exposed to online porn
#
# ['study', 'more', 'kids', 'exposed', 'to', 'online', 'porn']
# -----------
# Beyonce new SI bikini cover girl
#
# ['beyonce', 'new', 'si', 'bikini', 'cover', 'girl']
# -----------
# Marijuana helps ease HIV nerve pain, study says
#
# ['marijuana', 'helps', 'ease', 'hiv', 'nerve', 'pain', 'study', 'says']
# -----------
# Serena misses Bangalore tournament
#
# ['serena', 'misses', 'bangalore', 'tournament']
# -----------
# Dryer blamed for fire killing 39 cats, dogs
#
# ['dryer', 'blamed', 'for', 'fire', 'killing', '39', 'cats', 'dogs']
# -----------
# Roddick, Murray score in San Jose
#
# ['roddick', 'murray', 'score', 'in', 'san', 'jose']
# -----------
# Apple trademark dispute settled
#
# ['apple', 'trademark', 'dispute', 'settled']
# -----------
# U.S. online love brokers eye China
#
# ['u', 'is', 'online', 'love', 'brokers', 'eye', 'china']
# -----------
# U.S. diverts troops to fight Taliban
#
# ['u', 'is', 'diverts', 'troops', 'to', 'fight', 'taliban']
# -----------
# 'House of Cards' actor Ian Richardson dead
#
# ['house', 'of', 'cards', 'actor', 'ian', 'richardson', 'dead']
# -----------
# Taliban leader killed in airstrike
#
# ['taliban', 'leader', 'killed', 'in', 'airstrike']
# -----------
# Escape to Prague without the summer hordes
#
# ['escape', 'to', 'prague', 'without', 'the', 'summer', 'hordes']
# -----------
# Kathmandu: First snow in 63 years
#
# ['kathmandu', 'first', 'snow', 'in', '63', 'years']
# -----------
# Nasdaq fails in bid for LSE
#
# ['nasdaq', 'fails', 'in', 'bid', 'for', 'lse']
# -----------
# Ex-pastor gets death sentence
#
# ['ex', 'pastor', 'gets', 'death', 'sentence']
# -----------
# Baby born on turnpike after dad misses exit
#
# ['baby', 'born', 'on', 'turnpike', 'after', 'dad', 'misses', 'exit']
# -----------
# Study links chimps and 'hammers'
#
# ['study', 'links', 'chimps', 'and', 'hammers']
# -----------
# UN-Google Earth map climate change
#
# ['un', 'google', 'earth', 'map', 'climate', 'change']
# -----------
# ['test', 'to', 'predict', 'breast', 'cancer', 'relapse', 'is', 'approved']
# Average:  6
# schuey *---* ['schuey', 'sees', 'ferrari', 'unveil', 'new', 'car']
# bananaconda *---* ['bananaconda', 'inventor', 'is', 'top', 'poet', 'of', 'kids']
# upgraders *---* ['apple', 'to', 'vista', 'upgraders', 'wait']
# blissing *---* ['blissing', 'out', 'in', 'ojai']
# 65bn *---* ['google', 'buys', 'youtube', 'for', '1', '65bn']
# pantful *---* ['scorpion', 'on', 'a', 'plane', 'a', 'pantful', 'of', 'pain']
# edns *---* ['mideast', 'summit', 'edns', 'with', 'little', 'progress']
# hitfactory *---* ['reopening', 'bird', 'flu', 'hitfactory', 'ignores', 'risks', 'poultryman']
# revells *---* ['bruce', 'revells', 'in', 'upset']
# thrillville *---* ['create', 'own', 'thrillville', 'for', 'a', 'wild', 'ride']
# portege *---* ['toshiba', 'portege', 'r400']
# Sentences integer representation:  (1000, 6)
# Sentences:  1000
# Integer format [7.2800e+02 4.0000e+00 6.3260e+03 5.3530e+03 1.6470e+03 3.0492e+04]
# Normal format ['test', 'to', 'predict', 'breast', 'cancer', 'relapse', 'is', 'approved']
# Y_train:  (1000, 5)  Num Ejem X 5 clases
# X_train:  (1000, 6)  Num Ejem X Maximun Lengh

# %% [markdown]
# RNN Model

# %%
batchSize = 50 #Tiene que ser multiplo del NumEjem
lstmUnits = 64
numClasses = 5

# %% [markdown]
# Declarando placeholders para los labels (5 emotions) && data imput

# %%
import tensorflow as tf
tf.reset_default_graph()
numDimensions = 300 

#labels = tf.placeholder(tf.float32, [batchSize, numClasses])
#input_data = tf.placeholder(tf.int32, [batchSize, maxSeqLength])
labels = tf.placeholder(tf.float32, [None, numClasses])
input_data = tf.placeholder(tf.int32, [None, maxSeqLength])

# %% [markdown]
# Embeddings: Le damos el formato a nuestra data, aún no compilamos nada, solo declaramos

# %%
data = tf.Variable(tf.zeros([batchSize, maxSeqLength, numDimensions]),dtype=tf.float32)
data = tf.nn.embedding_lookup(wordVectors,input_data)

# %% [markdown]
# LSTM Model

# %%
lstmCell = tf.contrib.rnn.BasicLSTMCell(lstmUnits)
lstmCell = tf.contrib.rnn.DropoutWrapper(cell=lstmCell, output_keep_prob=0.75)
value, _ = tf.nn.dynamic_rnn(lstmCell, data, dtype=tf.float32)

# %%
weight = tf.Variable(tf.truncated_normal([lstmUnits, numClasses]))
bias = tf.Variable(tf.constant(0.1, shape=[numClasses]))
value = tf.transpose(value, [1, 0, 2])
last = tf.gather(value, int(value.get_shape()[0]) - 1)
prediction = (tf.matmul(last, weight) + bias)

# %%
correctPred = tf.equal(tf.argmax(prediction,1), tf.argmax(labels,1))
accuracy = tf.reduce_mean(tf.cast(correctPred, tf.float32))

# %%
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=prediction, labels=labels))
optimizer = tf.train.AdamOptimizer().minimize(loss)
# Out:
# C:\Users\UX310UQ\Anaconda3\envs\IaTopicos\lib\site-packages\tensorflow\python\ops\gradients_impl.py:100: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %% [markdown]
# Tensorboar

# %%
import datetime
def board(sess):
    tf.summary.scalar('Loss', loss)
    tf.summary.scalar('Accuracy', accuracy)
    tf.summary.histogram("Histogrma/hAccu", accuracy)
    merged = tf.summary.merge_all()
    logdir = "board/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + "/"
    writer = tf.summary.FileWriter(logdir, sess.graph)
    return merged,writer

# %% [markdown]
# Confusion Matrix Plot

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
# Initializing the variables
init = tf.global_variables_initializer()
display_step = 10
numEjemplos = 250
iterations = 10

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    #Calling tensorboard function
    #---merged,writer = board(sess)
    
    # Training cycle
    for epoch in range(iterations):
        avg_cost = 0.
        total_batch = int(numEjemplos/batchSize)
        
        #Create X groups of (50,5) Labels && (50,maximum) Examples
        X_batches = np.array_split(X_train, total_batch)
        Y_batches = np.array_split(Y_train, total_batch)
        # Loop over all batches
        for i in range(total_batch):
            batch_x, batch_y = X_batches[i], Y_batches[i]
            #print("X: ",batch_x.shape)
            #print("Y: ",batch_y.shape)
            # Run optimization op (backprop) and cost op (to get loss value)
            _, c , accu= sess.run([optimizer, loss, accuracy], feed_dict={input_data: batch_x,
                                                          labels: batch_y})
            # Compute average loss
            avg_cost += c / total_batch

            #Write summary to Tensorboard
            '''if (epoch % 10 == 0):
                summary = sess.run(merged, {input_data: batch_x, labels: batch_y})
                writer.add_summary(summary, epoch)'''
            

            #Save the network every 10,000 training iterations
            #if (i % 10000 == 0 and i != 0):
                # save_path = saver.save(sess, "models/pretrained_lstm.ckpt", global_step=i)
                 # print("saved to %s" % save_path)
            #writer.close()

        if epoch % display_step == 0:
            print("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(avg_cost)," accuracy=", "{:.9f}".format(accu*100))
    print("Optimization Finished!")
    
    #Test Model LSTM  
    correctPred = tf.equal(tf.argmax(prediction,1), tf.argmax(labels,1))
    # Calculate accuracy
    accuracy = tf.reduce_mean(tf.cast(correctPred, "float"))
    print("Accuracy:", accuracy.eval({input_data: X_test, labels: Y_test}))
    
    #Matriz de confusion

    print("Test Samples, Class Predictions: ")
    result = tf.argmax(prediction , 1).eval({input_data: X_test, labels: Y_test})
    print(result.shape)
    
    print("Test Samples, Class Truth Labels: ")
    print(Y_test.shape)
    
    print("Test Samples: ")
    test = (tf.argmax(Y_test , 1).eval()) #Convierte de [0,0,1,0,0] a [2] y lo hace np.array
    print(test.shape)
      

    from sklearn.metrics import confusion_matrix
    y_true = test
    y_pred = result
    print(confusion_matrix(y_true, y_pred))
    class_names = ["Anger","Disgust","Fear","Joy","Surprise"]
    
    from sklearn.metrics import precision_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import recall_score
    print("Precision: ",precision_score(y_true, y_pred, average=None))
    print("Recall: ",recall_score(y_true, y_pred, average=None))
    print("F1: ",f1_score(y_true, y_pred, average=None))

    # Compute confusion matrix
    cnf_matrix = confusion_matrix(y_true, y_pred)
    np.set_printoptions(precision=2)

    # Plot non-normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names,
                          title='Confusion matrix, without normalization')

    # Plot normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                          title='Normalized confusion matrix')

    plt.show()
# Out:
# Epoch: 0001 cost= 2.248742676  accuracy= 18.000000715
# Optimization Finished!
# Accuracy: 0.342
# Test Samples, Class Predictions:
# (1000,)
# Test Samples, Class Truth Labels:
# (1000, 5)
# Test Samples:
# (1000,)
# [[  3  15  20   8  38]
#  [  5  29  44  13  81]
#  [  1  17 110  14 114]
#  [  3  13  37  48  65]
#  [ 17  40 105  35 125]]
# Precision:  [0.10344828 0.25438596 0.34810127 0.40677966 0.29550827]
# Recall:  [0.03571429 0.16860465 0.4296875  0.28915663 0.38819876]
# F1:  [0.05309735 0.2027972  0.38461538 0.33802817 0.33557047]
# Confusion matrix, without normalization
# [[  3  15  20   8  38]
#  [  5  29  44  13  81]
#  [  1  17 110  14 114]
#  [  3  13  37  48  65]
#  [ 17  40 105  35 125]]
# Normalized confusion matrix
# [[0.04 0.18 0.24 0.1  0.45]
#  [0.03 0.17 0.26 0.08 0.47]
#  [0.   0.07 0.43 0.05 0.45]
#  [0.02 0.08 0.22 0.29 0.39]
#  [0.05 0.12 0.33 0.11 0.39]]

# %%
#Exporting For Heterogenious Dataset
print(len(sentences))
print(len(emotions))
def writeDataset(emotions,sentences):
    file = open("affectCorpus.txt","w") 
    for i in range(0,len(emotions)):
        linea = str(emotions[i]) + '#' + sentences[i]
        file.write(linea) 
    file.close()
# Out:
# 250
# 250

# %%
writeDataset(emotions,sentences)

# %%
#Corrgir emocions HP = 0 ...
