# %%
#!/usr/bin/python
import nltk
import numpy as np
import re
import tensorflow as tf
from nltk.corpus import stopwords
from nltk.tokenize import WordPunctTokenizer
from random import randint
from sklearn.model_selection import train_test_split
import random
import pandas as pd
import itertools
from nltk.stem.wordnet import WordNetLemmatizer

# %% [markdown]
# Importing Glove and  40000 words list

# %%
wordsList = np.load('wordsList.npy')
print('Loaded the word list!')
wordsList = wordsList.tolist() #Originally loaded as numpy array
wordsList = [word.decode('UTF-8') for word in wordsList] #Encode words as UTF-8
wordVectors = np.load('wordVectors.npy')
print ('Loaded the word vectors!')
print(len(wordsList))
print(wordVectors.shape)
print(wordsList[5066])
print(wordVectors[5066][:])
# Out:
# Loaded the word list!
# Loaded the word vectors!
# 400000
# (400000, 50)
# closure
# [ 0.50653   0.12284  -0.11653  -0.21052  -1.0672   -0.17536   0.16253
#   0.76781   0.25517  -0.15995   0.025424 -0.65425  -0.44638  -0.19395
#   0.45319   1.0955    0.050096 -0.36712   0.1729    0.28393   0.85448
#  -0.54932  -1.1816    0.066158 -0.58561  -0.84893   0.1947    0.37832
#   0.94141   0.62982   2.3869   -0.41035  -0.11599   0.049907 -0.41563
#  -0.056999  1.5044   -0.93772  -0.16045   0.80019  -0.44448  -0.50036
#   0.065875  0.27778  -0.27505  -0.012317 -0.37458   0.49171  -0.35498
#   0.035347]

# %% [markdown]
# Importing the Dataset

# %%
#--------------------Extracting Emotion && sentences from corpus
def extract(dataset):
    f = open(dataset, 'r+', encoding='utf-8')
    linea = f.readline()
    emotion = []
    sentences = []
    neutro = re.compile('^ne')
    while linea != "":    
        #Ignoramos Neutro emotions
        if not re.match(neutro, linea):
            #print("** ",linea)
            linea = linea.split("**@**")
            #Obtaining the emocion
            emotion.append(linea[2])
            sentences.append(linea[1])
        linea = f.readline()
    f.close()
    return sentences,emotion

dataset = "TwitterDataset/Train/allEmo.txt"
sentences,emotions = extract(dataset)
print(emotions[0]," ",sentences[0])
print("Labels: ",len(emotions), "Sentences: ",len(sentences))
# Out:
# anger   How the fu*k! Who the heck! moved my fridge!... should I knock the landlord door. #angry #mad ##
# Labels:  3613 Sentences:  3613

# %%
import csv
with open('TwitterDataset/Train/emotions.csv', mode='w', encoding='utf-8') as emo_file:
    emo_writer = csv.writer(emo_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    emo_writer.writerow(['Emotion', 'Sentence'])
    for i in range(0,len(emotions)):
        emo_writer.writerow([emotions[i],sentences[i]])
    
train = pd.read_csv("TwitterDataset/Train/emotions.csv", delimiter=",")
train.head()
# Out:
#   Emotion                                           Sentence
# 0   anger  How the fu*k! Who the heck! moved my fridge!.....
# 1   anger  So my Indian Uber driver just called someone t...
# 2   anger  @DPD_UK I asked for my parcel to be delivered ...
# 3   anger  so ef whichever butt wipe pulled the fire alar...
# 4   anger  Don't join @BTCare they put the phone down on ...

# %% [markdown]
# Cuánto hay de cada emoción

# %%
import matplotlib.pyplot as plt
import collections
# %matplotlib inline
def histograma(emotion):
    #print(emotion)
    plt.hist(emotion, 50)
    plt.xlabel('Emotion')
    plt.ylabel('Frequency')
    plt.axis([0, 4, 0, 1200])
    plt.show()
histograma(emotions)

# %% [markdown]
# Preprocesing of Sentences

# %%
def decontracted(phrase):
    # specific
    '''phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)'''

    if phrase == "t":
        phrase = "not"
    elif phrase == "re":
        phrase = "are"
    elif phrase == "s":
        phrase = "is"
    elif phrase == "d":
        phrase = "would"
    elif phrase == "ve":
        phrase = "have"
    elif phrase == "m":
        phrase = "am"
    elif phrase == "ca":
        phrase = "can"
    elif phrase == "isn":
        phrase = "is"
    elif phrase == "aren":
        phrase = "are"
    elif phrase == "wouldn":
        phrase = "would"
    elif phrase == "don":
        phrase = "do"
    elif phrase == "wasn":
        phrase = "was"
    elif phrase == "weren":
        phrase = "were"

    # general
    '''phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)'''
    return phrase

# %%
def translator(user_string):
    user_string = user_string.lower()
    user_string = WordPunctTokenizer().tokenize(user_string)
    j = 0
    for _str in user_string:
        # File path which consists of Abbreviations.
        fileName = "TwitterDataset/slang.txt"
        # File Access mode [Read Mode]
        accessMode = "r"
        with open(fileName, accessMode) as myCSVfile:
            # Reading file as CSV with delimiter as "=", so that abbreviation are stored in row[0] and phrases in row[1]
            dataFromFile = csv.reader(myCSVfile, delimiter="=")
            # Removing Special Characters.
            _str = re.sub('[^a-zA-Z0-9-_.]', '', _str)
            for row in dataFromFile:
                # Check if selected word matches short forms[LHS] in text file.
                if _str.upper() == row[0]:
                    # If match found replace it with its Abbreviation in text file.
                    user_string[j] = row[1].lower()
            myCSVfile.close()
        j = j + 1
    return user_string

# %%
#----------------Cleanning Sentences--------------
lem = WordNetLemmatizer()
def clean_text(text, remove_stopwords=False):
    '''Clean the text, with the option to remove stopwords'''
    #Remove @user or http://...
    text = re.sub(r"(@[A-Za-z0-9_]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",text) 

    # Translate OMG to Oh My God
    text = translator(text)
    #Decontracs
    for w in range (0,len(text)):
        text[w] = decontracted(text[w])

    # Convert words to lower case and split them
    #text = text.lower()#.split()

    # Optionally, remove stop words
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        text = [w for w in text if not w in stops]
    
    text = " ".join(text)

    # Clean the text
    text = re.sub(r"<br />", " ", text)
    text = re.sub(r"[^a-z]", " ", text)
    text = re.sub(r"   ", " ", text) # Remove any extra spaces
    text = re.sub(r"  ", " ", text)
    
    #Lematize && itertools Ejmp: looove to love
    text = ''.join(''.join(s)[:2] for _, s in itertools.groupby(text))
    text = lem.lemmatize(text, "v")
    
    # Return a list of words
    return(text)


train_clean = []
for sentence in train.Sentence:
    train_clean.append(clean_text(sentence))

# %%
# Inspect the cleaned reviews
for i in range(3):
    print(sentences[i])
    print(train_clean[i])
    print()
# Out:
# How the fu*k! Who the heck! moved my fridge!... should I knock the landlord door. #angry #mad ##
# how the fu k who the heck moved my fridge should i knock the landlord door angry mad
#
# So my Indian Uber driver just called someone the N word. If I wasn't in a moving vehicle I'd have jumped out #disgusted
# so my indian uber driver just called someone the n word if i was not in a moving vehicle i would have jumped out disgusted
#
# @DPD_UK I asked for my parcel to be delivered to a pick up store not my address #fuming #poorcustomerservice
# i asked for my parcel to be delivered to a pick up store not my address fuming poorcustomerservice

# %% [markdown]
# Les't determine the total and average number of words in each sentencesLes't determine the total and average number of words in each sentences

# %%
def maximum(sent):
    numWords = []
    for s in sent:
        counter = len(s)
        numWords.append(counter) 
    maxLengh = int(sum(numWords)/len(numWords))
    print("Average: ", maxLengh)
    return numWords,maxLengh
numWords,maxSeqLength = maximum(train_clean)
# Out:
# Average:  83

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
def histograma(numWords):
    plt.hist(numWords, 50)
    plt.xlabel('Sequence Length')
    plt.ylabel('Frequency')
    plt.axis([0, 70, 0, 500])
    plt.show()
histograma(numWords)

# %% [markdown]
# Converting each sentence into a vector and adding it into a matrix of 'ids'

# %%
def integerSenteces(sent,maximum):
    i = 0
    embbeding = 0
    matrix = np.zeros((len(sent), maximum)) #250 X 6 (numEjem X Maximun)
    for s in sent:
        vector = np.zeros((maximum), dtype='int32')
        s =  s.split()
        bound = maximum
        if len(s) < maximum:
            bound = len(s)    
        for token in range(0,bound): #No encuentra macu, porque la corta
            if s[token] not in wordsList:
                vector[token] = embbeding # ???
                print(s[token])
            else:
                vector[token] = (wordsList.index(s[token]))
                embbeding = vector[token]
        matrix[i] = (vector)
        i += 1
    return matrix

# %%
X = integerSenteces(train_clean,maxSeqLength) 
print("Sentences integer representation: ",(X.shape))
print("Sentences: ",len(train_clean))
print("Integer format",X[249])
print("Normal format",train_clean[249])
# Out:
# poorcustomerservice
# hangry
# willynilly
# oldcunt
# fuking
# hoopjunkie
# nwhy
# carrierfault
# swines
# treatcustomersfairly
# huckfp
# hangry
# allat
# therewillbeblood
# prebooked
# notfair
# whypay
# ikr
# uugghh
# cantsleep
# naay
# strawmen
# hangry
# hangry
# noloyalty
# notimpressed
# squashie
# hoopjunkie
# shitless
# therewillbeblood
# notfair
# whypay
# whenwillitstop
# howmanymoretimes
# ahahah
# stfuu
# nimber
# worsethananatomicbomb
# accidentlyspillbeeronthecarpet
# bollocked
# huckfp
# gbbo
# nwhen
# fuckery
# iphonephonehome
# toofaced
# crookedcourt
# noloyalty
# notimpressed
# charlotteprotest
# bpharm
# eish
# nje
# shutupphilsimms
# nthey
# inyourneighborhoodnotdc
# selasi
# cantsleep
# gbbo
# nothappy
# fullprice
# animalrights
# swines
# hissyfits
# cuck
# charlotteprotest
# oldcunt
# keithlamontscott
# thejail
# poorcustomerservice
# hissyfits
# becouse
# emoji
# gladsheisgone
# mopo
# backtoreality
# willynilly
# treatcustomersfairly
# bbfinale
# ampalaya
# paitpaitanangpeg
# hangry
# screenshotted
# animalrights
# uhoh
# albertbarnes
# adultingistheworst
# uugghh
# whenwillitstop
# howmanymoretimes
# burkeramsey
# byee
# inpouring
# janieck
# devy
# gestort
# shoutdrive
# carefull
# ladygaga
# iscalming
# mysoul
# gbbo
# stuartspecial
# bollocked
# nthe
# gbbo
# emoji
# bbfinale
# fallsongs
# connivers
# firsttweetever
# hotchocolate
# hellootwitter
# facebookisforfamily
# feesmustfall
# arsed
# expac
# wryy
# disgracefulesin
# esinscountdown
# accidetly
# alwayss
# stuartspecial
# nimber
# worsethananatomicbomb
# accidentlyspillbeeronthecarpet
# justsaying
# hudcomedy
# adamrowe
# slutfaceshlongnugget
# gbbo
# yuuhh
# prevmed
# ugghh
# hahaha
# bbctw
# innerconflict
# progrm
# unclecamscabin
# macom
# foreveralone
# zandu
# youtubegaming
# fancypants
# hangry
# allscumbags
# bradangelina
# blacklivesmatter
# whatprankishoulddo
# terencecruther
# srry
# ghus
# boltup
# makeamericasafeagain
# sagin
# sandrabland
# philando
# batonrouge
# michaelbrown
# emoji
# thatmoment
# worstcelebritycooks
# kylexy
# nochance
# kindadontmind
# outthere
# inthedark
# evanora
# outthere
# inthedark
# cyran
# jeongguk
# pacquaio
# clarkeson
# ladygaga
# iscalming
# mysoul
# feodal
# xlzjyhg
# dreamboys
# hesananimal
# innerconflict
# wycelv
# stworldprobs
# uhoh
# welfarereform
# nmade
# nheheh
# psychowasp
# rdquo
# yuuhh
# prevmed
# ugghh
# hahaha
# fwendz
# yalls
# menforchoice
# gladsheisgone
# backtoreality
# brissett
# terencecruther
# ngrasp
# burkeramsey
# gooddeed
# nahh
# gardevoir
# germantownbroncos
# lilleague
# popwarner
# usafootball
# nerfed
# ripshawtylo
# convo
# wptmain
# welfarereform
# trumpism
# shits
# nhelen
# nstephen
# whereareugoing
# nhelen
# nstephen
# whereareugoing
# quoteoftheday
# ydu
# youtubegaming
# ntfcvmufc
# schneiderlin
# bday
# drunkjesus
# nyou
# cyran
# jeongguk
# bestrong
# bestdayever
# sirli
# nwhere
# nby
# bibleverse
# gbbo
# nthank
# dragrace
# yaass
# teamalaska
# teamkatya
# bwahaha
# srry
# motivationalquotes
# rockys
# gamedev
# bibleverse
# nfrom
# lmaoo
# nletting
# adultingistheworst
# dreamboys
# wisewords
# ehh
# yess
# piyo
# hiit
# missedoutonsummerbikinibodybutwintersunbodywilldo
# thoughtfulthursday
# ampalaya
# paitpaitanangpeg
# nawazsharif
# letgo
# resultin
# trons
# mhchat
# thoughtfulthursday
# regarde
# startasyoumeantogoon
# gbbo
# trackdawgt
# believetour
# lookd
# firsttweetever
# hotchocolate
# hellootwitter
# facebookisforfamily
# vsvplou
# kikme
# aflcatsswans
# aflfinals
# rockys
# andriaprebles
# fallsongs
# spraypainting
# greenwichmarket
# lilylou
# benoakley
# quoteoftheday
# bestdayever
# newenglandpatriots
# neverquit
# dreambig
# teamtto
# motivationalquotes
# dragrace
# yaass
# teamalaska
# teamkatya
# bwahaha
# quotestoliveby
# bestrong
# hialeshia
# neverquit
# dreambig
# teamtto
# carlabtst
# selfie
# desication
# vsvplou
# kikme
# brodcast
# ughh
# carlabtst
# minutesfromhom
# bday
# lolololol
# falure
# falure
# tatinof
# singlegirlproblems
# procrasting
# nervouswreck
# goingcrazy
# helpme
# cosplaying
# shitting
# nervouswreck
# goingcrazy
# helpme
# feelsick
# weirdwednesday
# damnit
# anthonyweiner
# gascrisis
# nodapl
# collegelife
# obamalegacy
# atleastihavebuffy
# shamefull
# shitworldforourkids
# tmrw
# terrorstatepak
# chronicpain
# iamkratom
# nyssaalghul
# mommagrendel
# gbbo
# singlegirlproblems
# nlikewise
# weirdwednesday
# damnit
# imediately
# mommagrendel
# mufc
# enoughisenough
# enoughisenough
# perilsoflivingalone
# useallthehotwatershower
# ughh
# notfair
# whydidiwatchthat
# dailyfeels
# keithlamontscott
# southafrica
# worldrhinoday
# whydidiwatchthat
# anthonyweiner
# gascrisis
# nodapl
# stepofftheledge
# youvegottobekiddingme
# violentextremism
# lydiaa
# uspol
# nimagine
# nzionists
# febreeze
# writersblock
# nreally
# whitephosphrus
# perilsoflivingalone
# meaindia
# deffo
# climatechange
# airbnbnightmare
# cantsleep
# airbnbnightmare
# ivebeenbusierwhyamioverwhelmed
# brendonati
# terrencecrutcher
# colinkapernick
# atleastihavebuffy
# gbbo
# nyssaalghul
# jobinterview
# aloneinthecity
# emoji
# phedophiliac
# terrorstatepak
# navazsharif
# kashmirissue
# littlesister
# superexcited
# jiho
# probs
# chronicpain
# iamkratom
# idk
# becz
# urself
# pakistanmustpay
# feelsick
# retweeted
# nstop
# dreamornightmare
# uscitizens
# loompa
# presidenttrump
# cantsleep
# blacklivesmatter
# kulbhushanyadav
# youngleader
# wakeupcall
# wakeupcall
# etates
# islamexposed
# islambacon
# raisingtheboss
# blacklivesmatter
# nothanks
# ntfc
# whitepeople
# blackmen
# khalistaan
# nno
# febreeze
# obamalegacy
# nationalsecurity
# choosefreedom
# cryout
# nomorehammocks
# nawazsharif
# burhanwani
# cantsleep
# martyrsnotbeggars
# nlikewise
# liscence
# nabandonment
# spookytv
# mufc
# gameover
# worstairline
# appauling
# beyondajoke
# bbcfootball
# socialanxiety
# lool
# fosu
# northamptons
# teamna
# wch
# choosefreedom
# cryout
# fnaf
# suchagirl
# ndidn
# jumpstreet
# shitting
# uspol
# pcola
# fdt
# socialanxiety
# internationaldayofpeace
# younusalgohar
# killme
# uriattacks
# gbbo
# charlotteprotest
# charlotteriot
# notfair
# badservice
# killary
# makeamericagreatagain
# bellaissocute
# gothcore
# bcuz
# momlife
# deblasio
# stopcruelty
# charlotteprotest
# charlotteriot
# needsmoresleep
# lowmood
# kapernick
# embrrssd
# expresscripts
# nshe
# nsame
# indianarmy
# ahve
# terrorstatepak
# nawazsharif
# indianarmedforces
# sheikhhasina
# unroot
# embrrssd
# expresscripts
# keithlamontscott
# goldmedal
# wrongproduct
# killme
# gbbo
# farless
# anychance
# fullofshit
# thiza
# colinpowell
# weakhillary
# jumpstreet
# nstephen
# freespeech
# ccot
# phoneprovider
# badbusiness
# captureyourmind
# findgodnow
# presidentialdebate
# presidentialelection
# orangehitler
# teamnicole
# killary
# makeamericagreatagain
# damnnit
# riggedsystem
# oreillyfactor
# getoffthetrain
# imwithher
# childrenofmen
# trumppuppet
# yourefired
# ignorantpublic
# customerexperience
# youfm
# hillaryclinton
# berniesanders
# jillstein
# gbbo
# cbtworks
# loompa
# presidenttrump
# wholeworld
# presidentialdebate
# presidentialelection
# orangehitler
# ncomment
# gbbo
# bellaissocute
# riggedsystem
# oreillyfactor
# firstworldproblems
# voxconversations
# nthese
# toldeo
# badform
# didntlaugh
# ntfc
# tmobile
# customerservice
# waittime
# amwriting
# marniemccormack
# womenintech
# tmobile
# customerservice
# waittime
# nierstein
# stepofftheledge
# youvegottobekiddingme
# badform
# didntlaugh
# indvsnz
# thtest
# jumpship
# terribledebatequestions
# trumppuppet
# bresadvice
# gadot
# atltraffic
# clintonmafia
# rhobh
# uscitizens
# convo
# tsdoffsite
# ifiwastheoppositesex
# askaman
# marblesinmouth
# littlesister
# superexcited
# worstairline
# appauling
# beyondajoke
# needsmoresleep
# houvsne
# igotbetterthingstodotonightthandie
# rhobh
# gameface
# gameface
# fnaf
# suchagirl
# dailyfeels
# vape
# urghh
# mufc
# homefronttherevolution
# wasteofmoney
# aflcatsswans
# phoneprovider
# badbusiness
# monkhill
# solate
# craigen
# badservice
# nthe
# avanquest
# thtest
# blairwitch
# blairwitchproject
# horrormovies
# nagainst
# nwhy
# nkindly
# gopats
# avanquest
# noheart
# nogood
# getoffthetrain
# hahaha
# noclue
# gadot
# atltraffic
# unitedairlines
# faceyourfears
# cpfc
# goksfillyourhouseforfree
# thirdbasecoach
# customerexperience
# monkhill
# thoughtsbecomethings
# lifehacks
# pleasert
# problemsolving
# emoji
# lovinleeds
# thirdbasecoach
# gamedev
# indiedev
# amdeadtime
# proudofyouprimeminister
# whoisit
# relationshift
# clifemacon
# gbbo
# hardyboys
# impactonpop
# brendonati
# rhow
# horrorfilm
# rashford
# authorlove
# ajahnae
# euriechsa
# goksfillyourhouseforfree
# turnt
# ruint
# firesauce
# hotsauce
# mildsauce
# getsauced
# champagnedreams
# shutup
# gbbo
# wakemeup
# rgds
# residentadvisor
# poorservice
# nsuch
# nthat
# amndbots
# aqeelsyed
# lifeisbeautiful
# livewithpurpose
# nface
# nthis
# firstworldproblems
# manup
# americanairlinessucks
# aateam
# cantsleep
# fintech
# failur
# nstephen
# freespeech
# ccot
# shutup
# blairwitch
# blairwitchproject
# horrormovies
# fosu
# notcool
# picoftheday
# picoftheday
# funnypics
# stopbullying
# eaxh
# lovewins
# ripshawtylo
# yourefired
# gamedev
# indiedev
# amdeadtime
# texastech
# texansarebad
# ourgirl
# bbfail
# anyyone
# homefronttherevolution
# wasteofmoney
# clevelandhustles
# noclue
# wtvr
# amwriting
# teamna
# wch
# spookytv
# ghosthunters
# notcool
# hahahah
# bestadvice
# movienight
# knw
# glossinger
# cantstoplaughing
# spokeword
# mellogang
# djlife
# wazza
# wouldve
# mufc
# confiaejce
# nothanks
# marblesinmouth
# anychance
# nbecause
# youngleader
# turnt
# ruint
# firesauce
# hotsauce
# mildsauce
# getsauced
# champagnedreams
# publictransport
# canberraairport
# childrenofmen
# horrorfilm
# smackdev
# franglaise
# bernab
# viallreal
# mcfc
# solate
# amwriting
# indiansummer
# texastech
# texansarebad
# americanairlinessucks
# aateam
# hardyboys
# impactonpop
# jobinterview
# bobmarley
# fwm
# healthcareit
# socialmedia
# bigdata
# growthhacking
# wch
# brotein
# officaly
# dayatatime
# addair
# thursdaythoughts
# yourpushfactor
# gbbo
# snowdenmovie
# americanhorrorstory
# addair
# thursdaythoughts
# yourpushfactor
# bbfinale
# onlinemarketing
# solopreneur
# darthvader
# hoco
# residentadvisor
# poorservice
# bozzelli
# benevans
# movienight
# nogood
# contrib
# earhole
# worktivetruth
# dosomething
# yallamaccabi
# pcola
# dayfiance
# nafter
# panamaleaks
# nnow
# bahamasleaks
# dayfiance
# manup
# houvsne
# igotbetterthingstodotonightthandie
# gopats
# darthvader
# hahahaa
# equestrianhour
# okgoogle
# okgoogle
# personalassistant
# mellogang
# djlife
# firstdayoffall
# noheart
# pround
# getsmartwitharq
# whiteicenetwork
# dosomething
# buviobby
# mattmilne
# goodday
# americanhorrorstory
# twoo
# herbalifenutrition
# tastesogood
# nowords
# rocklandcounty
# ravis
# herbalifenutrition
# tastesogood
# nowords
# goodday
# goodday
# autumnmemories
# annabailey
# bridgetjonesbaby
# teammark
# thenicebot
# greatday
# gopackgo
# gogipego
# thisisus
# luckii
# igotthis
# bday
# thenicebot
# autumnmemories
# annabailey
# firstdayoffall
# pumpkinspice
# amwriting
# retweeted
# gunnysmith
# ndays
# relaxationiskey
# nlet
# rehoi
# ngood
# lololol
# fridayfeeling
# goodday
# modernfamily
# funsville
# gbbo
# opengym
# grandmercurejktkemayoran
# retweeted
# gunnysmith
# ndays
# bday
# eatcake
# goodday
# moretears
# feelsgood
# boostercourse
# hahahaha
# musthave
# lololol
# bestinbusiness
# happyme
# modernfamily
# gopackgo
# gogipego
# kaml
# cheerchick
# jeepgirl
# idriveajeep
# jeepjeep
# thenicebot
# melbjs
# thenicebot
# igotthis
# bridgetjonesbaby
# teammark
# opengym
# hahaha
# thisisus
# nlet
# ndon
# missyou
# wch
# teamna
# rewatching
# herewego
# bestinbusiness
# happyme
# bday
# eatcake
# mackinonns
# teamna
# wch
# actorslife
# hardworkpaysoff
# explicits
# boostercourse
# relaxationiskey
# goodcustomerservice
# garoppolo
# socialmedia
# winewednesday
# surprisepeople
# influenceinternational
# queendom
# seewitheyesofmercy
# grandmercurejktkemayoran
# contentwiththelordsportion
# thenicebot
# wsjnordics
# thenicebot
# timelesstips
# roadsofar
# lifetrip
# bday
# bday
# lethalweapon
# ukedchat
# contentwiththelordsportion
# lmaoo
# wch
# hygge
# gbbo
# webiversary
# herothegreyhound
# lifequote
# onechicago
# createlove
# sugarboy
# hahaha
# raar
# openhouse
# futurecantor
# nycletsgo
# staystrong
# yourebeautiful
# tgit
# everone
# lmboo
# maybeoneday
# hopefullyfunny
# lmboo
# personaldevelopment
# ntoday
# personaldevelopment
# bacheloretteau
# samvrhys
# pochama
# nalways
# ndare
# pandabot
# gby
# saturdaynightlive
# sunriseyoga
# bodyawareness
# gamaynoir
# evenin
# bcwinechat
# bffing
# witout
# secreteyes
# walterdale
# yeg
# snowgang
# bodyposi
# whitegirlwednesday
# gbbo
# hygge
# gbbo
# followback
# cutealert
# phenomanal
# rcmh
# focusx
# motivationalquotes
# quoteoftheday
# gbbo
# goodday
# sevylor
# eyggjxml
# gbbo
# actorslife
# hardworkpaysoff
# xhaka
# engiybhekayo
# yasezayoni
# lifequote
# nhlnycsweepstakes
# openhouse
# futurecantor
# nycletsgo
# tgit
# tiburonchamber
# yachtrock
# mustacheharbor
# npursing
# finfin
# symptomatize
# vrlfeyrn
# convo
# sunriseyoga
# bodyawareness
# ntomiho
# ipaglabanmo
# tapingday
# cutealert
# tribez
# castlez
# mouchole
# milspeak
# mysportinglife
# garoppolo
# wearecst
# maybeoneday
# hopefullyfunny
# racepimp
# fscts
# libtard
# biasedmedia
# neverhillary
# tbh
# gbbo
# topno
# moretears
# walterdale
# yeg
# neverchange
# yachtrock
# mustacheharbor
# muchlove
# habittalk
# problemsolving
# behappy
# ukedchat
# buffnpolish
# nsam
# defo
# emotionalhedge
# gleekforever
# mishle
# neverchange
# socialmedia
# winewednesday
# musicallyjh
# muchlove
# nwho
# nmummified
# neating
# mqnaocu
# jkuvmvqxy
# nconclusion
# pictureday
# ornot
# followback
# nwill
# finfin
# mayaangelou
# waltzwithbashir
# bqavtja
# woficc
# robocoq
# shortfilms
# wisewords
# robinhoodhour
# bizitalk
# bizhour
# southyorkshire
# mansfieldhour
# sheffieldhour
# nottshour
# thebible
# npraise
# npsa
# gbbo
# observingyou
# allthetime
# becareful
# incetown
# itsagunalright
# intermit
# irruptive
# twelvemonth
# nephalism
# thisisus
# isthereahelplineforthis
# musicallyjh
# bacheloretteau
# samvrhys
# thisisus
# isthereahelplineforthis
# tatenashi
# saltes
# narkham
# massali
# massali
# lethalweapon
# gbbo
# bobproctor
# nominatebunkface
# dming
# ntalk
# problemsolving
# behappy
# rewatching
# titanwisdom
# snowgang
# bodyposi
# whitegirlwednesday
# missyou
# arcdental
# problemsolving
# behappy
# thegoldbergs
# granddesigns
# shittalking
# nsfw
# lovee
# tagsforlikes
# tflers
# tweegram
# photooftheday
# arcdental
# habittalk
# problemsolving
# behappy
# pikxb
# sceen
# worstoneyet
# cmmyd
# elkracken
# gottawearshades
# letsgoyankees
# lkskqufke
# elkracken
# gottawearshades
# letsgoyankees
# yoosung
# gleesome
# tipstosurviveapoweroutage
# hellorhighwater
# gleegoodbye
# nhow
# fuckign
# herothegreyhound
# liarthiefscoundrel
# jammygunnerscum
# lufc
# arround
# ovet
# northcarolina
# neeze
# amndbots
# exhilarate
# wisewords
# milspeak
# tzxchldaq
# mirana
# nnot
# mombrain
# toomuchgoingon
# longday
# mombrain
# toomuchgoingon
# longday
# oilandgas
# prematured
# xucqb
# racepimp
# fscts
# libtard
# biasedmedia
# neverhillary
# rewatching
# bulushi
# amwriting
# onesimplechange
# hssu
# srpt
# etep
# etep
# adcomm
# aldub
# ndweeksary
# robocoq
# shortfilms
# itsagunalright
# blaiming
# bazigaga
# categ
# shanghais
# uudqujcia
# exactment
# hephxho
# itnis
# coltsnation
# werent
# gbbo
# brexit
# ishqbaaz
# terribledebatequestions
# izn
# desgusting
# tuhday
# oilandgas
# onision
# fucktrump
# normy
# reformationday
# healingjustice
# idk
# poorservice
# worstenemy
# thinktoomuch
# sorethroat
# fallweather
# carletonuniversity
# nsaddened
# nthe
# ntough
# nthis
# nroad
# nstill
# parcc
# atleastihavebuffy
# mentalhealth
# meetingmyabuserincourt
# dvsurvivor
# firstdayoffall
# thingsdie
# noflipflops
# blackinamerica
# wearenotsafe
# lodd
# charlotteprotest
# policeshootings
# gbbo
# unfollowing
# holidayblues
# wantogoback
# gbbo
# baarisshh
# patheticservices
# worstenemy
# thinktoomuch
# terrancecrutcher
# scfc
# stohul
# tbh
# dosomethingpoliticans
# congresscritters
# haikuchallenge
# nthe
# nmy
# nno
# smokeys
# ourworld
# sleepissues
# straightner
# lostwithoutmyhairstraightener
# somanypeople
# overit
# nojustice
# surivivor
# nomore
# anxietymaybe
# missingfriends
# growingupsucks
# lostfriends
# wheresthetruefriends
# worstairline
# appauling
# beyondajoke
# turnd
# bcuz
# silvereliteleftbehind
# mufc
# paulwasrobbed
# rewardhardwork
# bitterjury
# endtrumpweek
# mhchat
# terencecutcher
# wanttogobacktominehead
# ollafest
# ripkara
# extremeworld
# mhchat
# lool
# remainer
# wakeupcall
# mooncup
# prevelant
# twats
# urgh
# ourworld
# tunechi
# terencecruther
# nlast
# playwithsomeheart
# firstdayoffall
# goodbyesummer
# bathingsuitsforever
# theyve
# sadtimes
# cpfc
# ritamarley
# mufc
# needhelp
# sufc
# mufc
# ahut
# neach
# mgla
# selfhelp
# idgi
# rogerfederershop
# mhchat
# teampaella
# dylon
# hoody
# jesuschristhealssavesask
# fatloss
# gbbo
# gaad
# baitswitch
# badbusiness
# honoryourdeal
# stillwaiting
# wheresmybag
# dobetter
# villase
# waitingforexplanation
# preggy
# terrancecrutcher
# njdevils
# customerservicefail
# kennen
# xdd
# gbbo
# needhelp
# youpromised
# havemercy
# needpublisher
# beingedited
# workingonsidebook
# turnd
# bcuz
# silvereliteleftbehind
# lbvfs
# nstill
# terencecutcher
# gbbo
# mentalhealth
# talkshoe
# theydontlikeyoueither
# unwoke
# amndbots
# charlotteprotest
# policeshootings
# takeing
# gameing
# gavc
# amwriting
# gardevoir
# elphie
# grimmerie
# cureforinsomnia
# sooked
# selenagomez
# brexit
# namjoon
# nngh
# notif
# whereami
# brodcast
# lifeontheroad
# murking
# nahh
# nlpoli
# preschoolpolitics
# momthings
# whatgoesaroundcomesaround
# mybrokenfoot
# ukrunchat
# nbreath
# vinb
# vinb
# youarenotalone
# nooneisalone
# theydontlikeyoueither
# unwoke
# worldcupofhockey
# gbbo
# mhchat
# nyou
# brexit
# campaignin
# yawnoff
# amaity
# magicall
# nextt
# cloved
# unide
# norffampton
# applemusic
# treadlines
# extremeworld
# floofel
# lethalweapon
# xbeujgb
# wesper
# nalso
# inej
# feelz
# bravehearted
# thankyoucgi
# aqw
# hakyeon
# wonshik
# jaehwan
# feedingindia
# skillingindia
# startasyoumeantogoon
# gbbo
# spraypainting
# greenwichmarket
# lilylou
# benoakley
# spektar
# bojack
# thankfulmoment
# sences
# firstfriday
# nyou
# halloweenhorrornights
# harambe
# nhear
# mediumpurple
# shaytan
# wallahi
# shaytan
# nheheh
# larh
# cambma
# harvardsq
# nsure
# autodealerlive
# redheadteen
# boldandbeautiful
# schkeuditz
# preschoolpolitics
# momthings
# sixwordstory
# amwriting
# oligodendroglioma
# fallenskies
# jaymohrsports
# alwayshungry
# emoji
# newcastlegateshead
# musicbusiness
# musicislife
# askaman
# siyahleka
# oddish
# vileplume
# lifeontheroad
# peoplelikemebecause
# kuowrecord
# googlemaps
# blondmoment
# sonicsatam
# aosth
# toonie
# furrytails
# emojis
# nfrom
# granddesigns
# wibbly
# writingtip
# bettertogether
# nhearing
# akame
# juvia
# followme
# followback
# rhythmandblues
# ramelton
# haddrell
# nfri
# tunbridgewells
# beaconny
# raabin
# nwith
# nxx
# mrrobot
# nerdshow
# ricefodays
# ngerry
# byronbay
# lethalweapon
# nthose
# nthey
# nthey
# notusedtoit
# imafianc
# selfies
# nmade
# nfeeling
# nropes
# moonshinesociety
# housemd
# tvshow
# gbbo
# ntomorrow
# nnext
# livemusic
# rockandroll
# springequinox
# autumnequinox
# thebeautyofbalance
# tshirt
# nnothing
# selfhelp
# picoftheday
# picoftheday
# funnypics
# glowy
# byronbay
# Sentences integer representation:  (3613, 83)
# Sentences:  3613
# Integer format [8.100e+01 4.300e+01 3.320e+02 5.960e+02 1.318e+03 3.800e+01 4.146e+03
#  8.100e+01 1.170e+02 4.100e+01 1.190e+02 5.000e+00 1.200e+01 1.920e+02
#  8.350e+02 4.300e+01 3.000e+01 1.920e+02 5.476e+03 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00]
# Normal format you will never find someone who loved you like i did and that my love will be my revenge

# %%
def toClasses(emo):
    id_emo = []
    for e in emo:
        e = e.split()
        e = e[0]
        if e == 'joy':
            e = 1
        elif e == 'sadness':
            e = 2
        elif e == 'anger':
            e = 3
        elif e == 'fear':
            e = 4
            
        id_emo.append(e)
    return id_emo
emotion = toClasses(emotion)
print(emotion[0]," ",sentences[0])
# Out:
# 3   How the fu*k! Who the heck! moved my fridge!... should I knock the landlord door. #angry #mad ##

# %% [markdown]
# Split the Data (stratify) into : Train && Test Sets

# %%
print("Sentences: ",len(X),"  Labels: ",len(emotion))
X_train, X_test, Y_train, Y_test = train_test_split(X, emotion, test_size=0.20, random_state=random.randrange(100), stratify=emotion)
print("X_train: ",len(X_train),"  Y_train: ",len(Y_train),"  X_test: ",len(X_test),"  Y_test: ",len(Y_test))
# Out:
# Sentences:  3613   Labels:  3613
# X_train:  2890   Y_train:  2890   X_test:  723   Y_test:  723

# %%
import matplotlib.pyplot as plt
import collections
# %matplotlib inline
def histograma(emotion):
    #print(emotion)
    plt.hist(emotion, 50)
    plt.xlabel('Emotion')
    plt.ylabel('Frequency')
    plt.axis([0, 4, 0, 1000])
    plt.show()
histograma(Y_train)
print("*****************")
histograma(Y_test)
# Out:
# *****************

# %% [markdown]
# Converting the Labels into Onehot Vectors

# %%
def toLabels(emo):
    classes = 4
    Y = np.zeros((len(emo), classes)) #Num Ejemplos X 4 emociones
    for e in range(0,len(emo)):
        vector = np.zeros((classes))
        vector[(emo[e] % (classes + 1)) - 1] = 1 
        Y[e] = vector
        #print(emo[e],"---",vector)
    return Y
 
Y_train = toLabels(Y_train)
Y_test = toLabels(Y_test)

# %%
print("Y_train: ",Y_train.shape," Num Ejem X # clases")
print("X_train: ",X_train.shape," Num Ejem X Maximun Lengh")
print("Y_test: ",Y_test.shape," Num Ejem X # clases")
print("X_test: ",X_test.shape," Num Ejem X Maximun Lengh")
# Out:
# Y_train:  (2890, 4)  Num Ejem X # clases
# X_train:  (2890, 83)  Num Ejem X Maximun Lengh
# Y_test:  (723, 4)  Num Ejem X # clases
# X_test:  (723, 83)  Num Ejem X Maximun Lengh

# %% [markdown]
# RNN Model

# %%
batchSize = 85 #Tiene que ser multiplo del NumEjem
lstmUnits = 64
numClasses = 4

# %% [markdown]
# Declarando placeholders para los labels (6 emotions) && data imput

# %%
import tensorflow as tf
tf.reset_default_graph()
numDimensions = 300 

#labels = tf.placeholder(tf.float32, [batchSize, numClasses])
#input_data = tf.placeholder(tf.int32, [batchSize, maxSeqLength])
labels = tf.placeholder(tf.float32, [None, numClasses])
input_data = tf.placeholder(tf.int32, [None, maxSeqLength])

# %% [markdown]
# Embeddings: Le damos el formato a nuestra data, aún no compilamos nada, solo declaramos

# %%
data = tf.Variable(tf.zeros([batchSize, maxSeqLength, numDimensions]),dtype=tf.float32)
data = tf.nn.embedding_lookup(wordVectors,input_data)

# %% [markdown]
# LSTM Model

# %%
lstmCell = tf.contrib.rnn.BasicLSTMCell(lstmUnits)
lstmCell = tf.contrib.rnn.DropoutWrapper(cell=lstmCell, output_keep_prob=0.75)
value, _ = tf.nn.dynamic_rnn(lstmCell, data, dtype=tf.float32)

# %%
weight = tf.Variable(tf.truncated_normal([lstmUnits, numClasses]))
bias = tf.Variable(tf.constant(0.1, shape=[numClasses]))
value = tf.transpose(value, [1, 0, 2])
last = tf.gather(value, int(value.get_shape()[0]) - 1)
prediction = (tf.matmul(last, weight) + bias)

# %%
correctPred = tf.equal(tf.argmax(prediction,1), tf.argmax(labels,1))
accuracy = tf.reduce_mean(tf.cast(correctPred, tf.float32))

# %%
learning_rate = 0.001
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=prediction, labels=labels))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)
# Out:
# C:\Users\danie\Anaconda3\envs\Compositor\lib\site-packages\tensorflow\python\ops\gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %% [markdown]
# Tensorboar

# %%
import datetime
def board(sess):
    tf.summary.scalar('Loss', loss)
    tf.summary.scalar('Accuracy', accuracy)
    tf.summary.histogram("Histogrma/hAccu", accuracy)
    merged = tf.summary.merge_all()
    logdir = "board/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + "/"
    writer = tf.summary.FileWriter(logdir, sess.graph)
    return merged,writer

# %% [markdown]
# Confusion Matrix Plot

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
# Initializing the variables
init = tf.global_variables_initializer()
display_step = 10
numEjemplos = 2890         
iterations = 150

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    #Calling tensorboard function
    #---merged,writer = board(sess)
    print("X_train: ",len(X_train),"  Y_train: ",len(Y_train),"  X_test: ",len(X_test),"  Y_test: ",len(Y_test))

    # Training cycle
    for epoch in range(iterations):
        avg_cost = 0.
        avg_accu = 0.
        total_batch = int(numEjemplos/batchSize)
        #Create X groups of (50,6) Labels && (50,maximum) Examples
        X_batches = np.array_split(X_train, total_batch)
        Y_batches = np.array_split(Y_train, total_batch)
        
        # Loop over all batches
        for i in range(total_batch):
            batch_x, batch_y = X_batches[i], Y_batches[i]
            #print("X: ",batch_x.shape)
            #print("Y: ",batch_y.shape)
            # Run optimization op (backprop) and cost op (to get loss value)
            _, c , accu= sess.run([optimizer, loss, accuracy], feed_dict={input_data: batch_x,
                                                          labels: batch_y})
            # Compute average loss
            avg_cost += c / total_batch
            avg_accu += accu / total_batch

            #Write summary to Tensorboard
            '''if (epoch % 10 == 0):
                summary = sess.run(merged, {input_data: batch_x, labels: batch_y})
                writer.add_summary(summary, epoch)'''
            

            #Save the network every 10,000 training iterations
            #if (i % 10000 == 0 and i != 0):
                # save_path = saver.save(sess, "models/pretrained_lstm.ckpt", global_step=i)
                 # print("saved to %s" % save_path)
            #writer.close()

        if epoch % display_step == 0:
            print("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(avg_cost)," accuracy=", "{:.9f}".format(avg_accu*100))
    print("Optimization Finished!")
    
    #Test Model LSTM  
    correctPred = tf.equal(tf.argmax(prediction,1), tf.argmax(labels,1))
    # Calculate accuracy
    accuracy = tf.reduce_mean(tf.cast(correctPred, "float"))
    print("Accuracy:", accuracy.eval({input_data: X_test, labels: Y_test}))
    
    #Matriz de confusion

    #print("Test Samples, Class Predictions: ")
    #----Result es mi tensor prediction convertido a np.array
    result = tf.argmax(prediction , 1).eval({input_data: X_test, labels: Y_test})
    #print(result.shape)
    
    
    #print("Test Samples: ")
    test = (tf.argmax(Y_test , 1).eval()) #Convierte de [0,0,1,0,0] a [2] y lo hace np.array
    #print(test.shape)
    #print("Conversion: ")
    #for i in range(0,len(test)):
        #print(test[i],"---",Y_test[i],"---",result[i])
      

    from sklearn.metrics import confusion_matrix
    y_true = test
    y_pred = result
    #print(confusion_matrix(y_true, y_pred))
    class_names = ["Hapinnes","Sadness","Anger","Fear"]

    from sklearn.metrics import classification_report
    print(classification_report(y_true, y_pred, target_names=class_names))

    # Compute confusion matrix
    cnf_matrix = confusion_matrix(y_true, y_pred)
    np.set_printoptions(precision=2)

    # Plot non-normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names,
                          title='Confusion matrix, without normalization')

    # Plot normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                          title='Normalized confusion matrix')

    plt.show()
# Out:
# X_train:  2890   Y_train:  2890   X_test:  723   Y_test:  723
# Epoch: 0001 cost= 1.376337826  accuracy= 31.799308999
# Epoch: 0011 cost= 1.091619563  accuracy= 49.480970554
# Epoch: 0021 cost= 0.826569578  accuracy= 62.664362087
# Epoch: 0031 cost= 0.723040321  accuracy= 69.134949937
# Epoch: 0041 cost= 0.730511379  accuracy= 69.965399714
# Epoch: 0051 cost= 0.469364874  accuracy= 83.633218969
# Epoch: 0061 cost= 0.352575991  accuracy= 88.788928004
# Epoch: 0071 cost= 0.277892949  accuracy= 91.972318818
# Epoch: 0081 cost= 0.254317655  accuracy= 91.730104299
# Epoch: 0091 cost= 0.196050583  accuracy= 93.944637039
# Epoch: 0101 cost= 0.161520936  accuracy= 95.570934520
# Epoch: 0111 cost= 0.228046833  accuracy= 93.321799706
# Epoch: 0121 cost= 0.123535587  accuracy= 96.470588446
# Epoch: 0131 cost= 0.133537525  accuracy= 96.055363557
# Epoch: 0141 cost= 0.146722016  accuracy= 95.640138668
# Optimization Finished!
# Accuracy: 0.68603045
#              precision    recall  f1-score   support
#
#    Hapinnes       0.88      0.74      0.80       165
#     Sadness       0.66      0.45      0.53       157
#       Anger       0.65      0.74      0.69       171
#        Fear       0.63      0.78      0.70       230
#
# avg / total       0.70      0.69      0.68       723
#
# Confusion matrix, without normalization
# [[122  14   5  24]
#  [  6  70  34  47]
#  [  4   7 127  33]
#  [  7  15  29 179]]
# Normalized confusion matrix
# [[0.74 0.08 0.03 0.15]
#  [0.04 0.45 0.22 0.3 ]
#  [0.02 0.04 0.74 0.19]
#  [0.03 0.07 0.13 0.78]]

# %%
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE  
print('Balance',Counter(emotion))
# Out:
# Balance Counter({1: 1284, 2: 640, 3: 528, 6: 488, 5: 486, 4: 269})

# %%
from imblearn.over_sampling import SMOTE, ADASYN
#Banlancea ADASYN
X_balance, Y_balance = ADASYN().fit_sample(X,emotion)
print('Balance',Counter(Y_balance))
# Out:
# Balance Counter({6: 1402, 5: 1384, 3: 1297, 1: 1284, 2: 1242, 4: 1227})

# %%
print(X_balance.shape," ",Y_balance.shape)
print(len(X)," ",len(emotion))
# Out:
# (7836, 15)   (7836,)
# 3695   3695

# %%
X_train_b, X_test_b, Y_train_b, Y_test_b = train_test_split(X_balance, Y_balance, test_size=0.13, random_state=random.randrange(50), stratify=Y_balance)
print("X_train: ",len(X_train_b),"  Y_train: ",len(Y_train_b),"  X_test: ",len(X_test_b),"  Y_test: ",len(Y_test_b))
# Out:
# X_train:  6817   Y_train:  6817   X_test:  1019   Y_test:  1019

# %%
Y_train_b = toLabels(Y_train_b)
Y_test_b = toLabels(Y_test_b)

# %% [markdown]
# Otro Modelo: Solo balanceamos Trainset

# %%
#Averogua ottros modelos
#Cambie el keep_drop
#Cambia learning rate
#Cambie num unidades 128?
#Prueba con tu modelo
